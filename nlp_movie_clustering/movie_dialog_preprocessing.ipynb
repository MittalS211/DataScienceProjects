# %% [markdown]
# # Cornell movie dialog corpus prepocessing
# ## construct Convo exchanges by replcing list of line id with dialogue!!!
#
# The cornell movie dialog corpus' raw text fomat requires extensive parsing including:
# 1. extracting metadata and dialog for each movie,
# 2. cleaning movie dialog of non alpha numeric characters
# 3. reconstruction of movies' conversations according to Line ID seqencing in 'movie_conversations.txt'

# %%
# boilerplate
import re
import pandas as pd
import numpy as np
import spacy
import matplotlib.pyplot as plt
import matplotlib
from ast import literal_eval
from tqdm import tqdm
% matplotlib inline

# %%
# read in meta data
with open('/Users/markespina/Downloads/movie-dialogs-corpus/movie_titles_metadata.txt', encoding='ISO-8859-1') as text:
    data = []
    data.append(text.read())

# initialize raw data
raw_text = data[0]

# flag all movie IDs -- format 'mXX'
flag_id = r"m\d+"

# flag all movie genres in sq brackets
flag_brackets = "[\[].*?[\]]"


## save movie_ids to var
movie_ids = re.findall(flag_id, raw_text)
genres =re.findall(flag_brackets, raw_text)



# look at data
print(movie_ids[:5])
print(genres[:5])
# Out:
# ['m0', 'm1', 'm2', 'm3', 'm4']
# ["['comedy', 'romance']", "['adventure', 'biography', 'drama', 'history']", "['action', 'crime', 'drama', 'thriller']", "['adventure', 'mystery', 'sci-fi']", "['action', 'comedy', 'crime', 'drama', 'thriller']"]

# %%
# ## genre seems to be should be list format
# Let's convert with ast module
genre_lists = [literal_eval(genre) for genre in genres]

# extract movie ID - Genres pairs, save to Dict: movie_genres
movie_genres = dict(zip(movie_ids,genre_lists))


# display genres
movie_genres
# Out:
# {'m0': ['comedy', 'romance'],
#  'm1': ['adventure', 'biography', 'drama', 'history'],
#  'm2': ['action', 'crime', 'drama', 'thriller'],
#  'm3': ['adventure', 'mystery', 'sci-fi'],
#  'm4': ['action', 'comedy', 'crime', 'drama', 'thriller'],
#  'm5': ['action', 'adventure', 'romance', 'sci-fi', 'thriller'],
#  'm6': ['crime', 'mystery', 'thriller'],
#  'm7': ['fantasy', 'horror', 'thriller'],
#  'm8': ['fantasy', 'horror', 'thriller'],
#  'm9': ['sci-fi', 'thriller'],
#  'm10': ['drama', 'mystery', 'thriller'],
#  'm11': ['action', 'drama', 'thriller'],
#  'm12': ['comedy', 'romance', 'sci-fi'],
#  'm13': ['comedy', 'romance'],
#  'm14': ['crime', 'drama', 'sci-fi', 'thriller'],
#  'm15': ['action', 'sci-fi', 'thriller'],
#  'm16': ['biography', 'drama', 'music'],
#  'm17': ['horror', 'romance'],
#  'm18': ['drama'],
#  'm19': ['action', 'western'],
#  'm20': ['drama', 'thriller'],
#  'm21': ['drama', 'thriller'],
#  'm22': ['action', 'adventure', 'comedy', 'crime'],
#  'm23': ['action', 'adventure', 'thriller'],
#  'm24': ['comedy', 'romance'],
#  'm25': ['action', 'crime', 'drama', 'mystery', 'thriller'],
#  'm26': ['crime', 'drama'],
#  'm27': ['comedy', 'drama', 'music'],
#  'm28': ['drama', 'romance', 'war'],
#  'm29': ['crime', 'drama', 'mystery', 'thriller'],
#  'm30': ['adventure', 'drama', 'fantasy'],
#  'm31': ['comedy', 'crime', 'romance', 'thriller'],
#  'm32': ['drama'],
#  'm33': ['action', 'crime', 'drama', 'thriller'],
#  'm34': ['drama', 'sci-fi', 'thriller'],
#  'm35': ['comedy', 'drama', 'romance'],
#  'm36': ['crime', 'mystery', 'thriller'],
#  'm37': ['action', 'crime', 'drama', 'thriller'],
#  'm38': ['comedy', 'crime'],
#  'm39': ['action', 'adventure', 'mystery', 'thriller'],
#  'm40': ['action', 'biography', 'drama', 'history', 'war'],
#  'm41': ['drama', 'mystery', 'sci-fi', 'thriller'],
#  'm42': ['drama', 'romance', 'war'],
#  'm43': ['adventure', 'drama'],
#  'm44': ['drama', 'romance'],
#  'm45': ['crime', 'thriller'],
#  'm46': ['crime', 'drama'],
#  'm47': ['comedy', 'sci-fi', 'thriller'],
#  'm48': ['action', 'crime', 'drama', 'horror', 'sci-fi', 'thriller'],
#  'm49': ['comedy', 'music'],
#  'm50': ['drama', 'mystery', 'sci-fi'],
#  'm51': ['comedy', 'adult'],
#  'm52': ['comedy', 'musical'],
#  'm53': ['biography', 'drama', 'history'],
#  'm54': ['comedy', 'adventure', 'fantasy'],
#  'm55': ['drama', 'romance', 'sci-fi'],
#  'm56': ['comedy', 'drama', 'romance', 'western'],
#  'm57': ['horror', 'mystery', 'mystery', 'sci-fi', 'sci-fi'],
#  'm58': ['action', 'adventure', 'fantasy', 'sci-fi', 'fantasy'],
#  'm59': ['comedy', 'drama', 'romance'],
#  'm60': ['drama', 'fantasy'],
#  'm61': ['action', 'comedy', 'horror', 'thriller'],
#  'm62': ['biography', 'drama'],
#  'm63': ['drama', 'horror', 'sci-fi'],
#  'm64': ['horror'],
#  'm65': ['action', 'crime', 'horror', 'thriller'],
#  'm66': ['action', 'drama'],
#  'm67': ['action', 'horror', 'sci-fi', 'thriller'],
#  'm68': ['action', 'adventure', 'comedy', 'sci-fi'],
#  'm69': ['drama'],
#  'm70': ['comedy', 'crime', 'thriller'],
#  'm71': ['horror', 'mystery', 'thriller'],
#  'm72': ['comedy', 'drama'],
#  'm73': ['adventure', 'drama', 'thriller'],
#  'm74': ['action',
#   'adventure',
#   'comedy',
#   'fantasy',
#   'sci-fi',
#   'action',
#   'adventure',
#   'comedy',
#   'sci-fi'],
#  'm75': ['animation', 'comedy', 'fantasy', 'sci-fi', 'horror'],
#  'm76': ['action', 'adventure', 'drama'],
#  'm77': ['comedy', 'drama', 'romance'],
#  'm78': ['drama', 'romance'],
#  'm79': ['crime', 'drama', 'thriller'],
#  'm80': ['drama', 'horror', 'thriller'],
#  'm81': ['horror', 'thriller'],
#  'm82': ['comedy', 'drama'],
#  'm83': ['drama'],
#  'm84': ['comedy', 'romance'],
#  'm85': ['drama', 'horror', 'thriller'],
#  'm86': ['action', 'adventure', 'fantasy'],
#  'm87': ['horror'],
#  'm88': ['comedy', 'drama', 'music', 'romance'],
#  'm89': ['action', 'fantasy'],
#  'm90': ['comedy', 'drama', 'romance'],
#  'm91': ['drama', 'war'],
#  'm92': ['horror'],
#  'm93': ['comedy', 'drama'],
#  'm94': ['drama', 'romance', 'sport'],
#  'm95': ['drama', 'sci-fi', 'thriller'],
#  'm96': ['horror', 'sci-fi'],
#  'm97': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm98': ['action', 'adventure', 'thriller', 'action', 'adventure', 'fantasy'],
#  'm99': ['action', 'adventure'],
#  'm100': ['action', 'adventure', 'comedy', 'crime', 'sci-fi'],
#  'm101': ['biography', 'drama', 'thriller'],
#  'm102': ['comedy', 'romance', 'crime'],
#  'm103': ['comedy', 'romance'],
#  'm104': ['biography', 'drama', 'history', 'mystery', 'thriller'],
#  'm105': ['crime', 'drama', 'thriller'],
#  'm106': ['drama', 'mystery', 'thriller'],
#  'm107': ['horror', 'sci-fi'],
#  'm108': ['thriller'],
#  'm109': ['comedy', 'drama'],
#  'm110': ['crime', 'drama', 'thriller'],
#  'm111': ['crime', 'drama'],
#  'm112': ['mystery', 'thriller'],
#  'm113': ['fantasy', 'action', 'adventure', 'sci-fi'],
#  'm114': ['crime', 'drama', 'thriller'],
#  'm115': [],
#  'm116': ['drama', 'romance'],
#  'm117': ['comedy'],
#  'm118': ['fantasy', 'adventure', 'romance'],
#  'm119': ['drama', 'romance'],
#  'm120': ['drama', 'crime', 'thriller'],
#  'm121': ['fantasy',
#   'comedy',
#   'romance',
#   'animation',
#   'comedy',
#   'fantasy',
#   'horror'],
#  'm122': ['action', 'sci-fi'],
#  'm123': ['drama', 'horror', 'mystery', 'thriller'],
#  'm124': ['adventure', 'drama', 'fantasy', 'mystery'],
#  'm125': ['action', 'adventure', 'comedy', 'sci-fi'],
#  'm126': ['action',
#   'crime',
#   'mystery',
#   'sci-fi',
#   'thriller',
#   'action',
#   'animation',
#   'drama',
#   'mystery',
#   'sci-fi',
#   'thriller'],
#  'm127': ['comedy', 'crime', 'drama', 'thriller'],
#  'm128': ['biography', 'drama', 'history'],
#  'm129': ['action', 'crime', 'drama', 'thriller'],
#  'm130': ['drama', 'romance'],
#  'm131': ['comedy', 'war', 'drama'],
#  'm132': ['comedy', 'drama', 'romance'],
#  'm133': ['action', 'comedy', 'crime', 'drama', 'thriller'],
#  'm134': ['adventure', 'drama', 'sci-fi'],
#  'm135': ['action', 'family'],
#  'm136': ['crime', 'drama'],
#  'm137': ['animation', 'comedy', 'fantasy', 'romance'],
#  'm138': ['short'],
#  'm139': ['drama'],
#  'm140': ['comedy', 'romance'],
#  'm141': ['comedy', 'drama'],
#  'm142': ['action', 'adventure', 'fantasy'],
#  'm143': ['action', 'comedy', 'fantasy'],
#  'm144': ['family', 'adventure'],
#  'm145': ['comedy'],
#  'm146': ['crime', 'drama', 'thriller'],
#  'm147': ['drama', 'film-noir', 'thriller'],
#  'm148': ['horror'],
#  'm149': ['comedy', 'romance'],
#  'm150': ['biography', 'drama'],
#  'm151': ['crime', 'drama', 'mystery', 'thriller', 'western'],
#  'm152': ['comedy', 'crime', 'romance', 'thriller'],
#  'm153': ['comedy', 'adventure', 'crime', 'music'],
#  'm154': ['drama', 'romance'],
#  'm155': ['thriller'],
#  'm156': ['drama'],
#  'm157': ['action', 'drama', 'war'],
#  'm158': ['drama', 'fantasy', 'horror', 'mystery', 'thriller'],
#  'm159': ['adventure', 'fantasy', 'horror'],
#  'm160': ['drama'],
#  'm161': ['comedy', 'romance'],
#  'm162': ['comedy', 'drama', 'fantasy'],
#  'm163': ['comedy', 'drama', 'romance'],
#  'm164': ['biography', 'drama', 'history', 'romance'],
#  'm165': ['biography', 'drama'],
#  'm166': ['biography', 'drama', 'sport'],
#  'm167': ['crime', 'mystery', 'romance', 'thriller'],
#  'm168': ['drama', 'romance'],
#  'm169': ['action', 'crime', 'drama', 'thriller'],
#  'm170': ['crime', 'mystery', 'thriller'],
#  'm171': ['action', 'drama', 'romance', 'western'],
#  'm172': ['comedy'],
#  'm173': ['comedy', 'thriller'],
#  'm174': ['drama', 'horror', 'thriller'],
#  'm175': ['drama'],
#  'm176': ['horror', 'sci-fi'],
#  'm177': ['comedy', 'musical'],
#  'm178': ['comedy', 'drama', 'romance'],
#  'm179': ['drama', 'mystery', 'sci-fi', 'thriller'],
#  'm180': ['action', 'western'],
#  'm181': ['short', 'drama', 'horror', 'thriller'],
#  'm182': ['drama', 'mystery', 'thriller'],
#  'm183': ['comedy', 'horror', 'thriller'],
#  'm184': ['comedy', 'horror', 'sci-fi'],
#  'm185': ['action', 'comedy', 'crime', 'romance'],
#  'm186': ['action', 'crime', 'drama', 'thriller'],
#  'm187': ['drama', 'mystery', 'romance', 'sci-fi'],
#  'm188': ['action', 'crime', 'drama', 'romance', 'thriller'],
#  'm189': ['action',
#   'adventure',
#   'fantasy',
#   'sci-fi',
#   'action',
#   'adventure',
#   'sci-fi',
#   'thriller'],
#  'm190': ['drama', 'war'],
#  'm191': ['action', 'mystery', 'sci-fi', 'thriller'],
#  'm192': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm193': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm194': ['adventure', 'comedy', 'sci-fi'],
#  'm195': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm196': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm197': ['action', 'mystery', 'sci-fi', 'thriller'],
#  'm198': ['action', 'sci-fi', 'thriller'],
#  'm199': ['adventure', 'drama', 'romance', 'sci-fi'],
#  'm200': ['action',
#   'crime',
#   'drama',
#   'fantasy',
#   'music',
#   'mystery',
#   'sci-fi',
#   'thriller'],
#  'm201': ['crime', 'horror', 'sci-fi', 'thriller'],
#  'm202': ['comedy', 'drama'],
#  'm203': ['crime', 'drama', 'thriller'],
#  'm204': ['crime', 'drama', 'thriller'],
#  'm205': ['drama', 'thriller'],
#  'm206': ['action', 'adventure', 'thriller'],
#  'm207': ['drama', 'romance'],
#  'm208': ['horror', 'romance', 'thriller'],
#  'm209': ['drama', 'horror', 'thriller'],
#  'm210': ['action', 'crime', 'fantasy', 'mystery', 'thriller'],
#  'm211': ['drama', 'sci-fi', 'thriller'],
#  'm212': ['comedy', 'fantasy', 'horror', 'thriller'],
#  'm213': ['horror', 'mystery', 'sci-fi', 'thriller'],
#  'm214': ['sci-fi', 'adventure', 'action'],
#  'm215': ['drama', 'fantasy', 'mystery', 'sci-fi', 'thriller'],
#  'm216': ['crime', 'drama', 'thriller'],
#  'm217': ['comedy', 'romance'],
#  'm218': ['drama', 'history', 'thriller'],
#  'm219': ['crime', 'mystery', 'thriller', 'western'],
#  'm220': ['action', 'drama', 'romance'],
#  'm221': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm222': ['action', 'comedy', 'horror', 'thriller'],
#  'm223': ['drama', 'crime'],
#  'm224': ['drama', 'horror', 'mystery', 'thriller'],
#  'm225': ['drama'],
#  'm226': ['action', 'horror', 'sci-fi', 'thriller'],
#  'm227': ['fantasy', 'horror', 'mystery', 'thriller'],
#  'm228': ['adventure', 'drama'],
#  'm229': ['crime', 'romance', 'thriller'],
#  'm230': ['drama', 'comedy'],
#  'm231': ['drama'],
#  'm232': ['action', 'adventure', 'drama', 'sci-fi', 'thriller'],
#  'm233': ['drama', 'mystery'],
#  'm234': ['drama', 'mystery', 'thriller'],
#  'm235': ['comedy', 'music'],
#  'm236': ['adventure', 'horror', 'sci-fi', 'thriller'],
#  'm237': ['action', 'adventure', 'sci-fi'],
#  'm238': ['drama'],
#  'm239': ['drama', 'history', 'thriller'],
#  'm240': ['comedy', 'romance'],
#  'm241': ['horror', 'romance', 'thriller', 'comedy'],
#  'm242': ['animation',
#   'adventure',
#   'drama',
#   'family',
#   'musical',
#   'animation',
#   'family'],
#  'm243': ['comedy', 'drama', 'romance'],
#  'm244': ['drama', 'comedy'],
#  'm245': ['animation', 'adventure', 'comedy', 'family'],
#  'm246': ['romance', 'comedy', 'drama'],
#  'm247': ['drama', 'war'],
#  'm248': ['action', 'thriller'],
#  'm249': ['comedy', 'drama', 'romance'],
#  'm250': ['action', 'thriller', 'crime'],
#  'm251': ['drama', 'romance', 'thriller'],
#  'm252': ['drama', 'romance'],
#  'm253': ['adventure', 'family', 'sci-fi'],
#  'm254': ['crime', 'drama', 'romance', 'thriller'],
#  'm255': ['adventure', 'romance', 'comedy', 'sci-fi'],
#  'm256': ['drama', 'mystery', 'thriller'],
#  'm257': ['mystery', 'romance', 'thriller'],
#  'm258': ['biography', 'drama'],
#  'm259': ['action',
#   'crime',
#   'fantasy',
#   'thriller',
#   'animation',
#   'crime',
#   'fantasy',
#   'action',
#   'thriller'],
#  'm260': ['action', 'adventure', 'crime', 'drama', 'sci-fi'],
#  'm261': ['action', 'crime', 'fantasy', 'thriller'],
#  'm262': ['crime', 'drama', 'thriller', 'action', 'adventure', 'crime'],
#  'm263': ['comedy', 'family'],
#  'm264': ['animation', 'adventure', 'comedy', 'crime'],
#  'm265': ['comedy', 'fantasy'],
#  'm266': ['drama', 'comedy'],
#  'm267': ['comedy', 'drama', 'fantasy', 'romance'],
#  'm268': ['drama', 'mystery'],
#  'm269': ['comedy', 'crime', 'mystery'],
#  'm270': ['crime', 'drama', 'history', 'mystery', 'thriller'],
#  'm271': ['action',
#   'fantasy',
#   'horror',
#   'thriller',
#   'action',
#   'adventure',
#   'horror'],
#  'm272': ['action', 'adventure', 'fantasy', 'horror', 'thriller'],
#  'm273': ['crime', 'horror', 'mystery', 'thriller'],
#  'm274': ['crime', 'drama', 'thriller'],
#  'm275': ['action', 'thriller'],
#  'm276': ['biography', 'crime', 'drama'],
#  'm277': ['drama', 'history', 'war'],
#  'm278': ['drama', 'romance', 'thriller'],
#  'm279': ['drama', 'romance'],
#  'm280': ['crime', 'horror'],
#  'm281': ['crime', 'drama', 'thriller'],
#  'm282': ['action', 'adventure', 'mystery', 'thriller'],
#  'm283': ['drama', 'fantasy', 'sci-fi'],
#  'm284': ['drama', 'thriller'],
#  'm285': ['comedy', 'drama', 'romance'],
#  'm286': ['comedy', 'horror'],
#  'm287': ['horror', 'comedy', 'action'],
#  'm288': ['comedy', 'romance', 'sport'],
#  'm289': ['biography', 'crime', 'drama'],
#  'm290': ['action', 'crime', 'fantasy'],
#  'm291': ['action', 'crime', 'thriller'],
#  'm292': ['drama', 'thriller'],
#  'm293': ['comedy', 'mystery', 'romance', 'thriller'],
#  'm294': ['horror', 'mystery', 'thriller'],
#  'm295': ['action', 'adventure', 'comedy', 'thriller'],
#  'm296': ['crime', 'drama', 'mystery', 'thriller'],
#  'm297': ['comedy', 'drama', 'romance'],
#  'm298': ['drama', 'mystery'],
#  'm299': ['comedy'],
#  'm300': ['action', 'adventure', 'thriller'],
#  'm301': ['crime', 'drama', 'sci-fi'],
#  'm302': ['crime', 'drama', 'thriller'],
#  'm303': ['action', 'crime', 'mystery', 'romance', 'thriller'],
#  'm304': ['drama', 'mystery', 'sci-fi', 'thriller'],
#  'm305': ['crime', 'drama'],
#  'm306': ['crime', 'mystery', 'thriller'],
#  'm307': ['crime', 'drama'],
#  'm308': ['documentary'],
#  'm309': ['action', 'comedy', 'crime'],
#  'm310': ['action'],
#  'm311': ['action', 'crime', 'fantasy', 'thriller'],
#  'm312': ['drama', 'romance', 'thriller'],
#  'm313': ['drama', 'fantasy', 'horror'],
#  'm314': ['sci-fi', 'horror'],
#  'm315': ['mystery', 'sci-fi', 'thriller'],
#  'm316': ['comedy', 'romance'],
#  'm317': ['horror', 'sci-fi'],
#  'm318': ['drama'],
#  'm319': ['action', 'horror', 'sci-fi', 'thriller'],
#  'm320': ['drama', 'war'],
#  'm321': ['action', 'crime', 'sci-fi'],
#  'm322': ['comedy', 'drama', 'fantasy'],
#  'm323': ['action', 'crime', 'thriller'],
#  'm324': ['crime', 'drama'],
#  'm325': ['action', 'crime', 'drama', 'thriller'],
#  'm326': ['drama'],
#  'm327': ['comedy'],
#  'm328': ['action', 'adventure', 'sci-fi'],
#  'm329': ['biography', 'comedy', 'drama'],
#  'm330': ['comedy'],
#  'm331': ['comedy', 'drama'],
#  'm332': ['crime', 'drama', 'mystery', 'thriller'],
#  'm333': ['action', 'drama', 'thriller'],
#  'm334': ['romance', 'drama', 'war'],
#  'm335': ['action', 'crime', 'romance', 'thriller'],
#  'm336': ['biography', 'drama', 'romance'],
#  'm337': ['animation', 'adventure', 'action', 'fantasy'],
#  'm338': ['sci-fi', 'thriller'],
#  'm339': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm340': ['adventure', 'drama', 'fantasy'],
#  'm341': ['horror', 'thriller'],
#  'm342': ['drama', 'music', 'romance'],
#  'm343': ['action', 'crime', 'drama', 'sci-fi', 'thriller'],
#  'm344': ['comedy', 'fantasy', 'drama', 'romance'],
#  'm345': ['action', 'adventure', 'sci-fi', 'fantasy'],
#  'm346': ['adventure', 'sci-fi'],
#  'm347': ['crime', 'drama', 'thriller'],
#  'm348': ['crime', 'drama', 'mystery', 'thriller'],
#  'm349': ['horror', 'thriller'],
#  'm350': ['horror', 'thriller'],
#  'm351': ['action', 'adventure', 'thriller'],
#  'm352': ['comedy', 'drama', 'romance'],
#  'm353': ['drama'],
#  'm354': ['short'],
#  'm355': ['comedy', 'crime', 'mystery'],
#  'm356': ['action', 'adventure', 'comedy', 'music'],
#  'm357': ['action', 'crime', 'thriller'],
#  'm358': ['crime', 'drama', 'sci-fi', 'thriller'],
#  'm359': ['horror'],
#  'm360': ['comedy', 'horror', 'thriller'],
#  'm361': ['horror', 'thriller'],
#  'm362': ['horror'],
#  'm363': ['comedy', 'drama', 'sport'],
#  'm364': ['biography', 'drama', 'history'],
#  'm365': ['drama', 'romance', 'sci-fi', 'thriller'],
#  'm366': ['action', 'adventure', 'crime', 'thriller'],
#  'm367': ['action', 'crime', 'drama', 'thriller'],
#  'm368': ['drama'],
#  'm369': ['crime', 'drama', 'thriller'],
#  'm370': ['biography', 'drama'],
#  'm371': ['action', 'crime', 'thriller'],
#  'm372': ['crime', 'drama', 'thriller'],
#  'm373': ['drama'],
#  'm374': ['drama'],
#  'm375': ['comedy', 'crime', 'romance', 'thriller'],
#  'm376': ['drama', 'romance', 'western'],
#  'm377': ['action', 'crime', 'drama', 'thriller'],
#  'm378': ['horror', 'thriller'],
#  'm379': ['horror', 'thriller'],
#  'm380': ['comedy', 'drama', 'romance'],
#  'm381': ['crime', 'thriller'],
#  'm382': ['comedy'],
#  'm383': ['comedy', 'crime'],
#  'm384': ['crime', 'drama', 'fantasy', 'thriller'],
#  'm385': ['horror', 'mystery', 'thriller'],
#  'm386': ['comedy', 'drama'],
#  'm387': ['thriller'],
#  'm388': ['fantasy', 'sci-fi', 'action'],
#  'm389': ['action', 'crime', 'drama', 'thriller'],
#  'm390': ['adventure', 'drama', 'history', 'thriller', 'war'],
#  'm391': ['horror', 'mystery', 'thriller'],
#  'm392': ['action', 'horror', 'thriller'],
#  'm393': ['horror'],
#  'm394': ['action',
#   'adventure',
#   'comedy',
#   'action',
#   'adventure',
#   'comedy',
#   'crime'],
#  'm395': ['comedy', 'drama', 'fantasy', 'romance'],
#  'm396': ['horror'],
#  'm397': ['drama'],
#  'm398': ['crime', 'drama', 'mystery', 'thriller'],
#  'm399': ['drama', 'fantasy'],
#  'm400': ['horror', 'mystery', 'thriller'],
#  'm401': ['drama', 'horror', 'mystery', 'thriller'],
#  'm402': ['drama', 'fantasy', 'romance'],
#  'm403': ['thriller'],
#  'm404': ['thriller'],
#  'm405': ['thriller'],
#  'm406': ['drama', 'music', 'romance'],
#  'm407': ['thriller', 'mystery'],
#  'm408': ['comedy', 'drama', 'romance', 'sport'],
#  'm409': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm410': ['action',
#   'adventure',
#   'sci-fi',
#   'thriller',
#   'action',
#   'adventure',
#   'animation',
#   'horror',
#   'sci-fi',
#   'thriller'],
#  'm411': ['action',
#   'adventure',
#   'family',
#   'sci-fi',
#   'action',
#   'adventure',
#   'fantasy',
#   'sci-fi'],
#  'm412': ['horror', 'thriller'],
#  'm413': ['comedy', 'drama', 'mystery', 'sci-fi', 'thriller'],
#  'm414': ['adventure', 'drama', 'romance'],
#  'm415': ['mystery', 'romance', 'thriller'],
#  'm416': ['drama'],
#  'm417': ['biography', 'drama', 'history', 'war'],
#  'm418': ['action', 'comedy', 'horror', 'thriller'],
#  'm419': ['crime', 'thriller'],
#  'm420': ['action', 'adventure', 'war'],
#  'm421': ['adventure', 'horror', 'mystery', 'sci-fi', 'thriller'],
#  'm422': ['crime', 'thriller'],
#  'm423': ['drama', 'mystery', 'romance', 'western'],
#  'm424': ['fantasy', 'horror', 'mystery', 'thriller'],
#  'm425': ['drama', 'romance'],
#  'm426': ['drama', 'horror', 'thriller', 'romance'],
#  'm427': ['drama', 'romance', 'sport'],
#  'm428': ['drama'],
#  'm429': ['action', 'adventure', 'drama', 'history'],
#  'm430': ['action', 'adventure', 'crime', 'horror', 'thriller'],
#  'm431': ['crime', 'thriller'],
#  'm432': ['biography', 'comedy', 'drama'],
#  'm433': ['action', 'adventure', 'adventure', 'adventure', 'sci-fi'],
#  'm434': ['horror', 'mystery', 'sci-fi'],
#  'm435': ['drama', 'fantasy', 'mystery', 'romance'],
#  'm436': ['crime', 'drama', 'mystery', 'thriller'],
#  'm437': ['action', 'crime', 'drama', 'thriller'],
#  'm438': ['drama'],
#  'm439': ['biography', 'crime', 'drama', 'thriller'],
#  'm440': ['drama', 'horror', 'sci-fi'],
#  'm441': ['thriller'],
#  'm442': ['action', 'adventure', 'thriller'],
#  'm443': ['action', 'adventure', 'thriller'],
#  'm444': ['comedy', 'romance', 'drama'],
#  'm445': ['adventure', 'comedy'],
#  'm446': ['biography', 'drama', 'history', 'romance'],
#  'm447': ['sci-fi'],
#  'm448': ['drama', 'mystery', 'thriller'],
#  'm449': ['crime', 'drama', 'mystery'],
#  'm450': ['comedy', 'drama', 'family', 'romance'],
#  'm451': ['comedy', 'drama', 'family', 'romance'],
#  'm452': ['comedy', 'romance'],
#  'm453': ['drama', 'music'],
#  'm454': ['action', 'crime', 'drama', 'romance', 'thriller'],
#  'm455': ['drama', 'romance'],
#  'm456': ['action', 'crime', 'drama', 'mystery', 'thriller'],
#  'm457': ['action', 'adventure', 'animation', 'sci-fi'],
#  'm458': ['comedy', 'drama', 'romance'],
#  'm459': ['animation', 'family', 'fantasy', 'musical'],
#  'm460': ['fantasy', 'horror', 'thriller'],
#  'm461': ['fantasy', 'horror', 'thriller'],
#  'm462': ['comedy', 'romance'],
#  'm463': ['drama'],
#  'm464': ['comedy', 'romance'],
#  'm465': ['crime', 'drama', 'romance'],
#  'm466': ['fantasy', 'horror'],
#  'm467': ['comedy', 'crime', 'romance', 'thriller'],
#  'm468': ['action', 'drama', 'romance', 'war'],
#  'm469': ['comedy', 'drama', 'fantasy', 'romance'],
#  'm470': ['action', 'horror', 'thriller'],
#  'm471': ['drama'],
#  'm472': ['action', 'sci-fi', 'thriller'],
#  'm473': ['action',
#   'adventure',
#   'sci-fi',
#   'thriller',
#   'animation',
#   'action',
#   'adventure',
#   'sci-fi'],
#  'm474': ['action', 'drama', 'war'],
#  'm475': ['thriller'],
#  'm476': ['drama'],
#  'm477': ['action', 'adventure', 'crime', 'drama', 'sport', 'thriller'],
#  'm478': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm479': ['comedy', 'romance'],
#  'm480': ['adventure', 'comedy', 'family', 'fantasy', 'romance'],
#  'm481': ['comedy'],
#  'm482': ['drama', 'horror', 'mystery', 'thriller', 'thriller'],
#  'm483': ['drama', 'horror', 'thriller'],
#  'm484': ['fantasy', 'horror'],
#  'm485': ['horror', 'mystery', 'thriller'],
#  'm486': ['short', 'adventure', 'drama', 'romance'],
#  'm487': ['drama'],
#  'm488': ['documentary'],
#  'm489': ['action', 'adventure', 'fantasy', 'sci-fi'],
#  'm490': ['comedy', 'musical'],
#  'm491': ['drama', 'romance', 'sport'],
#  'm492': ['animation',
#   'comedy',
#   'crime',
#   'family',
#   'fantasy',
#   'mystery',
#   'animation',
#   'adventure',
#   'action',
#   'fantasy'],
#  'm493': ['drama', 'romance'],
#  'm494': ['action', 'crime', 'thriller'],
#  'm495': ['crime', 'drama'],
#  'm496': ['action', 'comedy', 'crime', 'thriller'],
#  'm497': ['action', 'comedy', 'thriller', 'crime'],
#  'm498': ['comedy', 'romance'],
#  'm499': ['comedy', 'romance', 'drama'],
#  'm500': ['drama', 'history'],
#  'm501': ['crime', 'drama', 'mystery', 'thriller'],
#  'm502': ['action', 'drama', 'history', 'war'],
#  'm503': ['comedy', 'drama', 'romance'],
#  'm504': ['biography', 'drama', 'history', 'war'],
#  'm505': ['horror', 'mystery', 'thriller'],
#  'm506': ['horror', 'mystery', 'thriller'],
#  'm507': ['crime', 'horror', 'mystery', 'thriller'],
#  'm508': ['action', 'drama'],
#  'm509': ['adventure', 'drama', 'western'],
#  'm510': ['drama', 'horror', 'thriller'],
#  'm511': ['comedy', 'drama', 'romance'],
#  'm512': ['comedy', 'crime', 'drama', 'thriller'],
#  'm513': ['drama', 'romance'],
#  'm514': ['horror', 'mystery', 'thriller'],
#  'm515': ['adventure', 'drama', 'horror', 'mystery', 'thriller'],
#  'm516': ['comedy', 'crime', 'music'],
#  'm517': ['fantasy', 'mystery', 'thriller'],
#  'm518': ['drama'],
#  'm519': ['comedy', 'drama'],
#  'm520': ['drama', 'mystery', 'romance', 'thriller'],
#  'm521': ['action', 'drama', 'sci-fi'],
#  'm522': ['comedy'],
#  'm523': ['comedy', 'romance'],
#  'm524': ['drama'],
#  'm525': ['animation', 'comedy', 'musical'],
#  'm526': ['action', 'sci-fi'],
#  'm527': ['thriller'],
#  'm528': ['drama', 'horror', 'mystery', 'sci-fi', 'thriller'],
#  'm529': ['action', 'adventure', 'fantasy', 'sci-fi'],
#  'm530': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm531': ['adventure', 'fantasy', 'mystery', 'sci-fi'],
#  'm532': ['comedy', 'drama'],
#  'm533': ['comedy', 'drama'],
#  'm534': ['comedy', 'drama'],
#  'm535': ['action', 'adventure', 'crime'],
#  'm536': ['comedy', 'drama'],
#  'm537': ['comedy', 'drama'],
#  'm538': ['comedy', 'crime'],
#  'm539': ['drama', 'film-noir'],
#  'm540': ['action', 'adventure', 'sci-fi'],
#  'm541': ['action', 'adventure', 'comedy', 'fantasy', 'sci-fi'],
#  'm542': ['action', 'adventure', 'fantasy', 'romance', 'sci-fi'],
#  'm543': ['action', 'adventure', 'family', 'fantasy', 'sci-fi'],
#  'm544': ['action', 'family', 'sci-fi'],
#  'm545': ['drama'],
#  'm546': ['drama', 'film-noir'],
#  'm547': ['action', 'sci-fi', 'thriller'],
#  'm548': ['drama', 'music', 'war'],
#  'm549': ['action', 'sci-fi', 'thriller'],
#  'm550': ['drama', 'mystery', 'thriller'],
#  'm551': ['horror', 'thriller', 'mystery'],
#  'm552': ['crime', 'drama', 'mystery', 'thriller'],
#  'm553': ['crime', 'drama'],
#  'm554': ['horror', 'mystery', 'thriller'],
#  'm555': ['drama'],
#  'm556': ['crime', 'horror', 'mystery', 'sci-fi', 'thriller'],
#  'm557': ['drama', 'fantasy', 'horror', 'sci-fi', 'thriller'],
#  'm558': ['film-noir', 'mystery', 'thriller'],
#  'm559': ['adventure', 'drama', 'romance', 'thriller'],
#  'm560': ['drama'],
#  'm561': ['adventure', 'drama', 'romance'],
#  'm562': ['comedy'],
#  'm563': ['drama', 'horror', 'mystery', 'thriller'],
#  'm564': ['crime', 'drama', 'romance', 'thriller'],
#  'm565': ['drama', 'romance', 'war'],
#  'm566': ['biography', 'drama', 'war'],
#  'm567': ['drama', 'romance'],
#  'm568': ['comedy', 'crime', 'drama'],
#  'm569': ['comedy', 'crime', 'drama', 'mystery', 'romance'],
#  'm570': ['action', 'adventure', 'comedy', 'drama', 'war'],
#  'm571': ['drama', 'mystery', 'sci-fi', 'thriller'],
#  'm572': ['action', 'thriller', 'crime'],
#  'm573': ['comedy', 'crime', 'romance'],
#  'm574': ['drama', 'history', 'romance'],
#  'm575': ['comedy', 'musical', 'mystery', 'romance'],
#  'm576': ['action', 'drama', 'history', 'romance', 'western'],
#  'm577': ['action', 'adventure', 'thriller'],
#  'm578': ['drama'],
#  'm579': ['animation', 'adventure', 'comedy', 'family', 'fantasy'],
#  'm580': ['fantasy'],
#  'm581': ['crime', 'drama', 'thriller'],
#  'm582': ['crime', 'drama'],
#  'm583': ['action', 'adventure', 'sci-fi', 'thriller'],
#  'm584': ['action', 'adventure', 'sci-fi', 'thriller', 'sci-fi'],
#  'm585': ['action', 'thriller'],
#  'm586': ['crime', 'romance', 'thriller'],
#  'm587': ['mystery', 'sci-fi', 'thriller'],
#  'm588': ['drama'],
#  'm589': ['crime', 'drama', 'thriller'],
#  'm590': ['drama', 'fantasy', 'mystery', 'thriller'],
#  'm591': ['drama', 'western'],
#  'm592': ['crime', 'mystery', 'thriller'],
#  'm593': ['drama'],
#  'm594': ['crime', 'mystery', 'romance', 'thriller'],
#  'm595': ['comedy', 'crime', 'thriller'],
#  'm596': ['drama'],
#  'm597': ['action', 'crime', 'sci-fi', 'thriller'],
#  'm598': ['comedy', 'drama'],
#  'm599': ['crime', 'drama'],
#  'm600': ['comedy', 'fantasy', 'horror'],
#  'm601': ['drama', 'horror', 'mystery', 'thriller'],
#  'm602': ['comedy', 'fantasy', 'romance'],
#  'm603': ['documentary', 'short'],
#  'm604': ['drama', 'thriller'],
#  'm605': ['comedy'],
#  'm606': ['crime', 'mystery', 'thriller'],
#  'm607': ['action', 'western', 'comedy', 'sci-fi'],
#  'm608': ['action', 'adventure', 'drama', 'fantasy', 'romance'],
#  'm609': ['drama', 'romance', 'thriller'],
#  'm610': ['adventure', 'family', 'fantasy', 'musical'],
#  'm611': ['action', 'adventure', 'thriller'],
#  'm612': ['action', 'crime', 'fantasy', 'mystery', 'sci-fi', 'thriller'],
#  'm613': ['action', 'adventure', 'crime'],
#  'm614': ['action', 'sci-fi'],
#  'm615': ['comedy', 'sci-fi'],
#  'm616': ['action', 'adventure', 'drama', 'history', 'war']}

# %%
# read in movie dialog
with open('/Users/markespina/Downloads/movie-dialogs-corpus/movie_titles_metadata.txt', encoding='ISO-8859-1') as text:
    data = []
    data.append(text.read())


raw_text = data[0]

# %%
# delete non-conventional separator
text = raw_text.replace('+++$+++', '')


flag_year = r'm\d+ \d+|\w+'



movie_data = re.findall(flag_year, text)

# look at metadata
print(movie_data[:500])
# Out:
# ['m0', '10', 'things', 'i', 'hate', 'about', 'you', '1999', '6', '90', '62847', 'comedy', 'romance', 'm1', '1492', 'conquest', 'of', 'paradise', '1992', '6', '20', '10421', 'adventure', 'biography', 'drama', 'history', 'm2', '15', 'minutes', '2001', '6', '10', '25854', 'action', 'crime', 'drama', 'thriller', 'm3', '2001', 'a', 'space', 'odyssey', '1968', '8', '40', '163227', 'adventure', 'mystery', 'sci', 'fi', 'm4', '48', 'hrs', '1982', '6', '90', '22289', 'action', 'comedy', 'crime', 'drama', 'thriller', 'm5', 'the', 'fifth', 'element', '1997', '7', '50', '133756', 'action', 'adventure', 'romance', 'sci', 'fi', 'thriller', 'm6', '8mm', '1999', '6', '30', '48212', 'crime', 'mystery', 'thriller', 'm7', 'a', 'nightmare', 'on', 'elm', 'street', '4', 'the', 'dream', 'master', '1988', '5', '20', '13590', 'fantasy', 'horror', 'thriller', 'm8', 'a', 'nightmare', 'on', 'elm', 'street', 'the', 'dream', 'child', '1989', '4', '70', '11092', 'fantasy', 'horror', 'thriller', 'm9', 'the', 'atomic', 'submarine', '1959', '4', '90', '513', 'sci', 'fi', 'thriller', 'm10', 'affliction', '1997', '6', '90', '7252', 'drama', 'mystery', 'thriller', 'm11', 'air', 'force', 'one', '1997', '6', '30', '61978', 'action', 'drama', 'thriller', 'm12', 'airplane', 'ii', 'the', 'sequel', '1982', '5', '80', '15210', 'comedy', 'romance', 'sci', 'fi', 'm13', 'airplane', '1980', '7', '80', '57692', 'comedy', 'romance', 'm14', 'alien', 'nation', '1988', '6', '10', '5590', 'crime', 'drama', 'sci', 'fi', 'thriller', 'm15', 'aliens', '1986', '8', '50', '173518', 'action', 'sci', 'fi', 'thriller', 'm16', 'amadeus', '1984', '8', '40', '99138', 'biography', 'drama', 'music', 'm17', 'an', 'american', 'werewolf', 'in', 'london', '1981', '7', '50', '24443', 'horror', 'romance', 'm18', 'american', 'madness', '1932', '7', '40', '702', 'drama', 'm19', 'american', 'outlaws', '2001', '5', '70', '7425', 'action', 'western', 'm20', 'american', 'psycho', '2000', '7', '40', '101357', 'drama', 'thriller', 'm21', 'antitrust', '2001', '6', '00', '16453', 'drama', 'thriller', 'm22', 'austin', 'powers', 'international', 'man', 'of', 'mystery', '1997', '7', '10', '75240', 'action', 'adventure', 'comedy', 'crime', 'm23', 'the', 'avengers', '1998', '3', '40', '21519', 'action', 'adventure', 'thriller', 'm24', 'bachelor', 'party', '1984', '5', '90', '14050', 'comedy', 'romance', 'm25', 'backdraft', '1991', '6', '60', '28541', 'action', 'crime', 'drama', 'mystery', 'thriller', 'm26', 'bad', 'lieutenant', '1992', '6', '90', '13908', 'crime', 'drama', 'm27', 'bamboozled', '2000', '6', '30', '5995', 'comedy', 'drama', 'music', 'm28', 'barry', 'lyndon', '1975', '8', '10', '40622', 'drama', 'romance', 'war', 'm29', 'basic', '2003', '6', '30', '26295', 'crime', 'drama', 'mystery', 'thriller', 'm30', 'big', 'fish', '2003', '8', '10', '144264', 'adventure', 'drama', 'fantasy', 'm31', 'birthday', 'girl', '2001', '6', '00', '13497', 'comedy', 'crime', 'romance', 'thriller', 'm32', 'black', 'snake', 'moan', '2006', '7', '10', '28509', 'drama', 'm33', 'black', 'rain', '1989', 'I', '6', '40', '16249', 'action', 'crime', 'drama', 'thriller', 'm34', 'blade', 'runner', '1982', '8', '30', '188735', 'drama', 'sci', 'fi', 'thriller', 'm35', 'blast', 'from', 'the', 'past', '1999', '6', '40', '23489', 'comedy', 'drama', 'romance', 'm36', 'blue', 'velvet', '1986', '7', '80', '54576', 'crime', 'mystery', 'thriller', 'm37', 'the', 'boondock', 'saints', '1999', '7', '80', '87895', 'action', 'crime', 'drama', 'thriller', 'm38', 'bottle', 'rocket', '1996', '7', '20', '22303', 'comedy', 'crime', 'm39', 'the', 'bourne', 'supremacy', '2004', '7', '60', '106349', 'action', 'adventure', 'mystery', 'thriller', 'm40', 'braveheart', '1995', '8', '40', '245652', 'action', 'biography', 'drama', 'history', 'war', 'm41', 'the', 'butterfly', 'effect', '2004', '7', '80', '104917', 'drama', 'mystery', 'sci', 'fi', 'thriller', 'm42', 'casablanca', '1942', '8', '80', '170874', 'drama', 'romance', 'war', 'm43', 'cast', 'away', '2000',  ...

# %% [markdown]
# ## Messy formatting
#
# Titles precede release year, let's extract years values and use them to find and parse metadata for title extraction

# %%
years =[]
for item in movie_data:
    if item.isdigit() and len(item) ==4:
        years.append(int(item))

# initialize dataframe of years for easy filtering
years_df = pd.Series(years).reset_index()
years_df.columns = ['index', 'year']



# filter for integers for existing years
years = list(years_df[(years_df.year>=1900) & (years_df.year<=2018)].year.unique())
years= [str(x) for x in years]


# extract movie titles
titles = []
for i, item in enumerate(movie_data):
    if item.startswith('m') and item[-1].isdigit():
        start_idx = i
        for idx, elem in enumerate(movie_data[start_idx+1:]):
            if elem in years:
                end_idx = i+idx+1

                titles.append(movie_data[start_idx:end_idx])
                break
                
# Check etracted text
print(titles[:5])
# Out:
# [['m0', '10', 'things', 'i', 'hate', 'about', 'you'], ['m1', '1492', 'conquest', 'of', 'paradise'], ['m2', '15', 'minutes'], ['m3'], ['m4', '48', 'hrs']]

# %%
movie_titles = [" ".join(t[1:]) for t in  titles]

#look at movies
print(movie_titles)
# Out:
# ['10 things i hate about you', '1492 conquest of paradise', '15 minutes', '', '48 hrs', 'the fifth element', '8mm', 'a nightmare on elm street 4 the dream master', 'a nightmare on elm street the dream child', 'the atomic submarine', 'affliction', 'air force one', 'airplane ii the sequel', 'airplane', 'alien nation', 'aliens', 'amadeus', 'an american werewolf in london', 'american madness', 'american outlaws', 'american psycho', 'antitrust', 'austin powers international man of mystery', 'the avengers', 'bachelor party', 'backdraft', 'bad lieutenant', 'bamboozled', 'barry lyndon', 'basic', 'big fish', 'birthday girl', 'black snake moan', 'black rain', 'blade runner', 'blast from the past', 'blue velvet', 'the boondock saints', 'bottle rocket', 'the bourne supremacy', 'braveheart', 'the butterfly effect', 'casablanca', 'cast away', 'the cider house rules', 'confidence', 'croupier', 'dark star', 'dark angel', 'detroit rock city', 'donnie darko', 'drop dead gorgeous', 'duck soup', 'the elephant man', 'erik the viking', 'eternal sunshine of the spotless mind', 'even cowgirls get the blues', 'event horizon', 'fantastic four', 'fast times at ridgemont high', 'fear and loathing in las vegas', 'feast', 'frances', 'frankenstein', 'friday the 13th', 'from dusk till dawn', 'g i jane', 'godzilla', 'galaxy quest', 'george washington', 'get shorty', 'ghost ship', 'ghost world', 'the ghost and the darkness', 'ghostbusters ii', 'ghostbusters', 'gladiator', 'the graduate', 'grand hotel', 'the grifters', 'halloween h20 20 years later', 'halloween the curse of michael myers', 'happy birthday wanda june', 'hardcore', 'harold and maude', 'hellbound hellraiser ii', 'hellboy', 'hellraiser', 'high fidelity', 'highlander', 'his girl friday', 'hope and glory', 'house of 1000 corpses', 'human nature', 'the hustler', 'i am legend', 'invaders from mars', 'independence day', 'indiana jones and the last crusade', 'indiana jones and the temple of doom', 'innerspace', 'the insider', 'intolerable cruelty', 'it happened one night', 'jfk', 'jackie brown', 'jacob s ladder', 'jason x', 'jaws', 'juno', 'kalifornia', 'kids', 'knight moves', 'krull', 'léon', 'labor of love', 'leaving las vegas', 'legally blonde', 'legend', 'life as a house', 'the life of david gale', 'little nicky', 'logan s run', 'lost highway', 'lost horizon', 'men in black', 'minority report', 'made', 'malcolm x', 'man on fire', 'marty', 'mash', 'meet john doe', 'metro', 'metropolis', 'mighty morphin power rangers', 'mobsters', 'monkeybone', 'my mother dreams the satan s disciples in new york', 'mr smith goes to washington', 'mr deeds goes to town', 'mumford', 'the mummy', 'mystery men', 'napoleon', 'next friday', 'nick of time', 'the night of the hunter', 'a nightmare on elm street', 'ninotchka', 'nixon', 'no country for old men', 'nurse betty', 'o brother where art thou', 'an officer and a gentleman', 'panic room', 'panther', 'the patriot', 'pet sematary', 'pirates of the caribbean', 'plastic man', 'platinum blonde', 'pleasantville', 'punch drunk love', 'quills', 'rko 281', 'raging bull', 'rear window', 'rebel without a cause', 'reindeer games', 'reservoir dogs', 'roughshod', 'scary movie 2', 'serial mom', 'the seventh victim', 'sex lies and videotape', 'shivers', 'shock treatment', 'sideways', 'signs', 'silverado', 'simone', 'the sixth sense', 'slash', 'slither', 'smokey and the bandit', 'smokin aces', 'solaris', 'someone to watch over me', 'spider man', 'stalag 17', 'star trek generations', 'star trek iii the search for spock', 'star trek the wrath of khan', 'star trek iv the voyage home', 'star trek insurrection', 'star trek first contact', 'star trek vi the undiscovered country', 'star trek nemesis', 'starman', 'strange days', 'suspect zero', 'swingers', 'the godfather', 'the talented mr ripley', 'taxi driver', 'the rock', 'the majestic', 'the birds', 'the body snatcher', 'the crow salvation', 'the day the earth stood still', 'the lost boys', 'the thing', 'the time machine', 'the jacket', 'the ...

# %%
# fix entry, title contains year, was ignoring by year flag
movie_titles[3] = '2001 a space odyssey'

# intialize dataframe of movies
df = pd.DataFrame(movie_titles, columns=['title'])

print("{} movies in corpus".format(df.shape[0]))

# add metadata
df['genre'] = genre_lists
df['ids'] = movie_ids

#reorder columns
df = df[['ids', 'title', 'genre']]

# look at data
df.head()
# Out:
# 617 movies in corpus
#   ids                       title                                     genre
# 0  m0  10 things i hate about you                         [comedy, romance]
# 1  m1   1492 conquest of paradise    [adventure, biography, drama, history]
# 2  m2                  15 minutes          [action, crime, drama, thriller]
# 3  m3        2001 a space odyssey              [adventure, mystery, sci-fi]
# 4  m4                      48 hrs  [action, comedy, crime, drama, thriller]

# %%
# read in dialog
dialogue =[]
with open('/Users/markespina/Downloads/movie-dialogs-corpus/movie_lines.txt', encoding='ISO-8859-1') as f:
    dialogue.append(f.read())

dialogue = dialogue[0]


# Look at text
dialogue[:1000]
# Out:
# 'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\nL1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\nL985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\nL984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\nL925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let\'s go.\nL924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\nL872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you\'re gonna need to learn how to lie.\nL871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\nL870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\nL869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\nL868 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The "real you".\nL867 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What good stuff?\nL866 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I figured you\'d get to the good stuff eventually.\nL865 +++$+++ u'

# %%
dialogue = dialogue.replace('+++$+++', '')

unstructured_text = " ".join(dialogue.split('\n'))

print("Unstructered text: \n\n{}".format(unstructured_text[:500]))

print("\ncorpus is {} characters long".format(len(unstructured_text)))
# Out:
# Unstructered text:
#
# L1045  u0  m0  BIANCA  They do not! L1044  u2  m0  CAMERON  They do to! L985  u0  m0  BIANCA  I hope so. L984  u2  m0  CAMERON  She okay? L925  u0  m0  BIANCA  Let's go. L924  u2  m0  CAMERON  Wow L872  u0  m0  BIANCA  Okay -- you're gonna need to learn how to lie. L871  u2  m0  CAMERON  No L870  u0  m0  BIANCA  I'm kidding.  You know how sometimes you just become this "persona"?  And you don't know how to quit? L869  u0  m0  BIANCA  Like my fear of wearing pastels? L868  u2  m0  CAMERON  The "r
#
# corpus is 26109956 characters long

# %%
#clean text of unnecessary ids
unnecessary_chars = 'u\d+  m\d+  '
other_char_flag = 'u\d+  '
dialogue = re.sub(unnecessary_chars, '', dialogue)
clean_lines = dialogue.split('\nL')
# get rid of first 'Lid char'
clean_lines[0] = clean_lines[0][1:]

# %%
dialog_order =[]
with open('/Users/markespina/Downloads/movie-dialogs-corpus/movie_conversations.txt', encoding='ISO-8859-1') as f:
    dialog_order.append(f.read())

dialog_order = dialog_order[0]





dialog_order = dialog_order.replace('+++$+++', '')
structure = " ".join(dialog_order.split('\n'))





other_chars = r"u\d+  u\d+  "
convo_order = re.sub(other_chars, "", structure)

# %%
convo_orders = re.findall(flag_brackets, convo_order)




convo_order_ls = [literal_eval(order) for order in convo_orders]

# %%
convo_order_ls[:1000]
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366'],
#  ['L367', 'L368'],
#  ['L401', 'L402', 'L403'],
#  ['L404', 'L405', 'L406', 'L407'],
#  ['L575', 'L576'],
#  ['L577', 'L578'],
#  ['L662', 'L663'],
#  ['L693', 'L694', 'L695'],
#  ['L696', 'L697', 'L698', 'L699'],
#  ['L860', 'L861'],
#  ['L862', 'L863', 'L864', 'L865'],
#  ['L866', 'L867', 'L868', 'L869'],
#  ['L870', 'L871', 'L872'],
#  ['L924', 'L925'],
#  ['L984', 'L985'],
#  ['L1044', 'L1045'],
#  ['L49', 'L50', 'L51'],
#  ['L571', 'L572', 'L573'],
#  ['L579', 'L580'],
#  ['L595', 'L596', 'L597'],
#  ['L598', 'L599', 'L600'],
#  ['L659', 'L660'],
#  ['L952', 'L953'],
#  ['L394', 'L395'],
#  ['L396', 'L397'],
#  ['L589', 'L590', 'L591'],
#  ['L592', 'L593'],
#  ['L756', 'L757', 'L758'],
#  ['L759', 'L760'],
#  ['L164', 'L165'],
#  ['L319', 'L320'],
#  ['L441', 'L442', 'L443', 'L444', 'L445'],
#  ['L525', 'L526', 'L527'],
#  ['L529', 'L530'],
#  ['L531', 'L532', 'L533'],
#  ['L542', 'L543'],
#  ['L601', 'L602'],
#  ['L655', 'L656'],
#  ['L889', 'L890', 'L891', 'L892'],
#  ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900'],
#  ['L901', 'L902', 'L903'],
#  ['L904', 'L905', 'L906', 'L907', 'L908'],
#  ['L909', 'L910', 'L911', 'L912', 'L913', 'L914'],
#  ['L982', 'L983'],
#  ['L1007', 'L1008', 'L1009', 'L1010', 'L1011'],
#  ['L1021', 'L1022'],
#  ['L1051', 'L1052'],
#  ['L179', 'L180', 'L181', 'L182', 'L183'],
#  ['L189', 'L190'],
#  ['L517', 'L518', 'L519', 'L520', 'L521'],
#  ['L523', 'L524'],
#  ['L536', 'L537'],
#  ['L538', 'L539', 'L540'],
#  ['L544', 'L545', 'L546'],
#  ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884'],
#  ['L922', 'L923'],
#  ['L458', 'L459', 'L460', 'L461', 'L462', 'L463'],
#  ['L63', 'L64', 'L65'],
#  ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74'],
#  ['L77', 'L78'],
#  ['L87', 'L88', 'L89', 'L90', 'L91', 'L92'],
#  ['L139', 'L140', 'L141', 'L142'],
#  ['L143', 'L144', 'L145', 'L146', 'L147'],
#  ['L157', 'L158', 'L159'],
#  ['L210', 'L211'],
#  ['L212', 'L213'],
#  ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222'],
#  ['L223', 'L224', 'L225'],
#  ['L244', 'L245'],
#  ['L388', 'L389', 'L390', 'L391'],
#  ['L416', 'L417', 'L418', 'L419'],
#  ['L424', 'L425'],
#  ['L432', 'L433'],
#  ['L499', 'L500'],
#  ['L583', 'L584', 'L585', 'L586'],
#  ['L778', 'L779'],
#  ['L385', 'L386'],
#  ['L411', 'L412'],
#  ['L426', 'L427'],
#  ['L430', 'L431'],
#  ['L619', 'L620'],
#  ['L621', 'L622'],
#  ['L623', 'L624', 'L625'],
#  ['L725', 'L726'],
#  ['L740', 'L741'],
#  ['L743', 'L744', 'L745'],
#  ['L780', 'L781'],
#  ['L148', 'L149', 'L150'],
#  ['L335', 'L336'],
#  ['L554', 'L555', 'L556'],
#  ['L557', 'L558'],
#  ['L285', 'L286'],
#  ['L287', 'L288', 'L289', 'L290', 'L291', 'L292'],
#  ['L294', 'L295', 'L296', 'L297'],
#  ['L298', 'L299'],
#  ['L300', 'L301'],
#  ['L349', 'L350', 'L351', 'L352'],
#  ['L354', 'L355', 'L356', 'L357', 'L358'],
#  ['L605', 'L606'],
#  ['L607', 'L608', 'L609'],
#  ['L747', 'L748'],
#  ['L231', 'L232', 'L233', 'L234', 'L235', 'L236'],
#  ['L238', 'L239', 'L240'],
#  ['L502', 'L503', 'L504', 'L505'],
#  ['L508', 'L509'],
#  ['L123', 'L124', 'L125', 'L126', 'L127', 'L128'],
#  ['L129', 'L130'],
#  ['L131', 'L132'],
#  ['L133', 'L134'],
#  ['L151', 'L152'],
#  ['L247', 'L248', 'L249', 'L250', 'L251'],
#  ['L252', 'L253', 'L254'],
#  ['L447', 'L448'],
#  ['L490', 'L491'],
#  ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'],
#  ['L750', 'L751', 'L752', 'L753', 'L754', 'L755'],
#  ['L946', 'L947', 'L948', 'L949'],
#  ['L304', 'L305', 'L306', 'L307'],
#  ['L309', 'L310'],
#  ['L311', 'L312', 'L313'],
#  ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328'],
#  ['L330', 'L331', 'L332'],
#  ['L333', 'L334'],
#  ['L473', 'L474'],
#  ['L475', 'L476', 'L477'],
#  ['L481', 'L482', 'L483'],
#  ['L564', 'L565', 'L566', 'L567'],
#  ['L610', 'L611'],
#  ['L612', 'L613', 'L614', 'L615', 'L616'],
#  ['L626',
#   'L627',
#   'L628',
#   'L629',
#   'L630',
#   'L631',
#   'L632',
#   'L633',
#   'L634',
#   'L635',
#   'L636'],
#  ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646'],
#  ['L650', 'L651'],
#  ['L668', 'L669'],
#  ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676'],
#  ['L677', 'L678', 'L679'],
#  ['L680', 'L681', 'L682'],
#  ['L683', 'L684'],
#  ['L686', 'L687', 'L688', 'L689', 'L690'],
#  ['L764', 'L765', 'L766', 'L767', 'L768'],
#  ['L769', 'L770', 'L771', 'L772', 'L773', 'L774'],
#  ['L798', 'L799'],
#  ['L800', 'L801', 'L802'],
#  ['L803', 'L804', 'L805', 'L806'],
#  ['L808', 'L809', 'L810', 'L811', 'L812'],
#  ['L813',
#   'L814',
#   'L815',
#   'L816',
#   'L817',
#   'L818',
#   'L819',
#   'L820',
#   'L821',
#   'L822',
#   'L823'],
#  ['L824', 'L825'],
#  ['L828', 'L829', 'L830', 'L831', 'L832'],
#  ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841'],
#  ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848'],
#  ['L852', 'L853', 'L854', 'L855', 'L856', 'L857'],
#  ['L936', 'L937', 'L938', 'L939', 'L940'],
#  ['L957', 'L958', 'L959'],
#  ['L960', 'L961'],
#  ['L973', 'L974', 'L975', 'L976', 'L977'],
#  ['L1031', 'L1032'],
#  ['L1033', 'L1034', 'L1035'],
#  ['L1040', 'L1041', 'L1042', 'L1043'],
#  ['L172', 'L173', 'L174'],
#  ['L184', 'L185'],
#  ['L338',
#   'L339',
#   'L340',
#   'L341',
#   'L342',
#   'L343',
#   'L344',
#   'L345',
#   'L346',
#   'L347'],
#  ['L986', 'L987', 'L988'],
#  ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997'],
#  ['L998', 'L999', 'L1000'],
#  ['L103', 'L104', 'L105', 'L106', 'L107'],
#  ['L108', 'L109'],
#  ['L1017', 'L1018'],
#  ['L728', 'L729', 'L730', 'L731'],
#  ['L732', 'L733'],
#  ['L735', 'L736', 'L737', 'L738'],
#  ['L371', 'L372', 'L373'],
#  ['L375', 'L376', 'L377'],
#  ['L378', 'L379'],
#  ['L380', 'L381', 'L382'],
#  ['L383', 'L384'],
#  ['L414', 'L415'],
#  ['L420', 'L421'],
#  ['L428', 'L429'],
#  ['L436', 'L437'],
#  ['L723', 'L724'],
#  ['L775', 'L776', 'L777'],
#  ['L59', 'L60', 'L61', 'L62'],
#  ['L257', 'L258', 'L259'],
#  ['L261', 'L262', 'L263', 'L264'],
#  ['L511', 'L512'],
#  ['L161', 'L162'],
#  ['L170', 'L171'],
#  ['L191', 'L192', 'L193'],
#  ['L876', 'L877'],
#  ['L886', 'L887'],
#  ['L917', 'L918'],
#  ['L926', 'L927'],
#  ['L929', 'L930', 'L931', 'L932', 'L933'],
#  ['L2170', 'L2171', 'L2172'],
#  ['L2173', 'L2174', 'L2175'],
#  ['L2176', 'L2177'],
#  ['L2179', 'L2180', 'L2181'],
#  ['L1989', 'L1990', 'L1991', 'L1992', 'L1993'],
#  ['L2005', 'L2006'],
#  ['L2010', 'L2011', 'L2012'],
#  ['L2014', 'L2015', 'L2016'],
#  ['L2019', 'L2020'],
#  ['L2022', 'L2023'],
#  ['L2024', 'L2025'],
#  ['L2027', 'L2028', 'L2029'],
#  ['L2030', 'L2031'],
#  ['L2274', 'L2275'],
#  ['L2522', 'L2523', 'L2524'],
#  ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984'],
#  ['L1985', 'L1986'],
#  ['L2118', 'L2119'],
#  ['L2121', 'L2122', 'L2123'],
#  ['L2318', 'L2319', 'L2320'],
#  ['L2471', 'L2472'],
#  ['L2473', 'L2474'],
#  ['L2537', 'L2538'],
#  ['L2539', 'L2540'],
#  ['L2290', 'L2291', 'L2292', 'L2293'],
#  ['L2421', 'L2422'],
#  ['L2423', 'L2424', 'L2425', 'L2426'],
#  ['L2429', 'L2430', 'L2431', 'L2432'],
#  ['L2127', 'L2128', 'L2129'],
#  ['L2130', 'L2131'],
#  ['L2439', 'L2440'],
#  ['L2484', 'L2485'],
#  ['L2500', 'L2501'],
#  ['L2541', 'L2542'],
#  ['L2547', 'L2548', 'L2549'],
#  ['L2550', 'L2551', 'L2552'],
#  ['L2103', 'L2104', 'L2105'],
#  ['L2106', 'L2107', 'L2108'],
#  ['L2109', 'L2110'],
#  ['L2281', 'L2282'],
#  ['L2286', 'L2287'],
#  ['L2295', 'L2296', 'L2297'],
#  ['L2299', 'L2300', 'L2301'],
#  ['L2463', 'L2464'],
#  ['L2465', 'L2466'],
#  ['L2467', 'L2468', 'L2469'],
#  ['L2237', 'L2238', 'L2239'],
#  ['L2248', 'L2249', 'L2250', 'L2251'],
#  ['L2253', 'L2254', 'L2255'],
#  ['L2256', 'L2257', 'L2258', 'L2259', 'L2260'],
#  ['L2341', 'L2342', 'L2343'],
#  ['L2393', 'L2394'],
#  ['L2409', 'L2410'],
#  ['L1942', 'L1943'],
#  ['L1947', 'L1948', 'L1949', 'L1950'],
#  ['L1951', 'L1952'],
#  ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962'],
#  ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969'],
#  ['L2037', 'L2038', 'L2039', 'L2040'],
#  ['L2041', 'L2042'],
#  ['L2045', 'L2046'],
#  ['L2132', 'L2133'],
#  ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139'],
#  ['L2140', 'L2141', 'L2142', 'L2143'],
#  ['L2144', 'L2145'],
#  ['L2525', 'L2526'],
#  ['L2531', 'L2532', 'L2533', 'L2534', 'L2535'],
#  ['L2071', 'L2072'],
#  ['L2073', 'L2074', 'L2075'],
#  ['L2076', 'L2077'],
#  ['L2079', 'L2080', 'L2081', 'L2082'],
#  ['L2085', 'L2086'],
#  ['L2279', 'L2280'],
#  ['L2456', 'L2457', 'L2458', 'L2459'],
#  ['L2277', 'L2278'],
#  ['L2328', 'L2329'],
#  ['L2331', 'L2332', 'L2333'],
#  ['L2345', 'L2346'],
#  ['L2347', 'L2348'],
#  ['L2386', 'L2387', 'L2388', 'L2389'],
#  ['L2154', 'L2155'],
#  ['L2157', 'L2158', 'L2159', 'L2160'],
#  ['L2164', 'L2165'],
#  ['L2490', 'L2491', 'L2492'],
#  ['L2064', 'L2065'],
#  ['L2196',
#   'L2197',
#   'L2198',
#   'L2199',
#   'L2200',
#   'L2201',
#   'L2202',
#   'L2203',
#   'L2204',
#   'L2205',
#   'L2206',
#   'L2207',
#   'L2208',
#   'L2209',
#   'L2210',
#   'L2211'],
#  ['L1930', 'L1931'],
#  ['L2112', 'L2113'],
#  ['L2115', 'L2116'],
#  ['L2376', 'L2377'],
#  ['L2414', 'L2415'],
#  ['L2417', 'L2418', 'L2419'],
#  ['L2460', 'L2461', 'L2462'],
#  ['L3380', 'L3381', 'L3382'],
#  ['L3383', 'L3384', 'L3385'],
#  ['L3392', 'L3393', 'L3394', 'L3395', 'L3396'],
#  ['L3459', 'L3460', 'L3461'],
#  ['L3464',
#   'L3465',
#   'L3466',
#   'L3467',
#   'L3468',
#   'L3469',
#   'L3470',
#   'L3471',
#   'L3472',
#   'L3473',
#   'L3474',
#   'L3475',
#   'L3476',
#   'L3477',
#   'L3478',
#   'L3479',
#   'L3480',
#   'L3481'],
#  ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489'],
#  ['L3490', 'L3491', 'L3492', 'L3493'],
#  ['L3496', 'L3497'],
#  ['L3545', 'L3546'],
#  ['L3059', 'L3060', 'L3061'],
#  ['L3089', 'L3090', 'L3091', 'L3092'],
#  ['L3093', 'L3094', 'L3095'],
#  ['L3096', 'L3097'],
#  ['L3158', 'L3159', 'L3160'],
#  ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166'],
#  ['L3167', 'L3168', 'L3169', 'L3170'],
#  ['L3177', 'L3178', 'L3179', 'L3180', 'L3181'],
#  ['L3300', 'L3301', 'L3302'],
#  ['L3305', 'L3306', 'L3307', 'L3308'],
#  ['L3309', 'L3310', 'L3311'],
#  ['L3313', 'L3314'],
#  ['L3315', 'L3316', 'L3317', 'L3318'],
#  ['L3329', 'L3330'],
#  ['L3514', 'L3515', 'L3516', 'L3517'],
#  ['L3045', 'L3046', 'L3047', 'L3048'],
#  ['L3049', 'L3050', 'L3051'],
#  ['L3055', 'L3056'],
#  ['L3062', 'L3063', 'L3064', 'L3065'],
#  ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214'],
#  ['L2797', 'L2798', 'L2799', 'L2800'],
#  ['L3196', 'L3197'],
#  ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203'],
#  ['L3293', 'L3294'],
#  ['L3498',
#   'L3499',
#   'L3500',
#   'L3501',
#   'L3502',
#   'L3503',
#   'L3504',
#   'L3505',
#   'L3506'],
#  ['L2801', 'L2802', 'L2803', 'L2804', 'L2805'],
#  ['L3289', 'L3290', 'L3291', 'L3292'],
#  ['L2599', 'L2600', 'L2601'],
#  ['L2602', 'L2603'],
#  ['L2630', 'L2631', 'L2632', 'L2633'],
#  ['L2751', 'L2752'],
#  ['L2920', 'L2921', 'L2922', 'L2923'],
#  ['L2924', 'L2925'],
#  ['L2936', 'L2937', 'L2938'],
#  ['L3016', 'L3017'],
#  ['L3022', 'L3023'],
#  ['L3027', 'L3028'],
#  ['L2964', 'L2965', 'L2966', 'L2967'],
#  ['L2971', 'L2972', 'L2973'],
#  ['L2975', 'L2976', 'L2977', 'L2978'],
#  ['L2979', 'L2980', 'L2981'],
#  ['L2986', 'L2987', 'L2988', 'L2989', 'L2990'],
#  ['L2730', 'L2731'],
#  ['L2746', 'L2747', 'L2748'],
#  ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882'],
#  ['L2883', 'L2884', 'L2885', 'L2886'],
#  ['L2887', 'L2888', 'L2889', 'L2890', 'L2891'],
#  ['L2892', 'L2893'],
#  ['L2895', 'L2896', 'L2897'],
#  ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906'],
#  ['L2949', 'L2950', 'L2951', 'L2952', 'L2953'],
#  ['L2955', 'L2956', 'L2957', 'L2958'],
#  ['L2962', 'L2963'],
#  ['L2991', 'L2992'],
#  ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999'],
#  ['L3052', 'L3053', 'L3054'],
#  ['L3057', 'L3058'],
#  ['L3067', 'L3068'],
#  ['L3069',
#   'L3070',
#   'L3071',
#   'L3072',
#   'L3073',
#   'L3074',
#   'L3075',
#   'L3076',
#   'L3077',
#   'L3078',
#   'L3079'],
#  ['L3080', 'L3081', 'L3082'],
#  ['L3219', 'L3220', 'L3221', 'L3222'],
#  ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228'],
#  ['L3229', 'L3230'],
#  ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242'],
#  ['L3243', 'L3244'],
#  ['L3248', 'L3249'],
#  ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765'],
#  ['L3029', 'L3030'],
#  ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037'],
#  ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044'],
#  ['L3101', 'L3102'],
#  ['L3103',
#   'L3104',
#   'L3105',
#   'L3106',
#   'L3107',
#   'L3108',
#   'L3109',
#   'L3110',
#   'L3111',
#   'L3112',
#   'L3113',
#   'L3114',
#   'L3115',
#   'L3116',
#   'L3117'],
#  ['L3119', 'L3120', 'L3121'],
#  ['L3126', 'L3127', 'L3128', 'L3129', 'L3130'],
#  ['L3135',
#   'L3136',
#   'L3137',
#   'L3138',
#   'L3139',
#   'L3140',
#   'L3141',
#   'L3142',
#   'L3143',
#   'L3144',
#   'L3145',
#   'L3146',
#   'L3147'],
#  ['L3148',
#   'L3149',
#   'L3150',
#   'L3151',
#   'L3152',
#   'L3153',
#   'L3154',
#   'L3155',
#   'L3156',
#   'L3157'],
#  ['L2595', 'L2596'],
#  ['L2604', 'L2605', 'L2606', 'L2607'],
#  ['L2611', 'L2612'],
#  ['L2644', 'L2645'],
#  ['L2646', 'L2647', 'L2648'],
#  ['L2651', 'L2652'],
#  ['L2653', 'L2654', 'L2655', 'L2656'],
#  ['L2664', 'L2665'],
#  ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626'],
#  ['L2627', 'L2628'],
#  ['L3278',
#   'L3279',
#   'L3280',
#   'L3281',
#   'L3282',
#   'L3283',
#   'L3284',
#   'L3285',
#   'L3286'],
#  ['L3419', 'L3420', 'L3421'],
#  ['L3431', 'L3432'],
#  ['L3433', 'L3434'],
#  ['L3435', 'L3436'],
#  ['L3554', 'L3555', 'L3556'],
#  ['L2845', 'L2846', 'L2847'],
#  ['L2848', 'L2849'],
#  ['L2850', 'L2851', 'L2852', 'L2853', 'L2854'],
#  ['L2855', 'L2856'],
#  ['L2857', 'L2858'],
#  ['L2563', 'L2564'],
#  ['L2565', 'L2566', 'L2567', 'L2568', 'L2569'],
#  ['L2570', 'L2571', 'L2572', 'L2573', 'L2574'],
#  ['L2577', 'L2578', 'L2579', 'L2580', 'L2581'],
#  ['L2908', 'L2909'],
#  ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915'],
#  ['L2557', 'L2558'],
#  ['L2559', 'L2560'],
#  ['L2561', 'L2562'],
#  ['L2635', 'L2636', 'L2637', 'L2638'],
#  ['L2639', 'L2640'],
#  ['L2666', 'L2667', 'L2668'],
#  ['L2670', 'L2671'],
#  ['L2778', 'L2779'],
#  ['L2780', 'L2781', 'L2782', 'L2783'],
#  ['L2789', 'L2790'],
#  ['L2842', 'L2843', 'L2844'],
#  ['L3083', 'L3084', 'L3085'],
#  ['L3087', 'L3088'],
#  ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188'],
#  ['L3189', 'L3190'],
#  ['L3191', 'L3192', 'L3193'],
#  ['L3246', 'L3247'],
#  ['L3250', 'L3251'],
#  ['L3356', 'L3357'],
#  ['L3359', 'L3360'],
#  ['L3361', 'L3362'],
#  ['L3363', 'L3364'],
#  ['L3365', 'L3366'],
#  ['L3368', 'L3369', 'L3370'],
#  ['L3372', 'L3373', 'L3374', 'L3375'],
#  ['L3376', 'L3377', 'L3378'],
#  ['L3547', 'L3548'],
#  ['L2672', 'L2673'],
#  ['L2674', 'L2675', 'L2676'],
#  ['L2678', 'L2679'],
#  ['L2680', 'L2681', 'L2682'],
#  ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692'],
#  ['L3271', 'L3272', 'L3273', 'L3274', 'L3275'],
#  ['L3352', 'L3353'],
#  ['L2608', 'L2609', 'L2610'],
#  ['L2614', 'L2615'],
#  ['L3409', 'L3410'],
#  ['L3411', 'L3412', 'L3413'],
#  ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269'],
#  ['L2575', 'L2576'],
#  ['L2582',
#   'L2583',
#   'L2584',
#   'L2585',
#   'L2586',
#   'L2587',
#   'L2588',
#   'L2589',
#   'L2590',
#   'L2591'],
#  ['L2732', 'L2733'],
#  ['L2740', 'L2741', 'L2742', 'L2743'],
#  ['L2744', 'L2745'],
#  ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403'],
#  ['L2698', 'L2699', 'L2700'],
#  ['L2701', 'L2702', 'L2703'],
#  ['L2706', 'L2707'],
#  ['L2771', 'L2772', 'L2773'],
#  ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813'],
#  ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721'],
#  ['L2724', 'L2725'],
#  ['L2735', 'L2736', 'L2737'],
#  ['L2738', 'L2739'],
#  ['L2754', 'L2755', 'L2756', 'L2757'],
#  ['L2767', 'L2768'],
#  ['L2793', 'L2794', 'L2795'],
#  ['L2863', 'L2864', 'L2865'],
#  ['L2870', 'L2871', 'L2872'],
#  ['L3024', 'L3025', 'L3026'],
#  ['L3287', 'L3288'],
#  ['L3342', 'L3343', 'L3344'],
#  ['L2928', 'L2929', 'L2930'],
#  ['L3422', 'L3423', 'L3424'],
#  ['L3425', 'L3426', 'L3427'],
#  ['L2828',
#   'L2829',
#   'L2830',
#   'L2831',
#   'L2832',
#   'L2833',
#   'L2834',
#   'L2835',
#   'L2836',
#   'L2837',
#   'L2838',
#   'L2839',
#   'L2840'],
#  ['L3712', 'L3713'],
#  ['L3720', 'L3721'],
#  ['L3728', 'L3729'],
#  ['L3749', 'L3750'],
#  ['L3756', 'L3757'],
#  ['L3770', 'L3771'],
#  ['L3777', 'L3778'],
#  ['L3942', 'L3943', 'L3944', 'L3945'],
#  ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969'],
#  ['L3972', 'L3973', 'L3974', 'L3975', 'L3976'],
#  ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984'],
#  ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992'],
#  ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001'],
#  ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017'],
#  ['L4159', 'L4160', 'L4161', 'L4162', 'L4163'],
#  ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193'],
#  ['L4196', 'L4197', 'L4198', 'L4199'],
#  ['L4208', 'L4209'],
#  ['L4282', 'L4283'],
#  ['L4296', 'L4297', 'L4298', 'L4299', 'L4300'],
#  ['L4006', 'L4007'],
#  ['L4068', 'L4069', 'L4070'],
#  ['L4079', 'L4080'],
#  ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224'],
#  ['L4227', 'L4228', 'L4229', 'L4230'],
#  ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271'],
#  ['L4333', 'L4334', 'L4335'],
#  ['L4346', 'L4347', 'L4348', 'L4349', 'L4350'],
#  ['L4353', 'L4354', 'L4355', 'L4356', 'L4357'],
#  ['L4360', 'L4361', 'L4362', 'L4363'],
#  ['L4366', 'L4367', 'L4368'],
#  ['L3970', 'L3971'],
#  ['L3977', 'L3978'],
#  ['L3993', 'L3994'],
#  ['L4002', 'L4003'],
#  ['L4009', 'L4010'],
#  ['L4018', 'L4019'],
#  ['L3668', 'L3669'],
#  ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677'],
#  ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685'],
#  ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693'],
#  ['L3797', 'L3798', 'L3799'],
#  ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810'],
#  ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735'],
#  ['L3758', 'L3759'],
#  ['L3774', 'L3775', 'L3776'],
#  ['L3779', 'L3780'],
#  ['L3622', 'L3623'],
#  ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631'],
#  ['L3651', 'L3652', 'L3653'],
#  ['L3724', 'L3725', 'L3726'],
#  ['L3738', 'L3739', 'L3740'],
#  ['L3745', 'L3746', 'L3747', 'L3748'],
#  ['L3751', 'L3752', 'L3753', 'L3754'],
#  ['L3760', 'L3761', 'L3762', 'L3763'],
#  ['L3766', 'L3767', 'L3768'],
#  ['L3772', 'L3773'],
#  ['L3868', 'L3869'],
#  ['L3889', 'L3890', 'L3891', 'L3892', 'L3893'],
#  ['L3896', 'L3897'],
#  ['L3904', 'L3905', 'L3906', 'L3907'],
#  ['L3817', 'L3818', 'L3819', 'L3820', 'L3821'],
#  ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829'],
#  ['L3832', 'L3833', 'L3834'],
#  ['L3837', 'L3838', 'L3839'],
#  ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025'],
#  ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033'],
#  ['L4096', 'L4097'],
#  ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113'],
#  ['L4118', 'L4119'],
#  ['L4169', 'L4170'],
#  ['L4174', 'L4175'],
#  ['L4181', 'L4182', 'L4183'],
#  ['L5039', 'L5040'],
#  ['L5041', 'L5042'],
#  ['L5043', 'L5044'],
#  ['L5045', 'L5046', 'L5047', 'L5048'],
#  ['L4897', 'L4898', 'L4899', 'L4900'],
#  ['L4903', 'L4904', 'L4905', 'L4906'],
#  ['L4922', 'L4923'],
#  ['L4924', 'L4925'],
#  ['L4453', 'L4454'],
#  ['L4501', 'L4502', 'L4503', 'L4504', 'L4505'],
#  ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511'],
#  ['L4562', 'L4563'],
#  ['L4567', 'L4568'],
#  ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180'],
#  ['L5181', 'L5182'],
#  ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188'],
#  ['L5193', 'L5194'],
#  ['L5215', 'L5216'],
#  ['L5366', 'L5367', 'L5368'],
#  ['L5370', 'L5371'],
#  ['L4944', 'L4945'],
#  ['L4959', 'L4960'],
#  ['L5316', 'L5317', 'L5318'],
#  ['L5321', 'L5322', 'L5323', 'L5324', 'L5325'],
#  ['L5328', 'L5329'],
#  ['L4628', 'L4629'],
#  ['L5338', 'L5339', 'L5340'],
#  ['L5346', 'L5347', 'L5348'],
#  ['L4727', 'L4728', 'L4729'],
#  ['L4731', 'L4732'],
#  ['L4739', 'L4740', 'L4741'],
#  ['L4743',
#   'L4744',
#   'L4745',
#   'L4746',
#   'L4747',
#   'L4748',
#   'L4749',
#   'L4750',
#   'L4751'],
#  ['L4763', 'L4764'],
#  ['L4765', 'L4766'],
#  ['L4769', 'L4770'],
#  ['L4771', 'L4772', 'L4773', 'L4774', 'L4775'],
#  ['L4778', 'L4779'],
#  ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785'],
#  ['L4786', 'L4787', 'L4788'],
#  ['L4789', 'L4790', 'L4791', 'L4792'],
#  ['L4800', 'L4801', 'L4802', 'L4803'],
#  ['L4814', 'L4815', 'L4816'],
#  ['L4825', 'L4826', 'L4827', 'L4828'],
#  ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855'],
#  ['L4857', 'L4858'],
#  ['L4860', 'L4861'],
#  ['L4863', 'L4864'],
#  ['L4866', 'L4867'],
#  ['L4868', 'L4869'],
#  ['L4870', 'L4871'],
#  ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879'],
#  ['L4880', 'L4881'],
#  ['L4882', 'L4883', 'L4884', 'L4885', 'L4886'],
#  ['L4887', 'L4888', 'L4889', 'L4890', 'L4891'],
#  ['L4893', 'L4894'],
#  ['L4895', 'L4896'],
#  ['L4911', 'L4912'],
#  ['L4929', 'L4930'],
#  ['L4937', 'L4938', 'L4939'],
#  ['L4964', 'L4965'],
#  ['L4969', 'L4970', 'L4971', 'L4972', 'L4973'],
#  ['L4974', 'L4975'],
#  ['L4994', 'L4995', 'L4996', 'L4997'],
#  ['L5002', 'L5003', 'L5004', 'L5005'],
#  ['L5007', 'L5008', 'L5009', 'L5010'],
#  ['L5011', 'L5012', 'L5013', 'L5014'],
#  ['L5016', 'L5017'],
#  ['L5018', 'L5019', 'L5020'],
#  ['L5021', 'L5022'],
#  ['L5023', 'L5024', 'L5025'],
#  ['L5028', 'L5029', 'L5030'],
#  ['L5033', 'L5034', 'L5035'],
#  ['L5036', 'L5037', 'L5038'],
#  ['L5049', 'L5050', 'L5051'],
#  ['L5052', 'L5053', 'L5054', 'L5055', 'L5056'],
#  ['L5057', 'L5058', 'L5059'],
#  ['L5060', 'L5061', 'L5062', 'L5063', 'L5064'],
#  ['L5065', 'L5066'],
#  ['L5067', 'L5068'],
#  ['L5069', 'L5070', 'L5071', 'L5072'],
#  ['L5073', 'L5074'],
#  ['L5076', 'L5077'],
#  ['L5083', 'L5084', 'L5085'],
#  ['L5171', 'L5172'],
#  ['L5190', 'L5191', 'L5192'],
#  ['L5195', 'L5196'],
#  ['L5197', 'L5198', 'L5199', 'L5200'],
#  ['L5201', 'L5202'],
#  ['L5204', 'L5205'],
#  ['L5206', 'L5207'],
#  ['L5208', 'L5209', 'L5210'],
#  ['L5212', 'L5213'],
#  ['L5224', 'L5225', 'L5226', 'L5227'],
#  ['L5236', 'L5237'],
#  ['L5249', 'L5250', 'L5251', 'L5252'],
#  ['L5253', 'L5254', 'L5255'],
#  ['L5256', 'L5257'],
#  ['L5290', 'L5291'],
#  ['L5304', 'L5305'],
#  ['L5306', 'L5307'],
#  ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314'],
#  ['L5351', 'L5352', 'L5353'],
#  ['L5372', 'L5373'],
#  ['L5375', 'L5376'],
#  ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382'],
#  ['L5383', 'L5384'],
#  ['L4689', 'L4690'],
#  ['L4691', 'L4692'],
#  ['L4693',
#   'L4694',
#   'L4695',
#   'L4696',
#   'L4697',
#   'L4698',
#   'L4699',
#   'L4700',
#   'L4701',
#   'L4702',
#   'L4703'],
#  ['L5093', 'L5094', 'L5095', 'L5096'],
#  ['L5097', 'L5098', 'L5099'],
#  ['L5100', 'L5101'],
#  ['L5102', 'L5103', 'L5104'],
#  ['L5242', 'L5243'],
#  ['L5244', 'L5245'],
#  ['L4636', 'L4637', 'L4638', 'L4639'],
#  ['L4642', 'L4643', 'L4644'],
#  ['L4669', 'L4670', 'L4671'],
#  ['L4672', 'L4673'],
#  ['L4675', 'L4676'],
#  ['L4677', 'L4678', 'L4679', 'L4680'],
#  ['L4681', 'L4682'],
#  ['L4685', 'L4686', 'L4687'],
#  ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138'],
#  ['L5142', 'L5143'],
#  ['L5144', 'L5145'],
#  ['L5158', 'L5159'],
#  ['L5162', 'L5163'],
#  ['L4809', 'L4810', 'L4811', 'L4812', 'L4813'],
#  ['L4817', 'L4818', 'L4819'],
#  ['L4821', 'L4822', 'L4823'],
#  ['L4467', 'L4468'],
#  ['L4469', 'L4470', 'L4471'],
#  ['L4472', 'L4473', 'L4474'],
#  ['L4475', 'L4476'],
#  ['L4477',
#   'L4478',
#   'L4479',
#   'L4480',
#   'L4481',
#   'L4482',
#   'L4483',
#   'L4484',
#   'L4485',
#   'L4486',
#   'L4487',
#   'L4488'],
#  ['L4513', 'L4514'],
#  ['L4516', 'L4517'],
#  ['L4519', 'L4520', 'L4521', 'L4522'],
#  ['L4523', 'L4524', 'L4525'],
#  ['L4528', 'L4529', 'L4530', 'L4531', 'L4532'],
#  ['L4533', 'L4534', 'L4535'],
#  ['L4704', 'L4705', 'L4706'],
#  ['L4707', 'L4708', 'L4709'],
#  ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718'],
#  ['L4836', 'L4837'],
#  ['L4839', 'L4840'],
#  ['L5149', 'L5150', 'L5151', 'L5152', 'L5153'],
#  ['L5164', 'L5165'],
#  ['L5167', 'L5168', 'L5169'],
#  ['L5219', 'L5220', 'L5221'],
#  ['L5258', 'L5259', 'L5260', 'L5261', 'L5262', 'L5263'],
#  ['L5275', 'L5276'],
#  ['L5284', 'L5285', 'L5286', 'L5287'],
#  ['L5292', 'L5293', 'L5294', 'L5295', 'L5296', 'L5297', 'L5298'],
#  ['L5301', 'L5302', 'L5303'],
#  ['L5355', 'L5356', 'L5357', 'L5358'],
#  ['L5359', 'L5360', 'L5361', 'L5362', 'L5363'],
#  ['L5364', 'L5365'],
#  ['L5264', 'L5265'],
#  ['L5266', 'L5267', 'L5268'],
#  ['L5279', 'L5280', 'L5281', 'L5282'],
#  ['L5288', 'L5289'],
#  ['L4600', 'L4601', 'L4602'],
#  ['L4603', 'L4604'],
#  ['L4609', 'L4610'],
#  ['L4612', 'L4613'],
#  ['L4493', 'L4494'],
#  ['L4495', 'L4496', 'L4497', 'L4498', 'L4499', 'L4500'],
#  ['L4543', 'L4544', 'L4545', 'L4546', 'L4547'],
#  ['L4548', 'L4549', 'L4550', 'L4551', 'L4552', 'L4553', 'L4554', 'L4555'],
#  ['L4558', 'L4559'],
#  ['L5230', 'L5231'],
#  ['L5233', 'L5234'],
#  ['L5105', 'L5106'],
#  ['L5107', 'L5108'],
#  ['L5109', 'L5110'],
#  ['L5113', 'L5114'],
#  ['L5115', 'L5116', 'L5117', 'L5118', 'L5119', 'L5120'],
#  ['L5121', 'L5122', 'L5123'],
#  ['L5124', 'L5125'],
#  ['L5643', 'L5644', 'L5645'],
#  ['L5673', 'L5674'],
#  ['L5678', 'L5679', 'L5680'],
#  ['L5692', 'L5693'],
#  ['L5875', 'L5876'],
#  ['L5889', 'L5890'],
#  ['L5710', 'L5711'],
#  ['L5737',
#   'L5738',
#   'L5739',
#   'L5740',
#   'L5741',
#   'L5742',
#   'L5743',
#   'L5744',
#   'L5745'],
#  ['L5746', 'L5747', 'L5748'],
#  ['L5751', 'L5752'],
#  ['L5754', 'L5755', 'L5756'],
#  ['L5760', 'L5761'],
#  ['L5613', 'L5614'],
#  ['L5615', 'L5616', 'L5617'],
#  ['L5620', 'L5621', 'L5622'],
#  ['L5624', 'L5625', 'L5626', 'L5627', 'L5628'],
#  ['L5648', 'L5649', 'L5650', 'L5651'],
#  ['L5652', 'L5653', 'L5654', 'L5655'],
#  ['L5656', 'L5657', 'L5658'],
#  ['L5826', 'L5827', 'L5828', 'L5829', 'L5830', 'L5831', 'L5832', 'L5833'],
#  ['L5839', 'L5840'],
#  ['L6168', 'L6169', 'L6170', 'L6171', 'L6172'],
#  ['L6258', 'L6259'],
#  ['L6263', 'L6264', 'L6265', 'L6266'],
#  ['L5463', 'L5464'],
#  ['L5468', 'L5469', 'L5470'],
#  ['L5508', 'L5509', 'L5510'],
#  ['L5511', 'L5512'],
#  ['L5515', 'L5516'],
#  ['L5521', 'L5522'],
#  ['L5556', 'L5557'],
#  ['L5630', 'L5631', 'L5632'],
#  ['L5636', 'L5637'],
#  ['L5646', 'L5647'],
#  ['L5671', 'L5672'],
#  ['L5675', 'L5676'],
#  ['L5686', 'L5687'],
#  ['L5688', 'L5689'],
#  ['L5730', 'L5731'],
#  ['L5911', 'L5912', 'L5913'],
#  ['L6251', 'L6252'],
#  ['L6105', 'L6106', 'L6107'],
#  ['L6108', 'L6109', 'L6110'],
#  ['L6114', 'L6115', 'L6116', 'L6117', 'L6118', 'L6119', 'L6120'],
#  ['L6123', 'L6124'],
#  ['L5488', 'L5489'],
#  ['L5490', 'L5491', 'L5492'],
#  ['L5493', 'L5494', 'L5495', 'L5496'],
#  ['L5497', 'L5498', 'L5499'],
#  ['L5501', 'L5502', 'L5503', 'L5504', 'L5505', 'L5506'],
#  ['L5664', 'L5665', 'L5666', 'L5667', 'L5668'],
#  ['L5669', 'L5670'],
#  ['L5596', 'L5597'],
#  ['L5605', 'L5606'],
#  ['L5609', 'L5610'],
#  ['L5611', 'L5612'],
#  ['L5633', 'L5634'],
#  ['L5638', 'L5639', 'L5640', 'L5641'],
#  ['L5420', 'L5421'],
#  ['L5422', 'L5423', 'L5424', 'L5425'],
#  ['L5426', 'L5427'],
#  ['L5777', 'L5778', 'L5779', 'L5780'],
#  ['L5782', 'L5783'],
#  ['L5785', 'L5786'],
#  ['L5787', 'L5788', 'L5789'],
#  ['L5790', 'L5791', 'L5792'],
#  ['L5880', 'L5881', 'L5882'],
#  ['L6029', 'L6030', 'L6031', 'L6032'],
#  ['L5543', 'L5544'],
#  ['L5545', 'L5546', 'L5547', 'L5548'],
#  ['L5834', 'L5835'],
#  ['L6208', 'L6209'],
#  ['L6211', 'L6212'],
#  ['L5922', 'L5923'],
#  ['L5924', 'L5925'],
#  ['L5933', 'L5934'],
#  ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026'],
#  ['L6132', 'L6133'],
#  ['L6156', 'L6157', 'L6158'],
#  ['L6183', 'L6184'],
#  ['L6190', 'L6191'],
#  ['L6206', 'L6207'],
#  ['L6213', 'L6214'],
#  ['L6215', 'L6216'],
#  ['L6278', 'L6279', 'L6280'],
#  ['L6282', 'L6283'],
#  ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800'],
#  ['L5801', 'L5802', 'L5803'],
#  ['L5804', 'L5805', 'L5806'],
#  ['L5809', 'L5810', 'L5811', 'L5812', 'L5813'],
#  ['L5815', 'L5816'],
#  ['L5817', 'L5818', 'L5819'],
#  ['L5820', 'L5821', 'L5822'],
#  ['L5824', 'L5825'],
#  ['L5858', 'L5859'],
#  ['L5869', 'L5870', 'L5871'],
#  ['L5900', 'L5901'],
#  ['L5943', 'L5944'],
#  ['L5946', 'L5947'],
#  ['L5949', 'L5950'],
#  ['L5954', 'L5955', 'L5956', 'L5957'],
#  ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965'],
#  ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056'],
#  ['L6057', 'L6058', 'L6059'],
#  ['L6062', 'L6063', 'L6064'],
#  ['L6066', 'L6067'],
#  ['L6237', 'L6238', 'L6239', 'L6240', 'L6241'],
#  ['L6267', 'L6268', 'L6269', 'L6270'],
#  ['L6289', 'L6290', 'L6291', 'L6292', 'L6293'],
#  ['L6297', 'L6298', 'L6299', 'L6300', 'L6301'],
#  ['L6302', 'L6303', 'L6304', 'L6305'],
#  ['L6308', 'L6309'],
#  ['L5722', 'L5723', 'L5724', 'L5725', 'L5726'],
#  ['L5728', 'L5729'],
#  ['L5531', 'L5532', 'L5533'],
#  ['L5534', 'L5535', 'L5536'],
#  ['L5537', 'L5538'],
#  ['L5539', 'L5540'],
#  ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567'],
#  ['L5568', 'L5569', 'L5570'],
#  ['L5573', 'L5574'],
#  ['L5585', 'L5586'],
#  ['L6313', 'L6314'],
#  ['L5767', 'L5768', 'L5769', 'L5770'],
#  ['L5773', 'L5774'],
#  ['L6254', 'L6255'],
#  ['L5441', 'L5442'],
#  ['L5443', 'L5444', 'L5445', 'L5446', 'L5447'],
#  ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453'],
#  ['L5479', 'L5480'],
#  ['L5396', 'L5397', 'L5398'],
#  ['L5399', 'L5400'],
#  ['L5404', 'L5405'],
#  ['L5406', 'L5407'],
#  ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225'],
#  ['L6002', 'L6003'],
#  ['L6004', 'L6005'],
#  ['L6006', 'L6007', 'L6008', 'L6009'],
#  ['L6011', 'L6012'],
#  ['L6335', 'L6336'],
#  ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344'],
#  ['L6347', 'L6348', 'L6349', 'L6350'],
#  ['L6351', 'L6352'],
#  ['L6361', 'L6362', 'L6363', 'L6364', 'L6365'],
#  ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435'],
#  ['L6957', 'L6958', 'L6959'],
#  ['L6960', 'L6961', 'L6962', 'L6963', 'L6964'],
#  ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976'],
#  ['L6977', 'L6978', 'L6979'],
#  ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985'],
#  ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993'],
#  ['L6996', 'L6997', 'L6998', 'L6999', 'L7000'],
#  ['L7001', 'L7002'],
#  ['L6605', 'L6606'],
#  ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612'],
#  ['L6707',
#   'L6708',
#   'L6709',
#   'L6710',
#   'L6711',
#   'L6712',
#   'L6713',
#   'L6714',
#   'L6715',
#   'L6716',
#   'L6717'],
#  ['L6909', 'L6910'],
#  ['L6779', 'L6780'],
#  ['L6781', 'L6782', 'L6783', 'L6784'],
#  ['L6789', 'L6790'],
#  ['L6791',
#   'L6792',
#   'L6793',
#   'L6794',
#   'L6795',
#   'L6796',
#   'L6797',
#   'L6798',
#   'L6799'],
#  ['L6800', 'L6801', 'L6802'],
#  ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808'],
#  ['L6810', 'L6811', 'L6812'],
#  ['L6814', 'L6815'],
#  ['L6828', 'L6829'],
#  ['L6830', 'L6831', 'L6832'],
#  ['L6833', 'L6834', 'L6835'],
#  ['L6840', 'L6841', 'L6842'],
#  ['L6844', 'L6845', 'L6846'],
#  ['L6852', 'L6853'],
#  ['L6858', 'L6859', 'L6860', 'L6861', 'L6862'],
#  ['L6863', 'L6864'],
#  ['L6847', 'L6848'],
#  ['L6865', 'L6866'],
#  ['L6906', 'L6907', 'L6908'],
#  ['L6911', 'L6912'],
#  ['L6935', 'L6936'],
#  ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442'],
#  ['L6443',
#   'L6444',
#   'L6445',
#   'L6446',
#   'L6447',
#   'L6448',
#   'L6449',
#   'L6450',
#   'L6451',
#   'L6452'],
#  ['L6453', 'L6454'],
#  ['L6460', 'L6461', 'L6462', 'L6463', 'L6464'],
#  ['L6693',
#   'L6694',
#   'L6695',
#   'L6696',
#   'L6697',
#   'L6698',
#   'L6699',
#   'L6700',
#   'L6701',
#   'L6702'],
#  ['L6919', 'L6920'],
#  ['L7013', 'L7014', 'L7015'],
#  ['L7016', 'L7017'],
#  ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025'],
#  ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033'],
#  ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039'],
#  ['L7043', 'L7044', 'L7045'],
#  ['L7048',
#   'L7049',
#   'L7050',
#   'L7051',
#   'L7052',
#   'L7053',
#   'L7054',
#   'L7055',
#   'L7056',
#   'L7057'],
#  ['L7059', 'L7060'],
#  ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067'],
#  ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076'],
#  ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692'],
#  ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380'],
#  ['L6868',
#   'L6869',
#   'L6870',
#   'L6871',
#   'L6872',
#   'L6873',
#   'L6874',
#   'L6875',
#   'L6876',
#   'L6877',
#   'L6878',
#   'L6879',
#   'L6880'],
#  ['L6881', 'L6882', 'L6883', 'L6884', 'L6885'],
#  ['L6886', 'L6887', 'L6888', 'L6889'],
#  ['L6890', 'L6891', 'L6892', 'L6893', 'L6894'],
#  ['L6898', 'L6899'],
#  ['L6900', 'L6901'],
#  ['L6902', 'L6903'],
#  ['L6921', 'L6922'],
#  ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553'],
#  ['L6556', 'L6557'],
#  ['L6558', 'L6559', 'L6560', 'L6561'],
#  ['L6568', 'L6569'],
#  ['L6570', 'L6571'],
#  ['L6574', 'L6575'],
#  ['L6576',
#   'L6577',
#   'L6578',
#   'L6579',
#   'L6580',
#   'L6581',
#   'L6582',
#   'L6583',
#   'L6584',
#   'L6585',
#   'L6586',
#   'L6587',
#   'L6588',
#   'L6589',
#   'L6590',
#   'L6591',
#   'L6592',
#   'L6593',
#   'L6594',
#   'L6595',
#   'L6596'],
#  ['L6597', 'L6598'],
#  ['L6614',
#   'L6615',
#   'L6616',
#   'L6617',
#   'L6618',
#   'L6619',
#   'L6620',
#   'L6621',
#   'L6622'],
#  ['L6623',
#   'L6624',
#   'L6625',
#   'L6626',
#   'L6627',
#   'L6628',
#   'L6629',
#   'L6630',
#   'L6631',
#   'L6632',
#   'L6633',
#   'L6634',
#   'L6635',
#   'L6636',
#   'L6637'],
#  ['L6722',
#   'L6723',
#   'L6724',
#   'L6725',
#   'L6726',
#   'L6727',
#   'L6728',
#   'L6729',
#   'L6730',
#   'L6731',
#   'L6732',
#   'L6733',
#   'L6734',
#   'L6735',
#   'L6736',
#   'L6737'],
#  ['L6750', 'L6751', 'L6752'],
#  ['L6753', 'L6754'],
#  ['L6757', 'L6758'],
#  ['L6762', 'L6763', 'L6764', 'L6765'],
#  ['L6768', 'L6769'],
#  ['L6787', 'L6788'],
#  ['L6816', 'L6817', 'L6818', 'L6819'],
#  ['L6821', 'L6822'],
#  ['L6823', 'L6824'],
#  ['L6368', 'L6369'],
#  ['L6372', 'L6373'],
#  ['L6382', 'L6383'],
#  ['L6384', 'L6385'],
#  ['L6386', 'L6387', 'L6388'],
#  ['L6389', 'L6390', 'L6391', 'L6392'],
#  ['L6395', 'L6396', 'L6397', 'L6398'],
#  ['L6399', 'L6400', 'L6401'],
#  ['L6402', 'L6403', 'L6404', 'L6405', 'L6406'],
#  ['L6407', 'L6408', 'L6409'],
#  ['L6410', 'L6411'],
#  ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418'],
#  ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424'],
#  ['L6425', 'L6426', 'L6427', 'L6428'],
#  ['L6639', 'L6640', 'L6641', 'L6642'],
#  ['L6643', 'L6644', 'L6645', 'L6646', 'L6647'],
#  ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655'],
#  ['L6738',
#   'L6739',
#   'L6740',
#   'L6741',
#   'L6742',
#   'L6743',
#   'L6744',
#   'L6745',
#   'L6746'],
#  ['L6747', 'L6748', 'L6749'],
#  ['L6466', 'L6467'],
#  ['L6468', 'L6469', 'L6470', 'L6471', 'L6472'],
#  ['L6473', 'L6474', 'L6475', 'L6476', 'L6477'],
#  ['L6479', 'L6480', 'L6481'],
#  ['L6482', 'L6483'],
#  ['L6485',
#   'L6486',
#   'L6487',
#   'L6488',
#   'L6489',
#   'L6490',
#   'L6491',
#   'L6492',
#   'L6493',
#   'L6494',
#   'L6495',
#   'L6496',
#   'L6497',
#   'L6498',
#   'L6499',
#   'L6500',
#   'L6501',
#   'L6502'],
#  ['L6503', 'L6504'],
#  ['L6507', 'L6508'],
#  ['L6511', 'L6512', 'L6513', 'L6514', 'L6515'],
#  ['L6516',
#   'L6517',
#   'L6518',
#   'L6519',
#   'L6520',
#   'L6521',
#   'L6522',
#   'L6523',
#   'L6524'],
#  ['L6525', 'L6526', 'L6527', 'L6528'],
#  ['L6531', 'L6532'],
#  ['L6534', 'L6535', 'L6536'],
#  ['L7081', 'L7082', 'L7083', 'L7084'],
#  ['L7085', 'L7086', 'L7087'],
#  ['L7088',
#   'L7089',
#   'L7090',
#   'L7091',
#   'L7092',
#   'L7093',
#   'L7094',
#   'L7095',
#   'L7096',
#   'L7097',
#   'L7098'],
#  ['L6657', 'L6658', 'L6659'],
#  ['L6661', 'L6662'],
#  ['L6665', 'L6666', 'L6667', 'L6668'],
#  ['L6669', 'L6670', 'L6671'],
#  ['L6354', 'L6355', 'L6356', 'L6357'],
#  ['L6358', 'L6359', 'L6360'],
#  ['L6676', 'L6677', 'L6678'],
#  ['L6679', 'L6680', 'L6681'],
#  ['L6682', 'L6683', 'L6684'],
#  ['L8029', 'L8030', 'L8031', 'L8032'],
#  ['L8033', 'L8034', 'L8035'],
#  ['L8036', 'L8037'],
#  ['L8094', 'L8095', 'L8096', 'L8097'],
#  ['L8155', 'L8156'],
#  ['L8196', 'L8197', 'L8198', 'L8199']]

# %%
def extract_num(line):
    return int(line.split()[0])

# %%
line_nums = list(map(extract_num, clean_lines))

# %%
nums = '\d+  '
plain_lines = list(map(lambda x: re.sub(nums, '', x), clean_lines))

# %%
temp_df = pd.Series(plain_lines,line_nums).reset_index()

# %%
ordered_df = temp_df.sort_values('index', ascending=True)
ordered_df.columns = ['line_id', 'dialogue']

# %%
ordered_df['dialogue']
# Out:
# 86                        BIANCA  Did you change your hair?
# 85                                            CHASTITY  No.
# 84                   BIANCA  You might wanna think about it
# 648                                  PATRICK  I missed you.
# 647       MISS PERKY  It says here you exposed yourself ...
# 646       PATRICK  It was a bratwurst.  I was eating lunch.
# 645              MISS PERKY  With the teeth of your zipper?
# 266                               MICHAEL  You the new guy?
# 265                             CAMERON  So they tell me...
# 264       MICHAEL  C'mon.  I'm supposed to give you the ...
# 263                   MICHAEL  So -- which Dakota you from?
# 262                CAMERON  North, actually.  How'd you   ?
# 261       MICHAEL  I was kidding. People actually live t...
# 260       CAMERON  Yeah.  A couple.  We're outnumbered b...
# 259       MICHAEL  How many people were in your old school?
# 258                                    CAMERON  Thirty-two.
# 257                                       MICHAEL  Get out!
# 256                       CAMERON  How many people go here?
# 255             MICHAEL  Couple thousand. Most of them evil
# 254                              CAMERON  That I'm used to.
# 253       MICHAEL  Yeah, but these guys have never seen ...
# 252                              CAMERON  That girl -- I --
# 251                MICHAEL  You burn, you pine, you perish?
# 250                                    CAMERON  Who is she?
# 249       MICHAEL  Bianca Stratford.  Sophomore. Don't e...
# 248                                       CAMERON  Why not?
# 247       MICHAEL  I could start with your haircut, but ...
# 599       MISS PERKY  Katarina Stratford.  My, my.  You'...
# 598       KAT  Expressing my opinion is not a terrorist ...
# 597       MISS PERKY  Well, yes, compared to your other ...
#                                 ...
# 304653    CHELMSFORD  My only fear is that the Zulu will...
# 304683    CREALOCK  The only reports of enemy activity h...
# 304682                               CHELMSFORD  Thank you.
# 304641             BOY-PULLEN  Why don 't the Zulus attack?
# 304640    BLOOMFIELD  Zulu may not wear shoes or trouser...
# 304670    CHELMSFORD  You intended to bring your reserve...
# 304669    DURNFORD  I have received intelligence from, s...
# 304668    CHELMSFORD  Intelligence? Sources of your own?...
# 304667    CHELMSFORD  Are you dictating the strategy of ...
# 304666                 DURNFORD  I'm explaining my reasons.
# 304681                                     CHELMSFORD  Yes?
# 304680    CREALOCK  A large party of Zulus have been sig...
# 304665    CHELMSFORD  Tomorrow we will continue our adva...
# 304664    DURNFORD  And the threat of counter invasion n...
# 304694                                     COGHILL  Stuart?
# 304693                                   STUART SMITH  Yes.
# 304692    COGHILL  How quickly can you move your artille...
# 304691    STUART SMITH  Well, my horses are feeding, as ...
# 304690    COGHILL  Well, fed or hungry, Pulleine wants t...
# 304689      STUART SMITH  Right.  Bombardier, to me please.
# 304652            CHELMSFORD  What o'clock is it, Mr Noggs?
# 304651            NORRIS-NEWMAN  Eleven o'clock, My LorJ 42
# 304650    CHELMSFORD  Our friend Colonel Dumford will be...
# 304706    VEREKER  Well I assure you, Sir, I have no des...
# 304705    DURNFORD  And I assure you, you do not In fact...
# 304704    VEREKER  So far only their scouts. But we have...
# 304679    CHELMSFORD  Splendid site, Crealock, splendil ...
# 304678                             CREALOCK  Certainly, Sin
# 304696    COGHILL  Choose your targets men. That's right...
# 304695    MELVILL  Keep steady. You're the best shots of...
# Name: dialogue, Length: 304713, dtype: object

# %%
# helper function to parse documents by custom deliminators
def split_text_by(doc, list_of_markers):
    """returns a dictionary of document segments based on list of substring markers,
       the items in the list of markers corresponds to a key in the dictionary
       NOTE: list of markers must occur sequentially in document!"""
    segment_index = dict()
    end = len(doc)
    # find index of last occurance of each movie id in text 
    for marker in list_of_markers[::-1]:
        idx = 0
        segment_index[marker]= doc[idx:].index(marker)
        idx = segment_index[marker]
        
    return segment_index

# %%
convo_order[:1000]
# Out:
# "m0  ['L194', 'L195', 'L196', 'L197'] m0  ['L198', 'L199'] m0  ['L200', 'L201', 'L202', 'L203'] m0  ['L204', 'L205', 'L206'] m0  ['L207', 'L208'] m0  ['L271', 'L272', 'L273', 'L274', 'L275'] m0  ['L276', 'L277'] m0  ['L280', 'L281'] m0  ['L363', 'L364'] m0  ['L365', 'L366'] m0  ['L367', 'L368'] m0  ['L401', 'L402', 'L403'] m0  ['L404', 'L405', 'L406', 'L407'] m0  ['L575', 'L576'] m0  ['L577', 'L578'] m0  ['L662', 'L663'] m0  ['L693', 'L694', 'L695'] m0  ['L696', 'L697', 'L698', 'L699'] m0  ['L860', 'L861'] m0  ['L862', 'L863', 'L864', 'L865'] m0  ['L866', 'L867', 'L868', 'L869'] m0  ['L870', 'L871', 'L872'] m0  ['L924', 'L925'] m0  ['L984', 'L985'] m0  ['L1044', 'L1045'] m0  ['L49', 'L50', 'L51'] m0  ['L571', 'L572', 'L573'] m0  ['L579', 'L580'] m0  ['L595', 'L596', 'L597'] m0  ['L598', 'L599', 'L600'] m0  ['L659', 'L660'] m0  ['L952', 'L953'] m0  ['L394', 'L395'] m0  ['L396', 'L397'] m0  ['L589', 'L590', 'L591'] m0  ['L592', 'L593'] m0  ['L756', 'L757', 'L758'] m0  ['L759', 'L760'] m0 "

# %%
# segment text by movie id
convo_index = split_text_by(convo_order, movie_ids)

# inspect dictiony items and if indices match star of each movie
print(list(convo_index.items())[:5])
print(convo_order[convo_index['m616']:])
# Out:
# [('m616', 3871524), ('m615', 3864054), ('m614', 3861716), ('m613', 3856449), ('m612', 3851621)]
# m616  ['L666361', 'L666362', 'L666363', 'L666364'] m616  ['L666365', 'L666366', 'L666367', 'L666368'] m616  ['L666462', 'L666463'] m616  ['L666388', 'L666389', 'L666390', 'L666391', 'L666392', 'L666393', 'L666394', 'L666395', 'L666396', 'L666397', 'L666398'] m616  ['L666503', 'L666504', 'L666505'] m616  ['L666246', 'L666247', 'L666248'] m616  ['L666249', 'L666250'] m616  ['L666357', 'L666358'] m616  ['L666480', 'L666481', 'L666482'] m616  ['L666483', 'L666484'] m616  ['L666487', 'L666488'] m616  ['L666251', 'L666252'] m616  ['L666383', 'L666384', 'L666385'] m616  ['L666460', 'L666461'] m616  ['L666485', 'L666486'] m616  ['L666546', 'L666547'] m616  ['L666497', 'L666498', 'L666499', 'L666500', 'L666501', 'L666502'] m616  ['L666262', 'L666263', 'L666264'] m616  ['L666324', 'L666325', 'L666326', 'L666327'] m616  ['L666575', 'L666576'] m616  ['L666256', 'L666257'] m616  ['L666369', 'L666370', 'L666371', 'L666372'] m616  ['L666520', 'L666521', 'L666522']

# %%
# helper function to extract a single Line ID
def extract_line(pattern, text, start):
    end = len(text)
    '''get raw text, remove trailing non-alpha chars,
       return first character string in sequence'''

    match = re.search(pattern, text[start:end])
    clean_str = str(match)[:-2].split("='")[-1]
    return clean_str

# flag Line ID
flag_line_id = 'L\d+'

# extract ID of first line of dialogue per movie

first_lines =[]
for movie_id, idx in convo_index.items():

    first_lines.append(extract_line(flag_line_id, convo_order, idx))


# IDS extracted in reverse, flip list order
first_lines = first_lines[::-1]
first_lines_ids =list(map(lambda x: int(x[1:]), first_lines))

# %%
first_lines_ids
# Out:
# [194,
#  2170,
#  3380,
#  3712,
#  5039,
#  5643,
#  6335,
#  8029,
#  8419,
#  55383,
#  12735,
#  16651,
#  18372,
#  19395,
#  24411,
#  26385,
#  31162,
#  31661,
#  34746,
#  35642,
#  36712,
#  44782,
#  56247,
#  57755,
#  59160,
#  60125,
#  61728,
#  62848,
#  64601,
#  66017,
#  84020,
#  85782,
#  86905,
#  87018,
#  88117,
#  93271,
#  96765,
#  102214,
#  103068,
#  108371,
#  109838,
#  117629,
#  119105,
#  122039,
#  130810,
#  141302,
#  148390,
#  152060,
#  154561,
#  163186,
#  169004,
#  170956,
#  172516,
#  180345,
#  187950,
#  194393,
#  195409,
#  195644,
#  203557,
#  206496,
#  208677,
#  210902,
#  221471,
#  222757,
#  225215,
#  227810,
#  241667,
#  247158,
#  229121,
#  232574,
#  233083,
#  235683,
#  236665,
#  237695,
#  238802,
#  239783,
#  242408,
#  251294,
#  253977,
#  255448,
#  257466,
#  260937,
#  267434,
#  269546,
#  270196,
#  273698,
#  274146,
#  274609,
#  279672,
#  282051,
#  283734,
#  285452,
#  290246,
#  294330,
#  295064,
#  296483,
#  307212,
#  298764,
#  299617,
#  300310,
#  302360,
#  303685,
#  306521,
#  310939,
#  327838,
#  313897,
#  315916,
#  317475,
#  319350,
#  329469,
#  333811,
#  334550,
#  336366,
#  338171,
#  346845,
#  339681,
#  343628,
#  344765,
#  346380,
#  348948,
#  348401,
#  350373,
#  352669,
#  356047,
#  357766,
#  381542,
#  386290,
#  360348,
#  364205,
#  366733,
#  370479,
#  371211,
#  374399,
#  378417,
#  379517,
#  384685,
#  389766,
#  390209,
#  391750,
#  393264,
#  395385,
#  399741,
#  401080,
#  405133,
#  406484,
#  412173,
#  413225,
#  413414,
#  414553,
#  419512,
#  421394,
#  422282,
#  423645,
#  426131,
#  426539,
#  434714,
#  435459,
#  436586,
#  439462,
#  442013,
#  443994,
#  444915,
#  447651,
#  454626,
#  457269,
#  469089,
#  458967,
#  461801,
#  462136,
#  463751,
#  465819,
#  474411,
#  484945,
#  491173,
#  496337,
#  497096,
#  503154,
#  503666,
#  504956,
#  505159,
#  506060,
#  507911,
#  509105,
#  510652,
#  513597,
#  515344,
#  515868,
#  518513,
#  521984,
#  529861,
#  533133,
#  545691,
#  535026,
#  534058,
#  535426,
#  536536,
#  539571,
#  538164,
#  540435,
#  542516,
#  550981,
#  562598,
#  566135,
#  593420,
#  568591,
#  569725,
#  577049,
#  588290,
#  588705,
#  589746,
#  591313,
#  591881,
#  596004,
#  601794,
#  603962,
#  583510,
#  594965,
#  600321,
#  607594,
#  611278,
#  618846,
#  620695,
#  624661,
#  626652,
#  630730,
#  636920,
#  645662,
#  646601,
#  650976,
#  653391,
#  661527,
#  661708,
#  10190,
#  10620,
#  14066,
#  14903,
#  23242,
#  27186,
#  29027,
#  29165,
#  34040,
#  38971,
#  41058,
#  42402,
#  44523,
#  45639,
#  46493,
#  48040,
#  49590,
#  51401,
#  52053,
#  53331,
#  58236,
#  61012,
#  62256,
#  64021,
#  65450,
#  67488,
#  68050,
#  69478,
#  72747,
#  73450,
#  74129,
#  76162,
#  76698,
#  78179,
#  80867,
#  83028,
#  83515,
#  84639,
#  86949,
#  89711,
#  89122,
#  91593,
#  93870,
#  94149,
#  95535,
#  98950,
#  99359,
#  100082,
#  100903,
#  106626,
#  108590,
#  110713,
#  112428,
#  113163,
#  114578,
#  115278,
#  116989,
#  119574,
#  122858,
#  123722,
#  124949,
#  126688,
#  127151,
#  127975,
#  129732,
#  132823,
#  133421,
#  134295,
#  137030,
#  137716,
#  139970,
#  141866,
#  143216,
#  143538,
#  144369,
#  145466,
#  145939,
#  147159,
#  148112,
#  149150,
#  150490,
#  150523,
#  151185,
#  153132,
#  154844,
#  156782,
#  157693,
#  159957,
#  160461,
#  161201,
#  164616,
#  165070,
#  167114,
#  168072,
#  170007,
#  172864,
#  173677,
#  175301,
#  176232,
#  179743,
#  182019,
#  183262,
#  183916,
#  184827,
#  189563,
#  191961,
#  193439,
#  193557,
#  197142,
#  197400,
#  199254,
#  200846,
#  202041,
#  204591,
#  204907,
#  206046,
#  213132,
#  215093,
#  214520,
#  216361,
#  217961,
#  218331,
#  219095,
#  219638,
#  220475,
#  223506,
#  224539,
#  225807,
#  226307,
#  226569,
#  227198,
#  229899,
#  230670,
#  232109,
#  234284,
#  235449,
#  243953,
#  245189,
#  246318,
#  247797,
#  248993,
#  249451,
#  254747,
#  257224,
#  258080,
#  259248,
#  260197,
#  259901,
#  261878,
#  265419,
#  266844,
#  271139,
#  272901,
#  275990,
#  277937,
#  278835,
#  281484,
#  287551,
#  288437,
#  291144,
#  291913,
#  292292,
#  293174,
#  293972,
#  296062,
#  296752,
#  304701,
#  305937,
#  308326,
#  308893,
#  311699,
#  320202,
#  322192,
#  324339,
#  325679,
#  326438,
#  326611,
#  328930,
#  330213,
#  331878,
#  332415,
#  332991,
#  335130,
#  335892,
#  337847,
#  339223,
#  340325,
#  341628,
#  342489,
#  347244,
#  351723,
#  354048,
#  354922,
#  356466,
#  358620,
#  359330,
#  361818,
#  367195,
#  368249,
#  369101,
#  369589,
#  372810,
#  373953,
#  375521,
#  376979,
#  379933,
#  382936,
#  383508,
#  385080,
#  387749,
#  387878,
#  388594,
#  390871,
#  392049,
#  396426,
#  398803,
#  399255,
#  401681,
#  403508,
#  402091,
#  404499,
#  406860,
#  407919,
#  409801,
#  410030,
#  410615,
#  411171,
#  415077,
#  416592,
#  417145,
#  422675,
#  428231,
#  430435,
#  431490,
#  432322,
#  433298,
#  437590,
#  439297,
#  440370,
#  440589,
#  442790,
#  443318,
#  445863,
#  446302,
#  448829,
#  449300,
#  450130,
#  450751,
#  451714,
#  452682,
#  454191,
#  456017,
#  457441,
#  458282,
#  456390,
#  460176,
#  463258,
#  467018,
#  467939,
#  469897,
#  470971,
#  472143,
#  472837,
#  475313,
#  478242,
#  477380,
#  479715,
#  480293,
#  481360,
#  482511,
#  482803,
#  484337,
#  486263,
#  487917,
#  488586,
#  486785,
#  489325,
#  490118,
#  495747,
#  499371,
#  499985,
#  501294,
#  502321,
#  506887,
#  508645,
#  511259,
#  512827,
#  514552,
#  517111,
#  519195,
#  521249,
#  522780,
#  523718,
#  525097,
#  525715,
#  526011,
#  526889,
#  542089,
#  543799,
#  544947,
#  547802,
#  548856,
#  550295,
#  551549,
#  552502,
#  553019,
#  554334,
#  555338,
#  555693,
#  556885,
#  557984,
#  558839,
#  560343,
#  564480,
#  565453,
#  567541,
#  568338,
#  570802,
#  572330,
#  573222,
#  574748,
#  575830,
#  576335,
#  578833,
#  580474,
#  581901,
#  584629,
#  585594,
#  585771,
#  587398,
#  593916,
#  594702,
#  597311,
#  597779,
#  599006,
#  599478,
#  601231,
#  602913,
#  610249,
#  612248,
#  612716,
#  613576,
#  614987,
#  615639,
#  616635,
#  617592,
#  619619,
#  621130,
#  622040,
#  622722,
#  623739,
#  624490,
#  625414,
#  626911,
#  627811,
#  629478,
#  632225,
#  633349,
#  634405,
#  634965,
#  636348,
#  637814,
#  639002,
#  640618,
#  642243,
#  642879,
#  643346,
#  644837,
#  646100,
#  647959,
#  649084,
#  649649,
#  650265,
#  651870,
#  654689,
#  656620,
#  657360,
#  659151,
#  659375,
#  662830,
#  663440,
#  664749,
#  664508,
#  665369,
#  666361]

# %%
clean_lines[:1000]
# Out:
# ['1045  BIANCA  They do not!',
#  '1044  CAMERON  They do to!',
#  '985  BIANCA  I hope so.',
#  '984  CAMERON  She okay?',
#  "925  BIANCA  Let's go.",
#  '924  CAMERON  Wow',
#  "872  BIANCA  Okay -- you're gonna need to learn how to lie.",
#  '871  CAMERON  No',
#  '870  BIANCA  I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  '869  BIANCA  Like my fear of wearing pastels?',
#  '868  CAMERON  The "real you".',
#  '867  BIANCA  What good stuff?',
#  "866  CAMERON  I figured you'd get to the good stuff eventually.",
#  '865  CAMERON  Thank God!  If I had to hear one more story about your coiffure...',
#  "864  BIANCA  Me.  This endless ...blonde babble. I'm like, boring myself.",
#  '863  CAMERON  What crap?',
#  '862  BIANCA  do you listen to this crap?',
#  '861  CAMERON  No...',
#  '860  BIANCA  Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  '699  CAMERON  You always been this selfish?',
#  '698  BIANCA  But',
#  "697  CAMERON  Then that's all you had to say.",
#  '696  BIANCA  Well, no...',
#  "695  CAMERON  You never wanted to go out with 'me, did you?",
#  '694  BIANCA  I was?',
#  '693  CAMERON  I looked for you back at the party, but you always seemed to be "occupied".',
#  '663  BIANCA  Tons',
#  '662  CAMERON  Have fun tonight?',
#  '578  CAMERON  I believe we share an art instructor',
#  '577  BIANCA  You know Chastity?',
#  '576  CAMERON  Looks like things worked out tonight, huh?',
#  '575  BIANCA  Hi.',
#  "407  BIANCA  Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  "406  CAMERON  So that's the kind of guy she likes? Pretty ones?",
#  "405  BIANCA  Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "404  CAMERON  She's not a...",
#  "403  CAMERON  I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "402  BIANCA  I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  '401  CAMERON  Sure have.',
#  "368  BIANCA  Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  '367  CAMERON  How do you get your hair to look like that?',
#  "366  BIANCA  You're sweet.",
#  '365  CAMERON  You have my word.  As a gentleman',
#  "364  BIANCA  I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  '363  CAMERON  You got something on your mind?',
#  '281  BIANCA  Where?',
#  '280  CAMERON  There.',
#  "277  CAMERON  Well, there's someone I think might be --",
#  '276  BIANCA  How is our little Find the Wench A Date plan progressing?',
#  '275  BIANCA  Forget French.',
#  "274  CAMERON  That's because it's such a nice one.",
#  "273  BIANCA  I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "272  CAMERON  Right.  See?  You're ready for the quiz.",
#  "271  BIANCA  C'esc ma tete. This is my head",
#  '208  CAMERON  Let me see what I can do.',
#  '207  BIANCA  Gosh, if only we could find Kat a boyfriend...',
#  "206  CAMERON  That's a shame.",
#  '205  BIANCA  Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  '204  CAMERON  Why?',
#  '203  CAMERON  Seems like she could get a date easy enough...',
#  "202  BIANCA  The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  '201  CAMERON  Cameron.',
#  "200  BIANCA  No, no, it's my fault -- we didn't have a proper introduction ---",
#  '199  CAMERON  Forget it.',
#  "198  BIANCA  You're asking me out.  That's so cute. What's your name again?",
#  "197  CAMERON  Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  '196  BIANCA  Not the hacking and gagging and spitting part.  Please.',
#  "195  CAMERON  Well, I thought we'd start with pronunciation, if that's okay with you.",
#  '194  BIANCA  Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  '953  BIANCA  I did.',
#  "952  CHASTITY  You think you ' re the only sophomore at the prom?",
#  "660  CHASTITY  I don't have to be home 'til two.",
#  '659  BIANCA  I have to be home in twenty minutes.',
#  "600  CHASTITY  All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "599  BIANCA  Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "598  CHASTITY  Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "597  BIANCA  Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  '596  CHASTITY  Is he oily or dry?',
#  "595  BIANCA  He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  '580  BIANCA  Would you mind getting me a drink, Cameron?',
#  '579  CHASTITY  Great',
#  '573  BIANCA  Joey.',
#  '572  CHASTITY  Who?',
#  '571  BIANCA  Where did he go?  He was just here.',
#  '51  BIANCA  You might wanna think about it',
#  '50  CHASTITY  No.',
#  '49  BIANCA  Did you change your hair?',
#  "760  BIANCA  You know the deal.  I can ' t go if Kat doesn't go --",
#  '759  JOEY  Listen, I want to talk to you about the prom.',
#  "758  JOEY  You're concentrating awfully hard considering it's gym class.",
#  '757  BIANCA  Hi, Joey.',
#  '756  JOEY  Hey, sweet cheeks.',
#  "593  JOEY  My agent says I've got a good shot at being the Prada guy next year.",
#  '592  BIANCA  Neat...',
#  "591  JOEY  It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  '590  BIANCA  Queen Harry?',
#  '589  JOEY  So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  '397  BIANCA  Hopefully.',
#  "396  JOEY  Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  '395  BIANCA  Expensive?',
#  "394  JOEY  It's more",
#  '1052  KAT  Perm?',
#  '1051  BIANCA  Patrick -- is that- a.',
#  "1022  KAT  It's just you.",
#  '1021  BIANCA  Is that woman a complete fruit-loop or is it just me?',
#  '1011  BIANCA  No! I just wanted',
#  '1010  KAT  What? To completely damage me?  To send me to therapy forever? What?',
#  '1009  BIANCA  I just wanted --',
#  '1008  KAT  You set me up.',
#  '1007  BIANCA  Let go!',
#  '983  KAT  So did you',
#  '982  BIANCA  You looked beautiful last night, you know.',
#  "914  BIANCA  I guess I'll never know, will I?",
#  "913  KAT  Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "912  BIANCA  God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  '911  KAT  I guess I thought I was protecting you.',
#  "910  BIANCA  I'm not stupid enough to repeat your mistakes.",
#  "909  KAT  That's not",
#  "908  BIANCA  No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  '907  KAT  I wanted to let you make up your own mind about him.',
#  "906  BIANCA  Why didn't you tell me?",
#  '905  KAT  After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  '904  BIANCA  But',
#  "903  KAT  Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  '902  BIANCA  You did what?',
#  '901  KAT  He said everyone was doing it.  So I did it.',
#  '900  BIANCA  As in...',
#  '899  KAT  Now I do.  Back then, was a different story.',
#  '898  BIANCA  But you hate Joey',
#  '897  KAT  He was, like, a total babe',
#  '896  BIANCA  Why?',
#  '895  KAT  In 9th.  For a month',
#  '894  BIANCA  What?',
#  '893  KAT  Joey never told you we went out, did he?',
#  "892  BIANCA  I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  "891  KAT  I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  '890  BIANCA  Like you care.',
#  "889  KAT  Listen, I know you hate having to sit home because I'm not Susie High School.",
#  "656  KAT  You're welcome.",
#  "655  BIANCA  I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "602  BIANCA  I really don't think I need any social advice from you right now.",
#  '601  KAT  Bianca, I need to talk to you -- I need to tell you --',
#  '543  KAT  Can we go now?',
#  '542  BIANCA  You are so completely unbalanced.',
#  "533  BIANCA  Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  "532  KAT  It's Shakespeare.  Maybe you've heard of him?",
#  "531  BIANCA  Like I'm supposed to know what that even means.",
#  "530  KAT  At least I'm not a clouted fen- sucked hedge-pig.",
#  "529  BIANCA  Can't you forget for just one night that you're completely wretched?",
#  "527  BIANCA  Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "526  KAT  What's normal?",
#  "525  BIANCA  You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "445  BIANCA  I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  '444  KAT  What do you think?',
#  "443  BIANCA  Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  "442  KAT  It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "441  BIANCA  Oh my God, does this mean you're becoming normal?",
#  '320  BIANCA  Can you at least start wearing a bra?',
#  "319  KAT  I have the potential to smack the crap out of you if you don't get out of my way.",
#  '165  BIANCA  Nowhere... Hi, Daddy.',
#  "164  KAT  Where've you been?",
#  "923  BIANCA  I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "922  WALTER  I'm missing something.",
#  "884  BIANCA  Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "883  WALTER  You're not going unless your sister goes.  End of story.",
#  '882  BIANCA  He\'s not a "hot rod".  Whatever that is.',
#  "881  WALTER  It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  '880  BIANCA  No, but',
#  '879  WALTER  The prom?  Kat has a date?',
#  "878  BIANCA  Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  "546  WALTER  Because she'll scare them away.",
#  '545  BIANCA  Why?',
#  "544  WALTER  Promise me you won't talk to any boys unless your sister is present.",
#  '540  WALTER  Just for a minute',
#  '539  BIANCA  Daddy, no!',
#  '538  WALTER  Wear the belly before you go.',
#  "537  BIANCA  It's just a party. Daddy.",
#  "536  WALTER  Oh, God.  It's starting.",
#  "524  WALTER  If Kat's not going, you're not going.",
#  '523  BIANCA  Daddy, people expect me to be there!',
#  '521  BIANCA  It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  '520  WALTER  Otherwise known as an orgy?',
#  '519  BIANCA  If you must know, we were attempting to go to a small study group of friends.',
#  "518  WALTER  And where're you going?",
#  '517  BIANCA  Daddy, I --',
#  '190  WALTER  Exactly my point',
#  "189  BIANCA  But she doesn't want to date.",
#  "183  BIANCA  But it's not fair -- she's a mutant, Daddy!",
#  "182  WALTER  Then neither will you.  And I'll get to sleep at night.",
#  '181  BIANCA  What if she never starts dating?',
#  "180  WALTER  No! You're not dating until your sister starts dating.  End of discussion.",
#  "179  BIANCA  Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "463  BRUCE  Just sent 'em through.",
#  '462  PATRICK  Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  '461  BRUCE  Never',
#  '460  PATRICK  Fan of a fan.  You see a couple of minors come in?',
#  "459  BRUCE  Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  '458  PATRICK  Always a pleasure, Brucie.',
#  "779  MICHAEL  Best case scenario, you're back on the payroll for awhile.",
#  '778  CAMERON  You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  "586  CAMERON  No, I ' m not.",
#  "585  MICHAEL  Buttholus extremus.  But hey, you're making progress.",
#  "584  CAMERON  The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  '583  MICHAEL  Extremely unfortunate maneuver.',
#  "500  CAMERON  Hell, I've just been going over the whole thing in my head and -",
#  '499  MICHAEL  You told me that part already.',
#  "433  CAMERON  It's her favorite band.",
#  '432  MICHAEL  Assail your ears for one night.',
#  "425  CAMERON  Okay!  I wasn't sure",
#  "424  MICHAEL  He's pretty!",
#  '419  MICHAEL  Dead at forty-one.',
#  '418  CAMERON  Her favorite uncle',
#  "417  MICHAEL  It's a lung cancer issue",
#  '416  CAMERON  Number one.  She hates smokers',
#  "391  MICHAEL  Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  '390  CAMERON  Will Bogey get bent?',
#  "389  MICHAEL  In that case, we'll need to make it a school-wide blow out.",
#  '388  CAMERON  This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "245  MICHAEL  Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  '244  CAMERON  You got him involved?',
#  "225  MICHAEL  Hey -- I've gotta have a few clients when I get to Wall Street.",
#  '224  CAMERON  I thought you hated those people.',
#  "223  MICHAEL  You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  "222  CAMERON  That's what I just said",
#  "221  MICHAEL  Did she actually say she'd go out with you?",
#  "220  CAMERON  Forget his reputation.  Do you think we've got a plan or not?",
#  "219  MICHAEL  I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  '218  CAMERON  They always let felons sit in on Honors Biology?',
#  "217  MICHAEL  No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  '216  CAMERON  He seems like he thrives on danger',
#  "215  MICHAEL  What makes you think he'll do it?",
#  '213  MICHAEL  You wanna go out with him?',
#  '212  CAMERON  What about him?',
#  "211  MICHAEL  Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  '210  CAMERON  I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  '159  MICHAEL  The mewling, rampalian wretch herself.',
#  "158  CAMERON  That's her?  Bianca's sister?",
#  '157  MICHAEL  Yeah, just a minor encounter with the shrew.',
#  '147  MICHAEL  You could consecrate with her, my friend.',
#  "146  CAMERON  You mean I'd get a chance to talk to her?",
#  '145  MICHAEL  Guess who just signed up for a tutor?',
#  "144  CAMERON  Sure do ... my Mom's from Canada",
#  '143  MICHAEL  You know French?',
#  "142  MICHAEL  Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  '141  CAMERON  He always have that shit-eating grin?',
#  "140  MICHAEL  Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  '139  CAMERON  Why do girls like that always like guys like that?',
#  "92  MICHAEL  I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  '91  CAMERON  Why not?',
#  "90  MICHAEL  Bianca Stratford.  Sophomore. Don't even think about it",
#  '89  CAMERON  Who is she?',
#  '88  MICHAEL  You burn, you pine, you perish?',
#  '87  CAMERON  That girl -- I --',
#  '78  MICHAEL  Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  "77  CAMERON  That I'm used to.",
#  '74  MICHAEL  Couple thousand. Most of them evil',
#  '73  CAMERON  How many people go here?',
#  '72  MICHAEL  Get out!',
#  '71  CAMERON  Thirty-two.',
#  '70  MICHAEL  How many people were in your old school?',
#  "69  CAMERON  Yeah.  A couple.  We're outnumbered by the cows, though.",
#  '68  MICHAEL  I was kidding. People actually live there?',
#  "67  CAMERON  North, actually.  How'd you   ?",
#  '66  MICHAEL  So -- which Dakota you from?',
#  "65  MICHAEL  C'mon.  I'm supposed to give you the tour.",
#  '64  CAMERON  So they tell me...',
#  '63  MICHAEL  You the new guy?',
#  '781  CAMERON  You get the girl.',
#  "780  PATRICK  What's the worst?",
#  '745  PATRICK  Where?',
#  '744  CAMERON  She kissed me.',
#  "743  PATRICK  You makin' any headway?",
#  "741  PATRICK  She just needs time to cool off I'll give it a day.",
#  "740  CAMERON  She hates you with the fire of a thousand suns .  That's a direct quote",
#  "726  PATRICK  I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "725  CAMERON  What'd you do to her?",
#  '625  PATRICK  Then, go get her',
#  '624  CAMERON  Sure',
#  '623  PATRICK  Cameron -- do you like the girl?',
#  "622  CAMERON  She's partial to Joey, not me",
#  "621  PATRICK  What 're you talking about?",
#  "620  CAMERON  It's off. The whole thing.",
#  "619  PATRICK  Cameron, I'm a little busy",
#  "431  PATRICK  Don't make me do it, man",
#  '430  CAMERON  Gigglepuss is playing there tomorrow night.',
#  "427  PATRICK  So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  '426  CAMERON  Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  "412  CAMERON  I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "411  PATRICK  What've you got for me?",
#  "386  PATRICK  Yeah -- we'll see.",
#  '385  CAMERON  And he means that strictly in a non- prison-movie type of way.',
#  '558  JOEY  And why would I do that?',
#  '557  KAT  Leave my sister alone.',
#  '556  JOEY  Your sister here?',
#  '555  KAT  Away.',
#  '554  JOEY  Where ya goin?',
#  '336  JOEY  Not at all',
#  '335  KAT  Hey -- do you mind?',
#  "150  JOEY  They're running the rest of me next month.",
#  '149  KAT  Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "148  JOEY  The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  "748  JOEY  Enough with the Barbie n' Ken shit. I know.",
#  "747  PATRICK  I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  '609  JOEY  Get her to act like a human',
#  '608  PATRICK  Do what?',
#  "607  JOEY  How'd you do it?",
#  "606  JOEY  A deal's a deal.",
#  "605  PATRICK  It's about time.",
#  '358  PATRICK  Forget her sister, then.',
#  '357  JOEY  Forget it.',
#  '356  PATRICK  A hundred bucks a date.',
#  '355  JOEY  What?',
#  '354  PATRICK  I just upped my price',
#  '352  PATRICK  I got her under control. She just acts crazed in public to keep up the image.',
#  "351  JOEY  Watching the bitch trash my car doesn't count as a date.",
#  "350  PATRICK  I'm on it",
#  '349  JOEY  When I shell out fifty, I expect results.',
#  "301  PATRICK  Fifty, and you've got your man.",
#  "300  JOEY  Take it or leave it.  This isn't a negotiation.",
#  '299  JOEY  Fine, thirty.',
#  "298  PATRICK  I can't take a girl like that out on twenty bucks.",
#  '297  PATRICK  How much?',
#  "296  JOEY  I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "295  PATRICK  You're gonna pay me to take out some girl?",
#  '294  JOEY  You got it, Verona.  I pick up the tab, you do the honors.',
#  "292  JOEY  But you'd go out with her if you had the cake?",
#  '291  PATRICK  You need money to take a girl out',
#  '290  JOEY  You just said',
#  "289  PATRICK  Sure, Sparky.  I'll get right on it.",
#  '288  JOEY  Yeah, whatever.  I want you to go out with her.',
#  '287  PATRICK  Two legs, nice rack...',
#  '286  JOEY  What do you think?',
#  '285  PATRICK  Yeah',
#  "509  MICHAEL  Hey -- it's all for the higher good right?",
#  "508  JOEY  You better not fuck this up.  I'm heavily invested.",
#  '505  MICHAEL  What?  We took bathes together when we were kids.',
#  '504  JOEY  You and Verona?',
#  "503  MICHAEL  Uh,  yeah.  We're old friend*",
#  "502  JOEY  I hear you're helpin' Verona.",
#  "240  MICHAEL  So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  '239  JOEY  Does this conversation have a purpose?',
#  "238  MICHAEL  But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  "236  JOEY  We're not.",
#  "235  MICHAEL  Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "234  JOEY  We don't chat.",
#  '233  MICHAEL  Nope - just came by to chat',
#  '232  JOEY  Are you lost?',
#  '231  MICHAEL  Hey.',
#  "949  KAT  Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  '948  MANDELLA  William - he asked me to meet him here.',
#  '947  KAT  Who?',
#  '946  MANDELLA  Have you seen him?',
#  '755  MANDELLA  Oh, good.  Something new and different for us.',
#  "754  KAT  You ' re looking at this from the wrong perspective.  We're making a statement.",
#  "753  MANDELLA  Okay, okay, we won't go.  It's not like I have a dress anyway",
#  '752  KAT  Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "751  MANDELLA  Well, I guess we're not, since we don't have dates .",
#  '750  KAT  Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  '721  KAT  I got drunk.  I puked.  I got rejected. It was big fun.',
#  "720  MANDELLA  You didn't",
#  '719  KAT  I did Bianca a favor and it backfired.',
#  "718  MANDELLA  You didn't have a choice?  Where's Kat and what have you done with her?",
#  "717  KAT  I didn't have a choice.",
#  '716  MANDELLA  You went to the party?  I thought we were officially opposed to suburban social activity.',
#  '491  KAT  Who cares?',
#  "490  MANDELLA  What'd he say?",
#  '448  KAT  No fear.',
#  "447  MANDELLA  You think this'll work?",
#  '254  KAT  If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  '253  MANDELLA  Does it matter?',
#  "252  KAT  I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  '251  KAT  Neither has his heterosexuality.',
#  "250  MANDELLA  That's never been proven",
#  "249  KAT  William didn't even go to high school",
#  '248  MANDELLA  William would never have gone to a state school.',
#  '247  KAT  So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  "152  MANDELLA  You could always go with me.  I'm sure William has some friends.",
#  '151  KAT  The people at this school are so incredibly foul.',
#  "134  MANDELLA  But imagine the things he'd say during sex.",
#  "133  KAT  I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  '132  MANDELLA  An attempted slit.',
#  "131  KAT  What's this?",
#  '130  MANDELLA  Just a little.',
#  '129  KAT  Mandella, eat.  Starving yourself is a very slow way to die.',
#  '128  KAT  Block E?',
#  '127  MANDELLA  He always look so',
#  "126  KAT  I'm sure he's completely incapable of doing anything that interesting.",
#  "125  MANDELLA  That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  '124  KAT  Patrick Verona   Random skid.',
#  "123  MANDELLA  Who's that?",
#  "1043  PATRICK  Don ' t you even dare. . .",
#  '1042  KAT  Oh, Bianca?  Can you get me my freshman yearbook?',
#  '1041  PATRICK  Because I like to torture you.',
#  '1040  KAT  Why is my veggie burger the only burnt object on this grill?',
#  '1035  PATRICK  Yeah, but then I fucked up. I fell for her.',
#  '1034  KAT  Is that right?',
#  '1033  PATRICK  Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  '1032  PATRICK  I thought you could use it. When you start your band.',
#  '1031  KAT  A Fender Strat. You bought this?',
#  "977  PATRICK  I didn't care about the money.",
#  '976  KAT  Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "975  PATRICK  It wasn't like that.",
#  '974  KAT  You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  '973  PATRICK  Wait I...',
#  '961  PATRICK  It gets worse -- you still have your freshman yearbook?',
#  "960  KAT  That ' s completely adorable!",
#  "959  PATRICK  That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  '958  KAT  What?',
#  "957  PATRICK  My grandmother's .",
#  "940  KAT  Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  '939  PATRICK  Oh huh',
#  "938  KAT  It's just something I had.  You know",
#  "937  PATRICK  It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "936  KAT  How'd you get a tux at the last minute?",
#  "857  PATRICK  Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  '856  KAT  Answer the question, Patrick',
#  '855  PATRICK  You need therapy.  Has anyone ever told you that?',
#  '854  KAT  You tell me.',
#  '853  PATRICK  So I have to have a motive to be with you?',
#  '852  KAT  Create a little drama?  Start a new rumor?  What?',
#  "848  KAT  Because I don't want to. It's a stupid tradition.",
#  '847  PATRICK  Why not?',
#  "846  KAT  No, I won't go with you",
#  '845  PATRICK  No what?',
#  '844  KAT  No.',
#  '843  PATRICK  You know what I mean',
#  '842  KAT  Is that a request or a command?',
#  '841  PATRICK  Go to the prom with me',
#  "840  KAT  You're amazingly self-assured. Has anyone ever told you that?",
#  '839  PATRICK  No one else knows',
#  '838  KAT  What?',
#  "837  PATRICK  You're sweet.  And sexy.  And completely hot for me.",
#  '836  KAT  No -- something real.  Something no one else knows.',
#  '835  PATRICK  I hate peas.',
#  '834  KAT  Tell me something true.',
#  "832  KAT  I know the porn career's a lie.",
#  '831  PATRICK  Hearsay.',
#  '830  KAT  The duck?',
#  '829  PATRICK  Fallacy.',
#  '828  KAT  State trooper?',
#  '825  KAT  For. . . ?',
#  '824  PATRICK  You up for it?',
#  '823  PATRICK  You never disappointed me.',
#  '822  KAT  How?',
#  '821  PATRICK  Then you screwed up',
#  '820  KAT  Something like that',
#  "819  PATRICK  So if you disappoint them from the start, you're covered?",
#  "818  KAT  I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  '817  PATRICK  Yes',
#  '816  KAT  Acting the way we do.',
#  "815  PATRICK  So what's your excuse?",
#  "814  KAT  Yeah, well, don't let it get out",
#  '813  PATRICK  A soft side? Who knew?',
#  '812  KAT  I dazzled him with my wit',
#  "811  PATRICK  So how'd you get Chapin to look the other way?",
#  '810  KAT  Good call.',
#  '809  PATRICK  I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  '808  KAT  The Partridge Family?',
#  '806  PATRICK  Maybe.',
#  '805  KAT  You want me to climb up and show you how to get down?',
#  "804  PATRICK  Forget it.  I'm stayin'.",
#  '803  KAT  Put your right foot there --',
#  "802  PATRICK  Try lookin' at it from this angle",
#  "801  KAT  C'mon.  It's not that bad",
#  "800  PATRICK  I guess I never told you I'm afraid of heights.",
#  '799  PATRICK  Look up, sunshine',
#  '798  KAT  He left!  I sprung the dickhead and he cruised on me.',
#  '774  KAT  Other than my upchuck reflex? Nothing.',
#  '773  PATRICK  So what did I have an effect on ?',
#  "772  KAT  Don't for one minute think that you had any effect whatsoever on my panties.",
#  '771  PATRICK  Unwelcome?  I guess someone still has her panties in a twist.',
#  '770  KAT  Unwelcome.',
#  '769  PATRICK  Wholesome.',
#  '768  PATRICK  Pleasant?',
#  "767  KAT  You 're so --",
#  '766  PATRICK  I heard there was a poetry reading.',
#  '765  KAT  What are you doing here?',
#  '764  PATRICK  Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  "690  PATRICK  No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  '689  KAT  BIANCA',
#  '688  PATRICK  Who?',
#  "687  KAT  He just wants me to be someone I'm not.",
#  "686  PATRICK  So what ' s up with your dad?  He a pain in the ass?",
#  "684  PATRICK  I'm gettin' there",
#  '683  KAT  Oh, so now you think you know me?',
#  "682  PATRICK  You don't strike me as the type that would ask permission.",
#  "681  KAT  My father wouldn't approve of that that",
#  '680  PATRICK  Start a band?',
#  '679  KAT  This.',
#  '678  PATRICK  Do what?',
#  '677  KAT  I should do this.',
#  "676  KAT  Why'd you lie?",
#  "675  PATRICK  Then why'd you ask?",
#  "674  KAT  No, you weren't",
#  '673  PATRICK  Maybe.',
#  '672  KAT  Were you in jail?',
#  '671  PATRICK  Busy',
#  '670  KAT  When you were gone last year -- where were you?',
#  "669  KAT  But it's Gigglepuss - I know you like them.  I saw you there.",
#  "668  PATRICK  And I'm in control of it.",
#  '651  KAT  What?',
#  '650  PATRICK  Kat! Wake up!',
#  '646  KAT  You know what they say',
#  '645  PATRICK  I thought you were above all that',
#  '644  KAT  Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  "643  PATRICK  I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  '642  KAT  I hate him.',
#  '641  PATRICK  Dorsey.',
#  '640  KAT  Who?',
#  "639  PATRICK  Why'd you let him get to you?",
#  '636  KAT  Just let me sit down.',
#  "635  PATRICK  See that?  Who needs affection when I've got blind hatred?",
#  '634  KAT  Like you could find one',
#  "633  PATRICK  Because then I'd have to start taking out girls who like me.",
#  '632  KAT  Why?',
#  '631  PATRICK  Sure, I do',
#  "630  KAT  You don't care if I die",
#  '629  PATRICK  I told you',
#  "628  KAT  Why 're you doing this?",
#  "627  PATRICK  Leave it to you to use big words when you're shitfaced.",
#  '626  KAT  This is so patronizing.',
#  '616  PATRICK  What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...',
#  '615  KAT  I know, just let me sleep',
#  "614  PATRICK  Uh, uh. You lie down and you'll go to sleep",
#  '613  KAT  I just need to lie down for awhile',
#  "612  PATRICK  You're not okay.",
#  "611  KAT  I'm fine. I'm",
#  '610  PATRICK  Okay?',
#  "567  KAT  Funny, you're the only one",
#  '566  PATRICK  I say, do what you wanna do.',
#  '565  KAT  "I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  "564  PATRICK  What's this?",
#  "483  PATRICK  Why, don't you?",
#  '482  KAT  You know who The Raincoats are?',
#  "481  PATRICK  You know, these guys are no Bikini Kill or The Raincoats, but they're right up there.",
#  "477  PATRICK  Do you mind?  You're sort of ruining it for me.",
#  "476  KAT  That's what you want, isn't it?",
#  '475  PATRICK  Excuse me?',
#  '474  KAT  ',
#  '473  PATRICK  hey.  Great show, huh?',
#  "334  KAT  Depends on the topic. My fenders don't really whip me into a verbal frenzy.",
#  "333  PATRICK  You're not a big talker, are you?",
#  '332  KAT  Hi',
#  "331  PATRICK  I was in the laundromat. I saw your car. Thought I'd say hi.",
#  '330  KAT  Are you following me?',
#  '328  PATRICK  Seven-thirty?',
#  '327  KAT  You -- covered in my vomit.',
#  '326  PATRICK  Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  '325  KAT  And why would I do that?',
#  "324  PATRICK  Then say you'll spend Dollar Night at the track with me.",
#  "323  KAT  I don't really think you warrant that strong an emotion.",
#  "322  PATRICK  You hate me don't you?",
#  '313  PATRICK  I know a lot more than that',
#  '312  KAT  Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  "311  PATRICK  The night I take you to places you've never been before.  And back.",
#  '310  KAT  Oh, right.  Friday.',
#  '309  PATRICK  Pick you up Friday, then',
#  '307  KAT  My mission in life.',
#  "306  PATRICK  There's a way to get a guy's attention.",
#  '305  KAT  Sweating like a pig, actually.  And yourself?',
#  "304  PATRICK  I mean Wo-man.  How ya doin'?",
#  "1000  WALTER  Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check.",
#  '999  KAT  When I go?',
#  "998  WALTER  You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game.",
#  '997  WALTER  No -- impressed.',
#  "996  KAT  What's the matter?  Upset that I rubbed off on her?",
#  '995  WALTER  Bianca did what?',
#  '994  KAT  The part where Bianca beat the hell out of some guy.',
#  '993  WALTER  Which parts?',
#  '992  KAT  Parts of it.',
#  '991  WALTER  So tell me about this dance. Was it fun?',
#  '990  KAT  No, Daddy.',
#  "989  WALTER  I don't understand the allure of dehydrated food.  Is this something I should be hip to?",
#  '988  WALTER  Funny.',
#  '987  KAT  Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  '986  WALTER  Was that your sister?',
#  '347  KAT  I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --',
#  "346  WALTER  You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  "345  KAT  So what I want doesn't matter?",
#  "344  WALTER  As a parent, that's my right",
#  "343  KAT  Because you're making decisions for me.",
#  "342  WALTER  Why can't we agree on this?",
#  '341  KAT  I thought you were punishing me.',
#  '340  WALTER  Is this about Sarah Lawrence? You punishing me?',
#  '339  KAT  Then tell them I had a seizure.',
#  '338  WALTER  My insurance does not cover PMS',
#  '185  WALTER  Enough!',
#  '184  KAT  This from someone whose diary is devoted to favorite grooming tips?',
#  '174  KAT  You decided.',
#  '173  WALTER  I thought we decided you were going to school here.  At U of 0.',
#  '172  KAT  I know.',
#  '1018  MISS PERKY  Just smack her now.',
#  '1017  KAT  Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?',
#  '109  MISS PERKY  No ... I believe "heinous bitch" is the term used most often.',
#  '108  KAT  Tempestuous?',
#  '107  MISS PERKY  The point is Kat -- people perceive you as somewhat ...',
#  '106  KAT  I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  "105  MISS PERKY  Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  '104  KAT  Expressing my opinion is not a terrorist action.',
#  "103  MISS PERKY  Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#  '738  MANDELLA  Yeah...',
#  '737  MICHAEL  Kat a fan, too?',
#  '736  MANDELLA  Right.',
#  '735  MICHAEL  Macbeth, right?',
#  '733  MICHAEL  Oh yeah.',
#  '732  MANDELLA  You think?',
#  '731  MANDELLA  Yeah.  I guess.',
#  '730  MICHAEL  Cool pictures.  You a fan?',
#  '729  MANDELLA  Hi.',
#  '728  MICHAEL  Hey there.  Tired of breathing?',
#  "777  PATRICK  Man -- don't say shit like that to  me. People can hear you.",
#  '776  MICHAEL  Sweet love, renew thy force!',
#  "775  PATRICK  You were right. She's still pissed.",
#  "724  PATRICK  No - I've got a sweet-payin' job that I'm about to lose.",
#  '723  MICHAEL  So you got cozy with she who stings?',
#  "437  PATRICK  I'm likin' you guys better",
#  '436  MICHAEL  I prefer to think of it simply as an alternative to what the law allows.',
#  '429  PATRICK  Yeah.',
#  '428  MICHAEL  Ever been to Club Skunk?',
#  '421  MICHAEL  Just for now.',
#  '420  PATRICK  Are you telling me I\'m a -  "non-smoker"?',
#  '415  MICHAEL  Good enough.',
#  '414  PATRICK  What?!',
#  "384  MICHAEL  We're your guys.",
#  '383  PATRICK  You two are gonna help me tame the wild beast?',
#  "382  MICHAEL  Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl.",
#  '381  PATRICK  So Dorsey can get the girl?',
#  "380  MICHAEL  That's where we can help you.  With Kat.",
#  "379  PATRICK  Dorsey can plow whoever he wants. I'm just in this for the cash.",
#  "378  MICHAEL  I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's.",
#  '377  PATRICK  What is it with this chick?  She have three tits?',
#  '376  MICHAEL  The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  '375  PATRICK  What plan?',
#  "373  PATRICK  Whatever the hell it is you're standin' there waitin' to say.",
#  '372  MICHAEL  What?',
#  '371  PATRICK  Say it',
#  '512  PATRICK  See you next week!',
#  "511  MISS PERKY  You're completely demented.",
#  "264  PATRICK  Well, you know -- there's the prestige of the job title... and the benefits package is pretty good...",
#  "263  MISS PERKY  You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  "262  PATRICK  What's to discuss?",
#  "261  MISS PERKY  Why don't we discuss your driving need to be a hemorrhoid?",
#  "259  MISS PERKY  I'm at a loss, then.  What should we talk about? Your year of absence?",
#  '258  PATRICK  Touch of the flu.',
#  "257  MISS PERKY  I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#  '62  MISS PERKY  With the teeth of your zipper?',
#  '61  PATRICK  It was a bratwurst.  I was eating lunch.',
#  '60  MISS PERKY  It says here you exposed yourself to a group of freshmen girls.',
#  '59  PATRICK  I missed you.',
#  "933  WALTER  That ' s what I thought",
#  '932  SHARON  Absolutely not.',
#  '931  WALTER  Did I have anything to say about it?',
#  '930  SHARON  Your daughters went to the prom.',
#  '929  WALTER  What just happened?',
#  '927  WALTER  But -- who -- what --?',
#  '926  SHARON  Have a great time, honey!',
#  '918  SHARON  Dr. Ruth?',
#  "917  WALTER  What do you wanna watch?  We've got crap, crap, crap or crap",
#  "887  WALTER  Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  "886  SHARON  They'll dance, they'll kiss, they'll come home.  Let her go.",
#  '877  WALTER  Pirate -- no question.',
#  '876  SHARON  Would you rather be ravished by a pirate or a British rear admiral?',
#  "193  WALTER  You're not helping.",
#  '192  SHARON  Tumescent!',
#  '191  WALTER  Jesus!  Can a man even grab a sandwich before you women start dilating?',
#  '171  WALTER  Sarah Lawrence is on the other side of the country.',
#  "170  SHARON  What's a synonym for throbbing?",
#  '162  WALTER  Make anyone cry today?',
#  '161  SHARON  In the microwave.',
#  "2181  ALONSO  Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign...",
#  "2180  SAILOR  We left three weeks ago, Alonso. Can't be that near.",
#  '2179  ALONSO  We should have seen land.',
#  "2177  SAILOR  We'll all go crazy...",
#  "2176  ALONSO  He's the devil's child...",
#  "2175  ALONSO  With a face like that?  I don't want you looking at me.  You hear?",
#  "2174  SAILOR  Ah, leave him alone.  He's doing no harm.",
#  '2173  ALONSO  What are you listening to, chicken ass?',
#  "2172  ALONSO  You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!",
#  "2171  SAILOR  The water's going putrid in the barrels.",
#  '2170  ALONSO  I never seen heat like this!  Not even in Las Minas!',
#  '2025  AROJAZ  IF-GOD-WILLS-IT!',
#  '2024  COLUMBUS  Asia can be found to the west -- and I will prove it.',
#  '2023  COLUMBUS  Blind faith is what I consider heresy!',
#  "2022  AROJAZ  Don't you realize your words could be considered heretical?",
#  "2020  COLUMBUS  Did He not choose a carpenter's son to reveal Himself to the world?",
#  '2019  AROJAZ  If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?',
#  '2016  COLUMBUS  No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.',
#  '2015  AROJAZ  Is that all that interests you? Gold?',
#  '2014  COLUMBUS  Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.',
#  '2012  COLUMBUS  If they agree to follow me, yes.',
#  '2011  AROJAZ  Your life, and that of others!',
#  '2010  COLUMBUS  Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.',
#  '2006  COLUMBUS  Excellency, you are right.',
#  '2005  AROJAZ  Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.',
#  '1993  AROJAZ  Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.',
#  '1992  COLUMBUS  I am, Your Eminence',
#  '1991  AROJAZ  Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  '1990  COLUMBUS  Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  '1989  AROJAZ  You say Asia can be found by sailing west?',
#  '2524  SANCHEZ  A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.',
#  '2523  AROJAZ  What a tragedy... what a waste of a life...',
#  '2522  SANCHEZ  You can see for yourself.',
#  '2275  SANCHEZ  On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.',
#  "2274  AROJAZ  It won't be easy to get rid of your prophet now, Don Sanchez.",
#  '2031  SANCHEZ  Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.',
#  '2030  AROJAZ  He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?',
#  '2029  SANCHEZ  Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.',
#  '2028  AROJAZ  The Judgment is ours!',
#  "2027  SANCHEZ  The State has some reason to be interested in this man's proposition, Your Eminence...",
#  "2540  COLUMBUS  I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you.",
#  '2539  BEATRIX  What is it, now?  Tell me...',
#  '2538  BEATRIX  I am busy inside.',
#  "2537  COLUMBUS  Can't you stay with us a little?",
#  "2474  COLUMBUS  Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier...",
#  '2473  BEATRIX  They took everything...',
#  "2472  BEATRIX  They tried... but I didn't let them.",
#  "2471  COLUMBUS  God... you're so beautiful!  I can't believe no other man has ever taken you away from me...",
#  '2320  COLUMBUS  I can arrange for the Queen to take Fernando and Diego into her service.',
#  "2319  BEATRIX  You don't usually ask.",
#  '2318  COLUMBUS  Beatrix, I want to ask you something.',
#  "2123  BEATRIX  That's something you can't decide.",
#  "2122  COLUMBUS  I don't want you to wait for me.",
#  "2121  BEATRIX  I'm not asking you to swear to anything.",
#  '2119  BEATRIX  Thank God...',
#  '2118  COLUMBUS  She said yes.',
#  '1986  BEATRIX  I find that hard to believe.',
#  '1985  COLUMBUS  Perhaps I was never meant to live with a woman...',
#  "1984  BEATRIX  I'd love to argue with you sometimes.  But you're never here!",
#  '1983  COLUMBUS  Are we going to argue?',
#  "1982  BEATRIX  Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  "1981  COLUMBUS  I haven't given you much of a life.",
#  '1980  BEATRIX  I know.',
#  '1979  COLUMBUS  I could be gone for years.',
#  '2432  BOBADILLA  I am afraid this is not the worst news.',
#  '2431  COLUMBUS  How could I be?  The mainland has been found.  Exactly as I said it would.',
#  '2430  BOBADILLA  I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  '2429  COLUMBUS  How far from here?',
#  '2426  COLUMBUS  Congratulations.  Then I am free to search for the mainland.',
#  '2425  BOBADILLA  Viceroy of the West Indies.',
#  '2424  COLUMBUS  Appointment to what?',
#  '2423  BOBADILLA  My letters of appointment.',
#  '2422  COLUMBUS  Yes... I remember...',
#  '2421  BOBADILLA  Don Alonso de Bobadilla.',
#  '2293  COLUMBUS  Bartolome and Giacomo Colon.',
#  '2292  BOBADILLA  May I ask by whom?',
#  '2291  COLUMBUS  Forgive me, Don Bobadilla -- those positions have already been taken.',
#  '2290  BOBADILLA  I understand that you will soon be appointing Governors for the islands?  Is it not so?',
#  '2552  FERNANDO  Tell me the first thing that comes to your mind.',
#  "2551  COLUMBUS  Really?  God... I wouldn't know where to start... and yet...",
#  '2550  FERNANDO  I want you to tell me everything you remember, Father.  From the beginning.  Everything.',
#  '2549  COLUMBUS  He never had one... except aboard my ships!',
#  '2548  FERNANDO  He asks when he can come to visit you.  He left his address.',
#  '2547  COLUMBUS  What does he say?',
#  "2542  FERNANDO  I am not listening, Father.  But I can't help hearing.",
#  '2541  COLUMBUS  What are you listening to?',
#  '2501  COLUMBUS  There must be a passage to that other ocean.',
#  '2500  FERNANDO  Father...',
#  '2485  FERNANDO  Not bad.',
#  '2484  COLUMBUS  How are you feeling, Fernando?',
#  '2440  FERNANDO  This time with me!',
#  '2439  COLUMBUS  I have to explore the mainland.',
#  '2131  COLUMBUS  Yes... Yes, I do... On all of them!',
#  '2130  FERNANDO  Do you swear on all the Holy Saints in heaven?',
#  '2129  FERNANDO  You promise?  Do you swear on St. Christopher...?',
#  "2128  COLUMBUS  There'll be a time.",
#  '2127  FERNANDO  I want to go with you!',
#  '2469  COLUMBUS  All of them created by people like me.',
#  '2468  SANCHEZ  Roofs... towers, palaces... spires...',
#  '2467  COLUMBUS  What do you see?',
#  '2466  COLUMBUS  Look out of that window.',
#  '2465  SANCHEZ  I am not afraid of you.  You are nothing but a dreamer.',
#  '2464  COLUMBUS  Call them.',
#  '2463  SANCHEZ  All I have to do is call the guards.',
#  '2301  SANCHEZ  To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.',
#  '2300  COLUMBUS  What...?  Do I have so many already?',
#  '2299  SANCHEZ  You seem to have a special talent for making friends.',
#  '2297  COLUMBUS  Good!  We are also in need of judges.  Except there are no thieves!',
#  '2296  SANCHEZ  Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  '2295  COLUMBUS  But we do have a lack of notaries. You should contact my administration.',
#  '2287  COLUMBUS  ... for a commoner?',
#  '2286  SANCHEZ  You defend yourself admirably...',
#  '2282  SANCHEZ  Forgive me, Don Colon.  But what about gold?',
#  "2281  COLUMBUS  They don't see sin in their nakedness.  They live according to nature, in a never ending summer. The islands are covered with trees, filled with blossoms and fruits. And...",
#  "2110  SANCHEZ  If you won't accept our proposal, we'll simply find someone who will.",
#  '2109  COLUMBUS  And were you never ambitious, Excellency?  Or is ambition only a virtue among the nobles, a fault for the rest of us?',
#  '2108  SANCHEZ  Then you are too ambitious.',
#  "2107  COLUMBUS  I'm not bargaining!",
#  '2106  SANCHEZ  I remind you, Senor Colon, that you are in no position to bargain with me.',
#  '2105  COLUMBUS  NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!',
#  '2104  SANCHEZ  No?',
#  '2103  COLUMBUS  No...',
#  '2410  UTAPAN  You never learned how to speak my language.',
#  "2409  COLUMBUS  Utapan, won't you speak to me?  You used to know how to speak to me.",
#  '2394  UTAPAN  You did the same to your God!',
#  '2393  COLUMBUS  You have to find them, Utapan.  Look what they did!',
#  '2343  COLUMBUS  Ask him if he will help.',
#  '2342  UTAPAN  He understands.',
#  '2341  COLUMBUS  We will work with his people.  We want peace.  Ask the Chief if he understands?',
#  '2260  COLUMBUS  He has medicine.  Tell him we admire his people.',
#  '2259  UTAPAN  Chief says...',
#  '2258  COLUMBUS  ... and also to bring medicine.',
#  '2257  UTAPAN  Chief says -- he has a God.',
#  '2256  COLUMBUS  To bring the word of God.',
#  '2255  UTAPAN  Why?',
#  '2254  COLUMBUS  Thousands.',
#  '2253  UTAPAN  Chief says -- how many?',
#  '2251  COLUMBUS  Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.',
#  '2250  UTAPAN  Chief knows.',
#  '2249  COLUMBUS  Tell the Chief we thank him.',
#  '2248  UTAPAN  You come!  You speak first!',
#  '2239  UTAPAN  Island.  Far.',
#  '2238  COLUMBUS  What is it?  A tribe?  An island?',
#  '2237  UTAPAN  Say not here!  Cuba!',
#  "2535  COLUMBUS  I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!",
#  '2534  MARCHENA  Oh?  So you are a new man?',
#  '2533  COLUMBUS  New worlds create new people.',
#  '2532  MARCHENA  I knew you would.',
#  '2531  COLUMBUS  I have to disagree.',
#  "2526  COLUMBUS  You'll always be older than me, Father.",
#  "2525  MARCHENA  I suppose we're both old men now.",
#  '2145  COLUMBUS  Give me absolution.',
#  '2144  MARCHENA  I believed in you...',
#  '2143  COLUMBUS  You are bound by an oath, Father.',
#  "2142  MARCHENA  My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  "2141  COLUMBUS  If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  '2140  MARCHENA  May God forgive you...!  You must tell them!  You must tell your men!',
#  '2139  COLUMBUS  I am not sure... It could be twice the distance.',
#  '2138  MARCHENA  How long?',
#  '2137  COLUMBUS  I lied.  The journey will be longer than I said.',
#  '2136  MARCHENA  What are you saying?',
#  '2135  COLUMBUS  Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  '2134  MARCHENA  I am listening, my son.',
#  '2133  COLUMBUS  Forgive me, Father.  For I have sinned.',
#  '2132  MARCHENA  In Nomine Patris et Filius, et Spiritus Sancti.',
#  "2046  MARCHENA  Colon!  Don't!",
#  '2045  COLUMBUS  All of them!  Just lies!',
#  '2042  COLUMBUS  Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!',
#  '2041  MARCHENA  Colon!',
#  '2040  COLUMBUS  Damn God!',
#  '2039  MARCHENA  If God intends you to go, then you will go.',
#  "2038  COLUMBUS  Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  "2037  MARCHENA  You mustn't give way to despair. You must wait.",
#  '1969  MARCHENA  Only God knows the meaning of such words, my son.',
#  "1968  COLUMBUS  I've been contradicted all my life... Eternity!",
#  '1967  MARCHENA  You get so carried away when you are being contradicted!',
#  '1966  COLUMBUS  Passion is something one cannot control!',
#  '1965  MARCHENA  Father Marchena!',
#  "1964  COLUMBUS  I'll try to remember that, Marchena...",
#  "1963  MARCHENA  Two minutes... and already you're a dead man.  Don't let passion overwhelm you, Colon.",
#  '1962  COLUMBUS  So was Christ!',
#  '1961  MARCHENA  Esdras is a Jew.',
#  '1960  COLUMBUS  The calculations of Toscanelli Marin de Tyr, Esdras...',
#  '1959  MARCHENA  How can you be so certain?',
#  '1958  COLUMBUS  Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  '1957  MARCHENA  How can you be so certain?  The Ocean is said to be infinite.',
#  '1952  COLUMBUS  To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  '1951  MARCHENA  Why do you wish to sail west?',
#  '1950  MARCHENA  With some difficulty.  I had to promise them you were not a total fool.',
#  '1949  COLUMBUS  How did you manage it?',
#  "1948  MARCHENA  That's what it says.",
#  "1947  COLUMBUS  God... That's in a week!",
#  '1943  COLUMBUS  Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  '1942  MARCHENA  Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  '2459  COLUMBUS  Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  "2458  ISABEL  There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  '2457  COLUMBUS  Thank you.',
#  '2456  ISABEL  But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  '2280  COLUMBUS  They come and go as naked as the day God created them...',
#  '2279  ISABEL  Do they have such thoughts?',
#  '2086  COLUMBUS  Thirty seven, Your Majesty... And you?',
#  '2085  ISABEL  How old are you, Senor Colon?',
#  '2082  ISABEL  A woman?',
#  '2081  COLUMBUS  I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  '2080  ISABEL  You show no inclination to speak otherwise!',
#  '2079  COLUMBUS  May I speak freely?',
#  '2077  COLUMBUS  Surely you can do anything you want.',
#  '2076  ISABEL  I cannot ignore the verdict of my council.',
#  '2075  ISABEL  That she was impregnable.',
#  '2074  COLUMBUS  What did they say about Granada before today?',
#  '2073  ISABEL  The ocean is uncrossable?',
#  '2072  COLUMBUS  No more than the woman who said she would take Granada from the Moors.',
#  '2071  ISABEL  I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  '2389  MOXICA  You will regret this.',
#  "2388  COLUMBUS  You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  '2387  MOXICA  Savagery is what monkeys understand.',
#  '2386  COLUMBUS  In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  '2348  MOXICA  You did not hear me, Don Colon.  Not my horse.',
#  '2347  COLUMBUS  Don Moxica -- we all have to work.',
#  "2346  MOXICA  My horse doesn't work.",
#  "2345  COLUMBUS  We can't raise the wheel without it.",
#  '2333  COLUMBUS  We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "2332  MOXICA  We don't need to know.",
#  '2331  COLUMBUS  You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "2329  COLUMBUS  If you want to keep your head on your shoulders, you'll do as I say.",
#  '2328  MOXICA  We lost cousins, friends.  We will wash this in blood.',
#  '2278  COLUMBUS  The Indians have no such word, Don Moxica.',
#  "2277  MOXICA  And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  "2492  MENDEZ  We can't be.",
#  "2491  COLUMBUS  He's drawing an isthmus... He's saying we're on an isthmus.",
#  "2490  MENDEZ  What's he doing?",
#  '2165  MENDEZ  Twenty eight.',
#  '2164  COLUMBUS  What do you read?',
#  '2160  COLUMBUS  Come over here.',
#  "2159  MENDEZ  Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  '2158  COLUMBUS  And what do you think Mendez?',
#  "2157  MENDEZ  Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  '2155  MENDEZ  God be with us admiral.',
#  '2154  COLUMBUS  Due west, Captain Mendez.  And may God be with us...',
#  "2211  COLUMBUS  You're right.  Let the men decide.",
#  '2210  PINZON  You tell that to them!',
#  '2209  COLUMBUS  Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  '2208  PINZON  You bloody...',
#  '2207  COLUMBUS  You never did.  You did all the talking for both of us, remember?',
#  '2206  PINZON  Jesus Maria!  I should have never listened to you!',
#  '2205  COLUMBUS  And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  "2204  PINZON  You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  '2203  COLUMBUS  The land is there.  I know it!',
#  "2202  PINZON  We're lost!",
#  "2201  COLUMBUS  You think I don't know that?",
#  "2200  PINZON  We're on the verge of a mutiny, Colon!",
#  '2199  COLUMBUS  We have to keep the hopes of these men alive!',
#  '2198  PINZON  You must be mad...!',
#  '2197  COLUMBUS  Six days ago, yes.',
#  "2196  PINZON  You lied!  You cheated!  We're way past 750 leagues!",
#  '2065  PINZON  Immediately.',
#  '2064  COLUMBUS  Where can I meet this man?',
#  '2462  ISABEL  Because he is not afraid of me.',
#  '2461  SANCHEZ  Then why?',
#  '2460  ISABEL  I know, I should not tolerate his impertinence.',
#  '2419  ISABEL  And who would you think of, for such a task?',
#  '2418  SANCHEZ  He must be replaced.',
#  '2417  ISABEL  Then, what do you suggest, Don Sanchez?',
#  '2415  ISABEL  Is this true, Brother Buyl?',
#  '2414  SANCHEZ  ... But there is worse.  He ordered the execution of five members of the nobility...',
#  "2377  ISABEL  We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  '2376  SANCHEZ  Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  "2116  ISABEL  Yes.  It would be a pity, wouldn't it?  Call him back!",
#  '2115  SANCHEZ  ... Into a monk...',
#  '2113  SANCHEZ  Never, Your Majesty.  Although...',
#  '2112  ISABEL  You were right, Don Sanchez... His demands could never be granted.',
#  '1931  SANCHEZ  Yes, Your Majesty.',
#  '1930  ISABEL  Is that the man I knew, Treasurer Sanchez?',
#  "3546  CUTLER  Officers, there's your killer, do your duty, arrest him!",
#  '3545  EMIL  ...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  "3497  CUTLER  I don't think it's abuse, I think it's torture.",
#  "3496  EMIL  I'm abused.  Don't you think?",
#  '3493  CUTLER  Can I see your back?',
#  '3492  EMIL  Out on my back when I was a small boy.',
#  '3491  CUTLER  Your father put cigarettes out on you?',
#  "3490  EMIL  That's what he did to me.  He put cigarettes out on me.",
#  '3489  EMIL  Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  "3488  CUTLER  Your father blamed you for your mother's blindness?",
#  '3487  EMIL  Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  '3486  CUTLER  Back in the Czech Republic?',
#  '3485  EMIL  Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  '3484  CUTLER  Your mother was blind?',
#  '3483  EMIL  My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  '3482  CUTLER  Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  '3481  EMIL  Give me another one, please.',
#  "3480  CUTLER  I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  '3479  EMIL  What else do you need?',
#  '3478  CUTLER  This is not about money, Emil.  I need your trust in me.',
#  "3477  EMIL  Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  "3476  CUTLER  But it's...",
#  '3475  EMIL  No.  No way.',
#  '3474  CUTLER  I would say...half.  Half is fair.',
#  "3473  EMIL  What's your cut?  How much?",
#  "3472  CUTLER  Look, I haven't really focused on that kind of thing.",
#  '3471  EMIL  What about my movie rights?  Book rights?',
#  "3470  CUTLER  Don't worry about him.  Think about yourself.",
#  '3469  EMIL  No, he is here.  Shit...',
#  "3468  CUTLER  Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  '3467  EMIL  What about Oleg?',
#  "3466  CUTLER  Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  '3465  EMIL  I was all of these.',
#  '3464  CUTLER  ...delusions and paranoia.',
#  '3461  CUTLER  Oh, sure.',
#  '3460  EMIL  You bring the cigarettes?',
#  "3459  CUTLER  I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  "3396  CUTLER  I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  '3395  EMIL  Yes.  Yes, come with me!',
#  "3394  CUTLER  I'm coming with you.",
#  '3393  EMIL  Where are we going?',
#  "3392  CUTLER  Don't say anything.",
#  '3385  EMIL  He has the camera!  He took the movie!',
#  '3384  CUTLER  Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  '3383  EMIL  Oh no!  No!  Shit!',
#  '3382  EMIL  Here.  I have your money.',
#  "3381  CUTLER  I'm not your lawyer until I see the money.",
#  "3380  EMIL  Are you my attorney?  I'm Emil.  I'm insane.",
#  '3517  JORDY  Daphne, I...',
#  "3516  DAPHNE  I don't want to drag you down with me.",
#  '3515  JORDY  ...Do you really want me to forget about you?',
#  '3514  DAPHNE  Forget about me.  You have enough problems of your own.',
#  '3330  DAPHNE  Pouring it out!',
#  '3329  JORDY  What are you doing?',
#  "3318  DAPHNE  I'll get my clothes.",
#  "3317  JORDY  I'll make some for us.",
#  '3316  DAPHNE  In the kitchen.',
#  '3315  JORDY  Do you have coffee?']

# %%
# split conversation sequences by movie id with extracted first line IDs
lines_dict = dict()
start, end, x = 0, 0, 0
for i, convo in enumerate(convo_order_ls):
    for line in first_lines:
        if line == 'L194':
            continue
        if line in convo:
            end = i
            lines_dict['m'+str(x)] = convo_order_ls[start:end]
            start = end
            x +=1
            
# add final movie
lines_dict['m616'] = convo_order_ls[start:]

# %%
import itertools

# %%
def strip_letter(text):
    return int(text[1:])

# %%
first_lines_ids = []
for movie_id in movie_ids:
    
    codes = lines_dict[movie_id]
    
    codes =itertools.chain.from_iterable(codes)
    
    # Strip L from id, get lowest index value
    first_idx = min(map(lambda x: strip_letter(x),codes))
    first_lines_ids.append(first_idx)

# %%
first_lines_ids
# Out:
# [49,
#  1930,
#  2557,
#  3622,
#  4453,
#  5396,
#  6335,
#  7981,
#  8362,
#  55321,
#  12104,
#  16572,
#  18372,
#  19279,
#  24144,
#  26253,
#  29991,
#  31352,
#  34616,
#  35589,
#  36554,
#  44782,
#  55879,
#  57464,
#  59059,
#  59960,
#  61711,
#  62559,
#  64444,
#  66017,
#  83658,
#  85534,
#  86108,
#  87018,
#  87655,
#  92354,
#  96753,
#  101486,
#  103068,
#  107908,
#  109822,
#  117610,
#  118384,
#  122039,
#  130796,
#  140743,
#  148200,
#  152048,
#  153965,
#  162618,
#  168570,
#  170689,
#  172019,
#  179846,
#  187356,
#  194043,
#  195181,
#  195542,
#  203019,
#  206423,
#  208329,
#  210515,
#  220965,
#  222084,
#  224799,
#  227435,
#  241560,
#  247050,
#  228848,
#  232173,
#  232978,
#  235544,
#  236343,
#  237572,
#  238736,
#  239541,
#  242408,
#  250520,
#  253116,
#  255240,
#  257393,
#  260818,
#  267168,
#  269326,
#  270034,
#  273482,
#  273889,
#  274523,
#  279094,
#  281828,
#  283359,
#  284998,
#  290042,
#  294330,
#  295064,
#  296402,
#  307179,
#  298298,
#  299241,
#  300013,
#  302181,
#  303665,
#  306194,
#  310436,
#  327491,
#  312777,
#  315296,
#  317328,
#  319335,
#  329305,
#  333563,
#  334262,
#  336303,
#  338145,
#  346697,
#  339468,
#  343544,
#  344646,
#  345645,
#  348848,
#  347839,
#  350063,
#  352392,
#  355698,
#  356899,
#  381400,
#  386038,
#  360220,
#  364048,
#  366198,
#  370319,
#  370970,
#  374386,
#  378395,
#  379330,
#  384025,
#  389281,
#  390130,
#  391666,
#  392747,
#  395000,
#  399638,
#  400630,
#  405047,
#  405853,
#  411839,
#  412582,
#  413353,
#  414232,
#  418864,
#  420113,
#  421563,
#  423335,
#  425807,
#  426539,
#  434626,
#  435169,
#  435937,
#  439433,
#  441596,
#  443817,
#  444657,
#  447480,
#  454548,
#  456452,
#  469042,
#  458345,
#  461055,
#  461922,
#  463526,
#  465397,
#  474367,
#  484825,
#  491037,
#  496240,
#  497028,
#  503086,
#  503370,
#  504051,
#  505122,
#  505805,
#  507017,
#  509105,
#  510500,
#  513497,
#  514910,
#  515542,
#  518206,
#  521963,
#  529527,
#  532705,
#  545348,
#  534593,
#  533653,
#  535372,
#  536323,
#  539547,
#  537825,
#  540263,
#  542516,
#  550670,
#  562162,
#  566105,
#  592849,
#  568530,
#  569366,
#  577049,
#  587573,
#  588518,
#  589661,
#  590829,
#  591434,
#  595920,
#  601738,
#  603656,
#  583413,
#  594959,
#  599844,
#  607288,
#  611278,
#  618591,
#  620253,
#  624597,
#  625904,
#  630285,
#  636652,
#  645577,
#  646459,
#  650767,
#  652790,
#  660506,
#  661655,
#  9917,
#  10592,
#  13821,
#  14763,
#  23242,
#  26986,
#  27658,
#  29044,
#  33659,
#  38668,
#  41058,
#  42364,
#  43683,
#  45623,
#  46420,
#  47622,
#  49537,
#  51091,
#  51914,
#  53274,
#  58233,
#  60910,
#  62022,
#  63679,
#  65259,
#  67056,
#  67945,
#  69416,
#  72581,
#  73333,
#  74045,
#  76144,
#  76698,
#  78150,
#  80635,
#  82371,
#  83259,
#  84430,
#  86949,
#  89636,
#  89096,
#  91572,
#  93631,
#  94137,
#  95083,
#  98689,
#  99138,
#  100058,
#  100796,
#  106381,
#  108548,
#  110494,
#  112198,
#  112953,
#  114107,
#  114912,
#  116736,
#  119512,
#  122848,
#  123662,
#  124537,
#  125762,
#  126983,
#  127687,
#  129645,
#  132823,
#  133299,
#  134289,
#  136924,
#  137676,
#  139957,
#  141709,
#  142538,
#  143428,
#  144245,
#  145466,
#  145700,
#  146653,
#  147668,
#  149022,
#  149552,
#  150523,
#  151153,
#  153061,
#  154754,
#  156705,
#  157213,
#  159645,
#  160272,
#  161156,
#  164130,
#  165070,
#  166646,
#  167608,
#  169332,
#  172559,
#  173529,
#  174878,
#  176097,
#  179094,
#  181653,
#  182688,
#  183859,
#  184827,
#  189471,
#  191585,
#  193439,
#  193557,
#  196755,
#  197377,
#  198243,
#  200706,
#  201970,
#  203914,
#  204812,
#  205509,
#  212212,
#  214899,
#  214447,
#  216034,
#  217452,
#  218270,
#  219027,
#  219288,
#  220255,
#  223380,
#  223949,
#  225723,
#  226118,
#  226569,
#  226848,
#  229899,
#  230612,
#  231582,
#  234181,
#  234844,
#  243837,
#  244836,
#  246026,
#  247737,
#  248763,
#  249451,
#  254219,
#  256723,
#  257846,
#  258950,
#  260197,
#  259696,
#  261794,
#  264977,
#  266541,
#  271111,
#  272767,
#  275954,
#  277649,
#  278516,
#  281175,
#  287459,
#  288380,
#  290906,
#  291691,
#  292260,
#  292733,
#  293407,
#  295973,
#  296609,
#  304681,
#  305362,
#  308124,
#  308777,
#  311609,
#  320060,
#  321776,
#  324181,
#  325679,
#  325700,
#  326533,
#  328798,
#  330175,
#  331522,
#  332376,
#  332945,
#  335052,
#  335543,
#  337267,
#  338837,
#  340190,
#  341628,
#  342403,
#  347163,
#  351709,
#  353663,
#  354881,
#  356441,
#  358541,
#  359258,
#  361526,
#  367084,
#  367951,
#  368580,
#  369541,
#  372772,
#  373679,
#  375512,
#  376868,
#  379915,
#  382856,
#  383378,
#  384802,
#  387328,
#  387859,
#  388594,
#  390773,
#  391879,
#  396374,
#  398506,
#  399043,
#  401375,
#  403027,
#  402055,
#  403909,
#  406709,
#  407573,
#  409222,
#  410030,
#  410094,
#  410923,
#  414889,
#  416590,
#  417046,
#  422391,
#  428058,
#  429863,
#  430987,
#  432155,
#  433274,
#  437527,
#  438360,
#  440020,
#  440536,
#  442431,
#  443116,
#  445611,
#  446302,
#  448587,
#  449138,
#  450073,
#  450408,
#  451311,
#  452104,
#  453843,
#  456017,
#  457324,
#  457537,
#  456325,
#  459718,
#  462845,
#  466609,
#  467773,
#  469870,
#  470781,
#  472143,
#  472565,
#  475249,
#  478078,
#  477371,
#  479508,
#  480293,
#  481233,
#  481897,
#  482744,
#  483604,
#  485758,
#  487533,
#  488501,
#  486541,
#  489189,
#  490118,
#  495716,
#  499022,
#  499985,
#  500717,
#  502164,
#  506609,
#  507999,
#  511216,
#  512636,
#  514042,
#  516348,
#  519195,
#  520602,
#  522703,
#  523355,
#  524012,
#  525303,
#  526011,
#  526739,
#  541904,
#  543479,
#  544544,
#  547464,
#  548825,
#  550110,
#  551459,
#  552078,
#  552947,
#  554256,
#  554793,
#  555673,
#  556441,
#  557984,
#  558766,
#  560103,
#  564382,
#  565117,
#  567240,
#  567982,
#  570802,
#  572102,
#  573080,
#  574611,
#  575389,
#  576201,
#  578510,
#  580096,
#  581883,
#  584231,
#  585590,
#  585771,
#  586724,
#  593781,
#  594333,
#  596603,
#  597647,
#  598836,
#  599446,
#  600989,
#  602444,
#  609280,
#  612034,
#  612658,
#  613248,
#  614356,
#  615333,
#  616570,
#  617592,
#  619586,
#  621130,
#  622014,
#  622344,
#  623284,
#  623909,
#  625276,
#  626789,
#  627646,
#  629478,
#  632186,
#  633308,
#  634319,
#  634962,
#  635867,
#  637549,
#  638426,
#  640333,
#  641841,
#  642608,
#  643302,
#  644737,
#  646079,
#  647938,
#  649084,
#  649222,
#  650265,
#  651857,
#  654671,
#  656541,
#  657202,
#  658795,
#  659375,
#  662531,
#  663297,
#  664680,
#  664258,
#  665362,
#  666246]

# %%
#Delete first id, intialize start at starting index of lines
first_lines_ids.pop(0)
start=49
lines = dict()
x = 0

for num in first_lines_ids:
    
    lines['m'+str(x)]= ordered_df[(ordered_df.line_id>=start)&(ordered_df.line_id<num)]['dialogue']
    x +=1
    start=num
lines['m616'] = ordered_df[(ordered_df.line_id>=start)&(ordered_df.line_id<num)]['dialogue']

# %%
ordered_df
# Out:
#         line_id                                           dialogue
# 86           49                  BIANCA  Did you change your hair?
# 85           50                                      CHASTITY  No.
# 84           51             BIANCA  You might wanna think about it
# 648          59                             PATRICK  I missed you.
# 647          60  MISS PERKY  It says here you exposed yourself ...
# 646          61  PATRICK  It was a bratwurst.  I was eating lunch.
# 645          62         MISS PERKY  With the teeth of your zipper?
# 266          63                          MICHAEL  You the new guy?
# 265          64                        CAMERON  So they tell me...
# 264          65  MICHAEL  C'mon.  I'm supposed to give you the ...
# 263          66              MICHAEL  So -- which Dakota you from?
# 262          67           CAMERON  North, actually.  How'd you   ?
# 261          68  MICHAEL  I was kidding. People actually live t...
# 260          69  CAMERON  Yeah.  A couple.  We're outnumbered b...
# 259          70  MICHAEL  How many people were in your old school?
# 258          71                               CAMERON  Thirty-two.
# 257          72                                  MICHAEL  Get out!
# 256          73                  CAMERON  How many people go here?
# 255          74        MICHAEL  Couple thousand. Most of them evil
# 254          77                         CAMERON  That I'm used to.
# 253          78  MICHAEL  Yeah, but these guys have never seen ...
# 252          87                         CAMERON  That girl -- I --
# 251          88           MICHAEL  You burn, you pine, you perish?
# 250          89                               CAMERON  Who is she?
# 249          90  MICHAEL  Bianca Stratford.  Sophomore. Don't e...
# 248          91                                  CAMERON  Why not?
# 247          92  MICHAEL  I could start with your haircut, but ...
# 599         103  MISS PERKY  Katarina Stratford.  My, my.  You'...
# 598         104  KAT  Expressing my opinion is not a terrorist ...
# 597         105  MISS PERKY  Well, yes, compared to your other ...
# ...         ...                                                ...
# 304653   666398  CHELMSFORD  My only fear is that the Zulu will...
# 304683   666460  CREALOCK  The only reports of enemy activity h...
# 304682   666461                             CHELMSFORD  Thank you.
# 304641   666462           BOY-PULLEN  Why don 't the Zulus attack?
# 304640   666463  BLOOMFIELD  Zulu may not wear shoes or trouser...
# 304670   666480  CHELMSFORD  You intended to bring your reserve...
# 304669   666481  DURNFORD  I have received intelligence from, s...
# 304668   666482  CHELMSFORD  Intelligence? Sources of your own?...
# 304667   666483  CHELMSFORD  Are you dictating the strategy of ...
# 304666   666484               DURNFORD  I'm explaining my reasons.
# 304681   666485                                   CHELMSFORD  Yes?
# 304680   666486  CREALOCK  A large party of Zulus have been sig...
# 304665   666487  CHELMSFORD  Tomorrow we will continue our adva...
# 304664   666488  DURNFORD  And the threat of counter invasion n...
# 304694   666497                                   COGHILL  Stuart?
# 304693   666498                                 STUART SMITH  Yes.
# 304692   666499  COGHILL  How quickly can you move your artille...
# 304691   666500  STUART SMITH  Well, my horses are feeding, as ...
# 304690   666501  COGHILL  Well, fed or hungry, Pulleine wants t...
# 304689   666502    STUART SMITH  Right.  Bombardier, to me please.
# 304652   666503          CHELMSFORD  What o'clock is it, Mr Noggs?
# 304651   666504          NORRIS-NEWMAN  Eleven o'clock, My LorJ 42
# 304650   666505  CHELMSFORD  Our friend Colonel Dumford will be...
# 304706   666520  VEREKER  Well I assure you, Sir, I have no des...
# 304705   666521  DURNFORD  And I assure you, you do not In fact...
# 304704   666522  VEREKER  So far only their scouts. But we have...
# 304679   666546  CHELMSFORD  Splendid site, Crealock, splendil ...
# 304678   666547                           CREALOCK  Certainly, Sin
# 304696   666575  COGHILL  Choose your targets men. That's right...
# 304695   666576  MELVILL  Keep steady. You're the best shots of...
#
# [304713 rows x 2 columns]

# %%
movie_ids
# Out:
# ['m0',
#  'm1',
#  'm2',
#  'm3',
#  'm4',
#  'm5',
#  'm6',
#  'm7',
#  'm8',
#  'm9',
#  'm10',
#  'm11',
#  'm12',
#  'm13',
#  'm14',
#  'm15',
#  'm16',
#  'm17',
#  'm18',
#  'm19',
#  'm20',
#  'm21',
#  'm22',
#  'm23',
#  'm24',
#  'm25',
#  'm26',
#  'm27',
#  'm28',
#  'm29',
#  'm30',
#  'm31',
#  'm32',
#  'm33',
#  'm34',
#  'm35',
#  'm36',
#  'm37',
#  'm38',
#  'm39',
#  'm40',
#  'm41',
#  'm42',
#  'm43',
#  'm44',
#  'm45',
#  'm46',
#  'm47',
#  'm48',
#  'm49',
#  'm50',
#  'm51',
#  'm52',
#  'm53',
#  'm54',
#  'm55',
#  'm56',
#  'm57',
#  'm58',
#  'm59',
#  'm60',
#  'm61',
#  'm62',
#  'm63',
#  'm64',
#  'm65',
#  'm66',
#  'm67',
#  'm68',
#  'm69',
#  'm70',
#  'm71',
#  'm72',
#  'm73',
#  'm74',
#  'm75',
#  'm76',
#  'm77',
#  'm78',
#  'm79',
#  'm80',
#  'm81',
#  'm82',
#  'm83',
#  'm84',
#  'm85',
#  'm86',
#  'm87',
#  'm88',
#  'm89',
#  'm90',
#  'm91',
#  'm92',
#  'm93',
#  'm94',
#  'm95',
#  'm96',
#  'm97',
#  'm98',
#  'm99',
#  'm100',
#  'm101',
#  'm102',
#  'm103',
#  'm104',
#  'm105',
#  'm106',
#  'm107',
#  'm108',
#  'm109',
#  'm110',
#  'm111',
#  'm112',
#  'm113',
#  'm114',
#  'm115',
#  'm116',
#  'm117',
#  'm118',
#  'm119',
#  'm120',
#  'm121',
#  'm122',
#  'm123',
#  'm124',
#  'm125',
#  'm126',
#  'm127',
#  'm128',
#  'm129',
#  'm130',
#  'm131',
#  'm132',
#  'm133',
#  'm134',
#  'm135',
#  'm136',
#  'm137',
#  'm138',
#  'm139',
#  'm140',
#  'm141',
#  'm142',
#  'm143',
#  'm144',
#  'm145',
#  'm146',
#  'm147',
#  'm148',
#  'm149',
#  'm150',
#  'm151',
#  'm152',
#  'm153',
#  'm154',
#  'm155',
#  'm156',
#  'm157',
#  'm158',
#  'm159',
#  'm160',
#  'm161',
#  'm162',
#  'm163',
#  'm164',
#  'm165',
#  'm166',
#  'm167',
#  'm168',
#  'm169',
#  'm170',
#  'm171',
#  'm172',
#  'm173',
#  'm174',
#  'm175',
#  'm176',
#  'm177',
#  'm178',
#  'm179',
#  'm180',
#  'm181',
#  'm182',
#  'm183',
#  'm184',
#  'm185',
#  'm186',
#  'm187',
#  'm188',
#  'm189',
#  'm190',
#  'm191',
#  'm192',
#  'm193',
#  'm194',
#  'm195',
#  'm196',
#  'm197',
#  'm198',
#  'm199',
#  'm200',
#  'm201',
#  'm202',
#  'm203',
#  'm204',
#  'm205',
#  'm206',
#  'm207',
#  'm208',
#  'm209',
#  'm210',
#  'm211',
#  'm212',
#  'm213',
#  'm214',
#  'm215',
#  'm216',
#  'm217',
#  'm218',
#  'm219',
#  'm220',
#  'm221',
#  'm222',
#  'm223',
#  'm224',
#  'm225',
#  'm226',
#  'm227',
#  'm228',
#  'm229',
#  'm230',
#  'm231',
#  'm232',
#  'm233',
#  'm234',
#  'm235',
#  'm236',
#  'm237',
#  'm238',
#  'm239',
#  'm240',
#  'm241',
#  'm242',
#  'm243',
#  'm244',
#  'm245',
#  'm246',
#  'm247',
#  'm248',
#  'm249',
#  'm250',
#  'm251',
#  'm252',
#  'm253',
#  'm254',
#  'm255',
#  'm256',
#  'm257',
#  'm258',
#  'm259',
#  'm260',
#  'm261',
#  'm262',
#  'm263',
#  'm264',
#  'm265',
#  'm266',
#  'm267',
#  'm268',
#  'm269',
#  'm270',
#  'm271',
#  'm272',
#  'm273',
#  'm274',
#  'm275',
#  'm276',
#  'm277',
#  'm278',
#  'm279',
#  'm280',
#  'm281',
#  'm282',
#  'm283',
#  'm284',
#  'm285',
#  'm286',
#  'm287',
#  'm288',
#  'm289',
#  'm290',
#  'm291',
#  'm292',
#  'm293',
#  'm294',
#  'm295',
#  'm296',
#  'm297',
#  'm298',
#  'm299',
#  'm300',
#  'm301',
#  'm302',
#  'm303',
#  'm304',
#  'm305',
#  'm306',
#  'm307',
#  'm308',
#  'm309',
#  'm310',
#  'm311',
#  'm312',
#  'm313',
#  'm314',
#  'm315',
#  'm316',
#  'm317',
#  'm318',
#  'm319',
#  'm320',
#  'm321',
#  'm322',
#  'm323',
#  'm324',
#  'm325',
#  'm326',
#  'm327',
#  'm328',
#  'm329',
#  'm330',
#  'm331',
#  'm332',
#  'm333',
#  'm334',
#  'm335',
#  'm336',
#  'm337',
#  'm338',
#  'm339',
#  'm340',
#  'm341',
#  'm342',
#  'm343',
#  'm344',
#  'm345',
#  'm346',
#  'm347',
#  'm348',
#  'm349',
#  'm350',
#  'm351',
#  'm352',
#  'm353',
#  'm354',
#  'm355',
#  'm356',
#  'm357',
#  'm358',
#  'm359',
#  'm360',
#  'm361',
#  'm362',
#  'm363',
#  'm364',
#  'm365',
#  'm366',
#  'm367',
#  'm368',
#  'm369',
#  'm370',
#  'm371',
#  'm372',
#  'm373',
#  'm374',
#  'm375',
#  'm376',
#  'm377',
#  'm378',
#  'm379',
#  'm380',
#  'm381',
#  'm382',
#  'm383',
#  'm384',
#  'm385',
#  'm386',
#  'm387',
#  'm388',
#  'm389',
#  'm390',
#  'm391',
#  'm392',
#  'm393',
#  'm394',
#  'm395',
#  'm396',
#  'm397',
#  'm398',
#  'm399',
#  'm400',
#  'm401',
#  'm402',
#  'm403',
#  'm404',
#  'm405',
#  'm406',
#  'm407',
#  'm408',
#  'm409',
#  'm410',
#  'm411',
#  'm412',
#  'm413',
#  'm414',
#  'm415',
#  'm416',
#  'm417',
#  'm418',
#  'm419',
#  'm420',
#  'm421',
#  'm422',
#  'm423',
#  'm424',
#  'm425',
#  'm426',
#  'm427',
#  'm428',
#  'm429',
#  'm430',
#  'm431',
#  'm432',
#  'm433',
#  'm434',
#  'm435',
#  'm436',
#  'm437',
#  'm438',
#  'm439',
#  'm440',
#  'm441',
#  'm442',
#  'm443',
#  'm444',
#  'm445',
#  'm446',
#  'm447',
#  'm448',
#  'm449',
#  'm450',
#  'm451',
#  'm452',
#  'm453',
#  'm454',
#  'm455',
#  'm456',
#  'm457',
#  'm458',
#  'm459',
#  'm460',
#  'm461',
#  'm462',
#  'm463',
#  'm464',
#  'm465',
#  'm466',
#  'm467',
#  'm468',
#  'm469',
#  'm470',
#  'm471',
#  'm472',
#  'm473',
#  'm474',
#  'm475',
#  'm476',
#  'm477',
#  'm478',
#  'm479',
#  'm480',
#  'm481',
#  'm482',
#  'm483',
#  'm484',
#  'm485',
#  'm486',
#  'm487',
#  'm488',
#  'm489',
#  'm490',
#  'm491',
#  'm492',
#  'm493',
#  'm494',
#  'm495',
#  'm496',
#  'm497',
#  'm498',
#  'm499',
#  'm500',
#  'm501',
#  'm502',
#  'm503',
#  'm504',
#  'm505',
#  'm506',
#  'm507',
#  'm508',
#  'm509',
#  'm510',
#  'm511',
#  'm512',
#  'm513',
#  'm514',
#  'm515',
#  'm516',
#  'm517',
#  'm518',
#  'm519',
#  'm520',
#  'm521',
#  'm522',
#  'm523',
#  'm524',
#  'm525',
#  'm526',
#  'm527',
#  'm528',
#  'm529',
#  'm530',
#  'm531',
#  'm532',
#  'm533',
#  'm534',
#  'm535',
#  'm536',
#  'm537',
#  'm538',
#  'm539',
#  'm540',
#  'm541',
#  'm542',
#  'm543',
#  'm544',
#  'm545',
#  'm546',
#  'm547',
#  'm548',
#  'm549',
#  'm550',
#  'm551',
#  'm552',
#  'm553',
#  'm554',
#  'm555',
#  'm556',
#  'm557',
#  'm558',
#  'm559',
#  'm560',
#  'm561',
#  'm562',
#  'm563',
#  'm564',
#  'm565',
#  'm566',
#  'm567',
#  'm568',
#  'm569',
#  'm570',
#  'm571',
#  'm572',
#  'm573',
#  'm574',
#  'm575',
#  'm576',
#  'm577',
#  'm578',
#  'm579',
#  'm580',
#  'm581',
#  'm582',
#  'm583',
#  'm584',
#  'm585',
#  'm586',
#  'm587',
#  'm588',
#  'm589',
#  'm590',
#  'm591',
#  'm592',
#  'm593',
#  'm594',
#  'm595',
#  'm596',
#  'm597',
#  'm598',
#  'm599',
#  'm600',
#  'm601',
#  'm602',
#  'm603',
#  'm604',
#  'm605',
#  'm606',
#  'm607',
#  'm608',
#  'm609',
#  'm610',
#  'm611',
#  'm612',
#  'm613',
#  'm614',
#  'm615',
#  'm616']

# %%
for movie_id in movie_ids:
    lines[movie_id] = " ".join(lines[movie_id])

# %%
dialog_df = pd.DataFrame.from_dict(lines, orient='index')
dialog_df.columns = ['dialogue']

# %%
dialog_df.to_csv('/Users/markespina/Downloads/movie-dialogs-corpus/movies_dialogs_ordered.csv')

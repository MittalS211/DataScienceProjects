# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import BernoulliNB
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)   
pd.set_option('display.max_colwidth', -1)

# %%
#read data
data_path = ('/Users/markespina/Downloads/sentiment_labelled_sentences/yelp_labelled.txt'
            )
data_raw = pd.read_csv(data_path, delimiter= '\t', header=None)
#rename columns
data_raw.columns=['review', 'sentiment']

# %%
keywords=['great', 'good', 'love', 'amazing', 'fantastic']
for key in keywords:
# chosen key words more likely to be end of senctence for positive reviews, adjust for pattern
    data_raw[str(key)] = data_raw.review.str.contains(
        ' ' + str(key),
        case=False
    )
data_raw["absence of 'not'"]=data_raw.review.str.contains('not' + ' ', case=False)==False

# %%
data_raw['char_count']=data_raw.review.apply(lambda x: len(x))

# %%
data_raw['char_count<100']=(data_raw['char_count']<100)

# %%
# count number of conditions met
for x in range(len(data_raw)):
    bool_cnt=0
    for elem in list(data_raw.T[x]):
        if elem==True:
            bool_cnt+=1
    data_raw.loc[x, 'condition_count>2']=bool_cnt

# %%
'''review meets 3 conditional features, most likely to be positive, 
   i.e has 3 keywords, is under 100 chars, doesn't contain 'not' and has one keyword etc...'''
data_raw['condition_count>2']=data_raw['condition_count>2']>2

# %%
data_raw
# Out:
#                                                                                                                                                     review  sentiment  great   good   love  amazing  fantastic  absence of 'not'  char_count  char_count<100  condition_count>2
# 0    Wow... Loved this place.                                                                                                                               1          False  False  True   False    False      True              24          True            True
# 1    Crust is not good.                                                                                                                                     0          False  True   False  False    False      False             18          True            False
# 2    Not tasty and the texture was just nasty.                                                                                                              0          False  False  False  False    False      False             41          True            False
# 3    Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.                                                                1          False  False  True   False    False      True              87          True            True
# 4    The selection on the menu was great and so were the prices.                                                                                            1          True   False  False  False    False      True              59          True            True
# 5    Now I am getting angry and I want my damn pho.                                                                                                         0          False  False  False  False    False      True              46          True            False
# 6    Honeslty it didn't taste THAT fresh.)                                                                                                                  0          False  False  False  False    False      True              37          True            False
# 7    The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.                                        0          False  False  False  False    False      True              111         False           False
# 8    The fries were great too.                                                                                                                              1          True   False  False  False    False      True              25          True            True
# 9    A great touch.                                                                                                                                         1          True   False  False  False    False      True              14          True            True
# 10   Service was very prompt.                                                                                                                               1          False  False  False  False    False      True              24          True            True
# 11   Would not go back.                                                                                                                                     0          False  False  False  False    False      False             18          True            False
# 12   The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.                                                    0          False  False  False  False    False      True              99          True            False
# 13   I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!                                                                                            1          False  False  False  False    False      True              59          True            True
# 14   I was disgusted because I was pretty sure that was human hair.                                                                                         0          False  False  False  False    False      True              62          True            False
# 15   I was shocked because no signs indicate cash only.                                                                                                     0          False  False  False  False    False      True              50          True            False
# 16   Highly recommended.                                                                                                                                    1          False  False  False  False    False      True              19          True            True
# 17   Waitress was a little slow in service.                                                                                                                 0          False  False  False  False    False      True              38          True            False
# 18   This place is not worth your time, let alone Vegas.                                                                                                    0          False  False  False  False    False      False             51          True            False
# 19   did not like at all.                                                                                                                                   0          False  False  False  False    False      False             20          True            False
# 20   The Burrittos Blah!                                                                                                                                    0          False  False  False  False    False      True              19          True            False
# 21   The food, amazing.                                                                                                                                     1          False  False  False  True     False      True              18          True            True
# 22   Service is also cute.                                                                                                                                  1          False  False  False  False    False      True              21          True            True
# 23   I could care less... The interior is just beautiful.                                                                                                   1          False  False  False  False    False      True              52          True            True
# 24   So they performed.                                                                                                                                     1          False  False  False  False    False      True              18          True            True
# 25   That's right....the red velvet cake.....ohhh this stuff is so good.                                                                                    1          False  True   False  False    False      True              67          True            True
# 26   - They never brought a salad we asked for.                                                                                                             0          False  False  False  False    False      True              42          True            False
# 27   This hole in the wall has great Mexican street tacos, and friendly staff.                                                                              1          True   False  False  False    False      True              73          True            True
# 28   Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.          0          False  False  False  False    False      True              141         False           False
# 29   The worst was the salmon sashimi.                                                                                                                      0          False  False  False  False    False      True              33          True            False
# ..                                 ...                                                                                                                     ..            ...    ...    ...    ...      ...       ...              ..           ...              ...
# 970  I immediately said I wanted to talk to the manager but I did not want to talk to the guy who was doing shots of fireball behind the bar.               0          False  False  False  False    False      False             136         False           False
# 971  The ambiance isn't much better.                                                                                                                        0          False  False  False  False    False      True              31          True            False
# 972  Unfortunately, it only set us up for disapppointment with our entrees.                                                                                 0          False  False  False  False    False      True              70          True            False
# 973  The food wasn't good.                                                                                                                                  0          False  True   False  False    False      True              21          True            True
# 974  Your servers suck, wait, correction, our server Heimer sucked.                                                                                         0          False  False  False  False    False      True              62          True            False
# 975  What happened next was pretty....off putting.                                                                                                          0          False  False  False  False    False      True              45          True            False
# 976  too bad cause I know it's family owned, I really wanted to like this place.                                                                            0          False  False  False  False    False      True              75          True            False
# 977  Overpriced for what you are getting.                                                                                                                   0          False  False  False  False    False      True              36          True            False
# 978  I vomited in the bathroom mid lunch.                                                                                                                   0          False  False  False  False    False      True              36          True            False
# 979  I kept looking at the time and it had soon become 35 minutes, yet still no food.                                                                       0          False  False  False  False    False      True              80          True            False
# 980  I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list.                                      0          False  False  False  False    False      True              113         False           False
# 981  We started with the tuna sashimi which was brownish in color and obviously wasn't fresh.                                                               0          False  False  False  False    False      True              88          True            False
# 982  Food was below average.                                                                                                                                0          False  False  False  False    False      True              23          True            False
# 983  It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant.                                              0          False  False  False  False    False      True              105         False           False
# 984  All in all, Ha Long Bay was a bit of a flop.                                                                                                           0          False  False  False  False    False      True              44          True            False
# 985  The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).  0          False  False  False  False    False      True              149         False           False
# 986  Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold.                                                         0          False  False  False  False    False      True              94          True            False
# 987  It lacked flavor, seemed undercooked, and dry.                                                                                                         0          False  False  False  False    False      True              46          True            False
# 988  It really is impressive that the place hasn't closed down.                                                                                             0          False  False  False  False    False      True              58          True            False
# 989  I would avoid this place if you are staying in the Mirage.                                                                                             0          False  False  False  False    False      True              58          True            False
# 990  The refried beans that came with my meal were dried out and crusty and the food was bland.                                                             0          False  False  False  False    False      True              90          True            False
# 991  Spend your money and time some place else.                                                                                                             0          False  False  False  False    False      True              42          True            False
# 992  A lady at the table next to us found a live green caterpillar In her salad.                                                                            0          False  False  False  False    False      True              75          True            False
# 993  the presentation of the food was awful.                                                                                                                0          False  False  False  False    False      True              39          True            False
# 994  I can't tell you how disappointed I was.                                                                                                               0          False  False  False  False    False      True              40          True            False
# 995  I think food should have flavor and texture and both were lacking.                                                                                     0          False  False  False  False    False      True              66          True            False
# 996  Appetite instantly gone.                                                                                                                               0          False  False  False  False    False      True              24          True            False
# 997  Overall I was not impressed and would not go back.                                                                                                     0          False  False  False  False    False      False             50          True            False
# 998  The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time.                                                            0          False  False  False  False    False      True              91          True            False
# 999  Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.                 0          False  False  False  False    False      True              134         False           False
#
# [1000 rows x 11 columns]

# %%
data_raw['sentiment'] = (data_raw['sentiment'] == 1)

# %%
sns.heatmap(data_raw.corr())

# %%
data_raw
# Out:
#                                                                                                                                                     review  sentiment  great   good   love  amazing  fantastic  absence of 'not'  char_count  char_count<100  true_count>2
# 0    Wow... Loved this place.                                                                                                                               True       False  False  True   False    False      True              24          True            True
# 1    Crust is not good.                                                                                                                                     False      False  True   False  False    False      False             18          True            False
# 2    Not tasty and the texture was just nasty.                                                                                                              False      False  False  False  False    False      False             41          True            False
# 3    Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.                                                                True       False  False  True   False    False      True              87          True            True
# 4    The selection on the menu was great and so were the prices.                                                                                            True       True   False  False  False    False      True              59          True            True
# 5    Now I am getting angry and I want my damn pho.                                                                                                         False      False  False  False  False    False      True              46          True            False
# 6    Honeslty it didn't taste THAT fresh.)                                                                                                                  False      False  False  False  False    False      True              37          True            False
# 7    The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.                                        False      False  False  False  False    False      True              111         False           False
# 8    The fries were great too.                                                                                                                              True       True   False  False  False    False      True              25          True            True
# 9    A great touch.                                                                                                                                         True       True   False  False  False    False      True              14          True            True
# 10   Service was very prompt.                                                                                                                               True       False  False  False  False    False      True              24          True            True
# 11   Would not go back.                                                                                                                                     False      False  False  False  False    False      False             18          True            False
# 12   The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.                                                    False      False  False  False  False    False      True              99          True            False
# 13   I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!                                                                                            True       False  False  False  False    False      True              59          True            True
# 14   I was disgusted because I was pretty sure that was human hair.                                                                                         False      False  False  False  False    False      True              62          True            False
# 15   I was shocked because no signs indicate cash only.                                                                                                     False      False  False  False  False    False      True              50          True            False
# 16   Highly recommended.                                                                                                                                    True       False  False  False  False    False      True              19          True            True
# 17   Waitress was a little slow in service.                                                                                                                 False      False  False  False  False    False      True              38          True            False
# 18   This place is not worth your time, let alone Vegas.                                                                                                    False      False  False  False  False    False      False             51          True            False
# 19   did not like at all.                                                                                                                                   False      False  False  False  False    False      False             20          True            False
# 20   The Burrittos Blah!                                                                                                                                    False      False  False  False  False    False      True              19          True            False
# 21   The food, amazing.                                                                                                                                     True       False  False  False  True     False      True              18          True            True
# 22   Service is also cute.                                                                                                                                  True       False  False  False  False    False      True              21          True            True
# 23   I could care less... The interior is just beautiful.                                                                                                   True       False  False  False  False    False      True              52          True            True
# 24   So they performed.                                                                                                                                     True       False  False  False  False    False      True              18          True            True
# 25   That's right....the red velvet cake.....ohhh this stuff is so good.                                                                                    True       False  True   False  False    False      True              67          True            True
# 26   - They never brought a salad we asked for.                                                                                                             False      False  False  False  False    False      True              42          True            False
# 27   This hole in the wall has great Mexican street tacos, and friendly staff.                                                                              True       True   False  False  False    False      True              73          True            True
# 28   Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.          False      False  False  False  False    False      True              141         False           False
# 29   The worst was the salmon sashimi.                                                                                                                      False      False  False  False  False    False      True              33          True            False
# ..                                 ...                                                                                                                        ...        ...    ...    ...    ...      ...       ...              ..           ...              ...
# 970  I immediately said I wanted to talk to the manager but I did not want to talk to the guy who was doing shots of fireball behind the bar.               False      False  False  False  False    False      False             136         False           False
# 971  The ambiance isn't much better.                                                                                                                        False      False  False  False  False    False      True              31          True            False
# 972  Unfortunately, it only set us up for disapppointment with our entrees.                                                                                 False      False  False  False  False    False      True              70          True            False
# 973  The food wasn't good.                                                                                                                                  False      False  True   False  False    False      True              21          True            True
# 974  Your servers suck, wait, correction, our server Heimer sucked.                                                                                         False      False  False  False  False    False      True              62          True            False
# 975  What happened next was pretty....off putting.                                                                                                          False      False  False  False  False    False      True              45          True            False
# 976  too bad cause I know it's family owned, I really wanted to like this place.                                                                            False      False  False  False  False    False      True              75          True            False
# 977  Overpriced for what you are getting.                                                                                                                   False      False  False  False  False    False      True              36          True            False
# 978  I vomited in the bathroom mid lunch.                                                                                                                   False      False  False  False  False    False      True              36          True            False
# 979  I kept looking at the time and it had soon become 35 minutes, yet still no food.                                                                       False      False  False  False  False    False      True              80          True            False
# 980  I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list.                                      False      False  False  False  False    False      True              113         False           False
# 981  We started with the tuna sashimi which was brownish in color and obviously wasn't fresh.                                                               False      False  False  False  False    False      True              88          True            False
# 982  Food was below average.                                                                                                                                False      False  False  False  False    False      True              23          True            False
# 983  It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant.                                              False      False  False  False  False    False      True              105         False           False
# 984  All in all, Ha Long Bay was a bit of a flop.                                                                                                           False      False  False  False  False    False      True              44          True            False
# 985  The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).  False      False  False  False  False    False      True              149         False           False
# 986  Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold.                                                         False      False  False  False  False    False      True              94          True            False
# 987  It lacked flavor, seemed undercooked, and dry.                                                                                                         False      False  False  False  False    False      True              46          True            False
# 988  It really is impressive that the place hasn't closed down.                                                                                             False      False  False  False  False    False      True              58          True            False
# 989  I would avoid this place if you are staying in the Mirage.                                                                                             False      False  False  False  False    False      True              58          True            False
# 990  The refried beans that came with my meal were dried out and crusty and the food was bland.                                                             False      False  False  False  False    False      True              90          True            False
# 991  Spend your money and time some place else.                                                                                                             False      False  False  False  False    False      True              42          True            False
# 992  A lady at the table next to us found a live green caterpillar In her salad.                                                                            False      False  False  False  False    False      True              75          True            False
# 993  the presentation of the food was awful.                                                                                                                False      False  False  False  False    False      True              39          True            False
# 994  I can't tell you how disappointed I was.                                                                                                               False      False  False  False  False    False      True              40          True            False
# 995  I think food should have flavor and texture and both were lacking.                                                                                     False      False  False  False  False    False      True              66          True            False
# 996  Appetite instantly gone.                                                                                                                               False      False  False  False  False    False      True              24          True            False
# 997  Overall I was not impressed and would not go back.                                                                                                     False      False  False  False  False    False      False             50          True            False
# 998  The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time.                                                            False      False  False  False  False    False      True              91          True            False
# 999  Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.                 False      False  False  False  False    False      True              134         False           False
#
# [1000 rows x 11 columns]

# %%
data = data_raw[keywords+['char_count<100']+['condition_count>2']]
target = data_raw['sentiment']

# %%
data
# Out:
#      great   good   love  amazing  fantastic  char_count<100  condition_count>2
# 0    False  False  True   False    False      True            True
# 1    False  True   False  False    False      True            False
# 2    False  False  False  False    False      True            False
# 3    False  False  True   False    False      True            True
# 4    True   False  False  False    False      True            True
# 5    False  False  False  False    False      True            False
# 6    False  False  False  False    False      True            False
# 7    False  False  False  False    False      False           False
# 8    True   False  False  False    False      True            True
# 9    True   False  False  False    False      True            True
# 10   False  False  False  False    False      True            True
# 11   False  False  False  False    False      True            False
# 12   False  False  False  False    False      True            False
# 13   False  False  False  False    False      True            True
# 14   False  False  False  False    False      True            False
# 15   False  False  False  False    False      True            False
# 16   False  False  False  False    False      True            True
# 17   False  False  False  False    False      True            False
# 18   False  False  False  False    False      True            False
# 19   False  False  False  False    False      True            False
# 20   False  False  False  False    False      True            False
# 21   False  False  False  True     False      True            True
# 22   False  False  False  False    False      True            True
# 23   False  False  False  False    False      True            True
# 24   False  False  False  False    False      True            True
# 25   False  True   False  False    False      True            True
# 26   False  False  False  False    False      True            False
# 27   True   False  False  False    False      True            True
# 28   False  False  False  False    False      False           False
# 29   False  False  False  False    False      True            False
# ..     ...    ...    ...    ...      ...       ...              ...
# 970  False  False  False  False    False      False           False
# 971  False  False  False  False    False      True            False
# 972  False  False  False  False    False      True            False
# 973  False  True   False  False    False      True            True
# 974  False  False  False  False    False      True            False
# 975  False  False  False  False    False      True            False
# 976  False  False  False  False    False      True            False
# 977  False  False  False  False    False      True            False
# 978  False  False  False  False    False      True            False
# 979  False  False  False  False    False      True            False
# 980  False  False  False  False    False      False           False
# 981  False  False  False  False    False      True            False
# 982  False  False  False  False    False      True            False
# 983  False  False  False  False    False      False           False
# 984  False  False  False  False    False      True            False
# 985  False  False  False  False    False      False           False
# 986  False  False  False  False    False      True            False
# 987  False  False  False  False    False      True            False
# 988  False  False  False  False    False      True            False
# 989  False  False  False  False    False      True            False
# 990  False  False  False  False    False      True            False
# 991  False  False  False  False    False      True            False
# 992  False  False  False  False    False      True            False
# 993  False  False  False  False    False      True            False
# 994  False  False  False  False    False      True            False
# 995  False  False  False  False    False      True            False
# 996  False  False  False  False    False      True            False
# 997  False  False  False  False    False      True            False
# 998  False  False  False  False    False      True            False
# 999  False  False  False  False    False      False           False
#
# [1000 rows x 7 columns]

# %%
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)

# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 49
